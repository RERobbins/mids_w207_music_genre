# %%
import sys
import json
import ast
import pandas as pd

sys.path.append("../../")

from helpers.save import results

# %%
save = results('rich_results.json')
# Out:
# /Users/rerobbins/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/../../results/rich_results.json
# file exist, reading json

# %%
df = save.getDataframe()
df
# Out:
#                   model                        dataset  phase  \
# 0    LogisticRegression             dataset_00_all_pca  train
# 1    LogisticRegression             dataset_00_all_pca   test
# 2    LogisticRegression            dataset_01_mean_pca  train
# 3    LogisticRegression            dataset_01_mean_pca   test
# 4    LogisticRegression        dataset_02_mean_cov_pca  train
# ..                  ...                            ...    ...
# 257                 SVC       dataset_07_pvtt_mean_cov   test
# 258                 SVC      dataset_08_pvtt_mean_icov  train
# 259                 SVC      dataset_08_pvtt_mean_icov   test
# 260                 SVC  dataset_09_pvtt_mean_cov_icov  train
# 261                 SVC  dataset_09_pvtt_mean_cov_icov   test
#
#                                                 result
# 0    {'genre_blues': {'precision': 0.2531194296, 'r...
# 1    {'genre_blues': {'precision': 0.1392857143, 'r...
# 2    {'genre_blues': {'precision': 0.052905464, 're...
# 3    {'genre_blues': {'precision': 0.0729927007, 'r...
# 4    {'genre_blues': {'precision': 0.0933660934, 'r...
# ..                                                 ...
# 257  {'genre_blues': {'precision': 0.1666666667, 'r...
# 258  {'genre_blues': {'precision': 0.0626525631, 'r...
# 259  {'genre_blues': {'precision': 0.0733333333, 'r...
# 260  {'genre_blues': {'precision': 0.2246575342, 'r...
# 261  {'genre_blues': {'precision': 0.1338582677, 'r...
#
# [262 rows x 4 columns]

# %%
df = save.unnestDataframeLevel(level = 2)
df
# Out:
#                   model                        dataset  phase  \
# 0    LogisticRegression             dataset_00_all_pca  train
# 1    LogisticRegression             dataset_00_all_pca   test
# 2    LogisticRegression            dataset_01_mean_pca  train
# 3    LogisticRegression            dataset_01_mean_pca   test
# 4    LogisticRegression        dataset_02_mean_cov_pca  train
# ..                  ...                            ...    ...
# 257                 SVC       dataset_07_pvtt_mean_cov   test
# 258                 SVC      dataset_08_pvtt_mean_icov  train
# 259                 SVC      dataset_08_pvtt_mean_icov   test
# 260                 SVC  dataset_09_pvtt_mean_cov_icov  train
# 261                 SVC  dataset_09_pvtt_mean_cov_icov   test
#
#      result.genre_blues.precision  result.genre_blues.recall  \
# 0                        0.253119                   0.759358
# 1                        0.139286                   0.414894
# 2                        0.052905                   0.163102
# 3                        0.072993                   0.212766
# 4                        0.093366                   0.304813
# ..                            ...                        ...
# 257                      0.166667                   0.351064
# 258                      0.062653                   0.205882
# 259                      0.073333                   0.234043
# 260                      0.224658                   0.657754
# 261                      0.133858                   0.361702
#
#      result.genre_blues.f1-score  result.genre_blues.support  \
# 0                       0.379679                         374
# 1                       0.208556                          94
# 2                       0.079895                         374
# 3                       0.108696                          94
# 4                       0.142947                         374
# ..                           ...                         ...
# 257                     0.226027                          94
# 258                     0.096070                         374
# 259                     0.111675                          94
# 260                     0.334922                         374
# 261                     0.195402                          94
#
#      result.genre_blues.mcc  result.genre_classical.precision  \
# 0                  0.418941                          0.913087
# 1                  0.211731                          0.887379
# 2                  0.057009                          0.804692
# 3                  0.090986                          0.796046
# 4                  0.135505                          0.866203
# ..                      ...                               ...
# 257                0.217396                          0.839154
# 258                0.077544                          0.877446
# 259                0.096154                          0.858128
# 260                0.362619                          0.898659
# 261                0.191705                          0.855502
#
#      result.genre_classical.recall  ...  result.accuracy.support  \
# 0                         0.861170  ...                    17080
# 1                         0.866351  ...                     4271
# 2                         0.723288  ...                    17080
# 3                         0.725118  ...                     4271
# 4                         0.766880  ...                    17080
# ..                             ...  ...                      ...
# 257                       0.865403  ...                     4271
# 258                       0.807392  ...                    17080
# 259                       0.825592  ...                     4271
# 260                       0.857143  ...                    17080
# 261                       0.847393  ...                     4271
#
#      result.accuracy.mcc  result.macro avg.precision  result.macro avg.recall  \
# 0               0.632108                    0.584578                 0.767051
# 1               0.566060                    0.512139                 0.623045
# 2               0.288502                    0.294794                 0.366546
# 3               0.291271                    0.299025                 0.363854
# 4               0.413770                    0.402289                 0.517018
# ..                   ...                         ...                      ...
# 257             0.516464                    0.472718                 0.580623
# 258             0.389238                    0.374711                 0.465066
# 259             0.389777                    0.375954                 0.461111
# 260             0.563905                    0.523249                 0.699207
# 261             0.493201                    0.458072                 0.583348
#
#      result.macro avg.f1-score  result.macro avg.support  \
# 0                     0.624253                     17080
# 1                     0.535070                      4271
# 2                     0.273231                     17080
# 3                     0.274398                      4271
# 4                     0.398427                     17080
# ..                         ...                       ...
# 257                   0.498463                      4271
# 258                   0.359808                     17080
# 259                   0.357853                      4271
# 260                   0.551646                     17080
# 261                   0.476193                      4271
#
#      result.weighted avg.precision  result.weighted avg.recall  \
# 0                         0.738068                    0.679274
# 1                         0.684052                    0.624912
# 2                         0.479416                    0.360363
# 3                         0.488991                    0.364083
# 4                         0.588666                    0.475878
# ..                             ...                         ...
# 257                       0.629545                    0.583938
# 258                       0.579781                    0.453103
# 259                       0.580991                    0.454226
# 260                       0.692970                    0.615749
# 261                       0.627500                    0.557247
#
#      result.weighted avg.f1-score  result.weighted avg.support
# 0                        0.684742                        17080
# 1                        0.635994                         4271
# 2                        0.371725                        17080
# 3                        0.378184                         4271
# 4                        0.488647                        17080
# ..                            ...                          ...
# 257                      0.587322                         4271
# 258                      0.466068                        17080
# 259                      0.465236                         4271
# 260                      0.620285                        17080
# 261                      0.564026                         4271
#
# [262 rows x 64 columns]

# %% [markdown]
# ## The pandas filter function makes it easily to isolate on fields of interest ....

# %%
df.filter(like="f1")
# Out:
#      result.genre_blues.f1-score  result.genre_classical.f1-score  \
# 0                       0.379679                         0.886369
# 1                       0.208556                         0.876739
# 2                       0.079895                         0.761822
# 3                       0.108696                         0.758929
# 4                       0.142947                         0.813521
# ..                           ...                              ...
# 257                     0.226027                         0.852077
# 258                     0.096070                         0.840962
# 259                     0.111675                         0.841546
# 260                     0.334922                         0.877410
# 261                     0.195402                         0.851429
#
#      result.genre_country.f1-score  result.genre_disco.f1-score  \
# 0                         0.465909                     0.493965
# 1                         0.310345                     0.352941
# 2                         0.140021                     0.125960
# 3                         0.143141                     0.112266
# 4                         0.226047                     0.203327
# ..                             ...                          ...
# 257                       0.436214                     0.310078
# 258                       0.207362                     0.191504
# 259                       0.197701                     0.187135
# 260                       0.445385                     0.374363
# 261                       0.388889                     0.281437
#
#      result.genre_hiphop.f1-score  result.genre_jazz.f1-score  \
# 0                        0.767115                    0.673889
# 1                        0.703196                    0.597325
# 2                        0.201450                    0.307891
# 3                        0.215289                    0.293742
# 4                        0.443059                    0.451524
# ..                            ...                         ...
# 257                      0.540894                    0.521858
# 258                      0.382768                    0.408469
# 259                      0.394161                    0.405612
# 260                      0.633497                    0.611878
# 261                      0.524941                    0.511379
#
#      result.genre_metal.f1-score  result.genre_pop.f1-score  \
# 0                       0.678409                   0.533571
# 1                       0.615385                   0.496716
# 2                       0.360821                   0.189831
# 3                       0.367089                   0.210134
# 4                       0.456550                   0.278879
# ..                           ...                        ...
# 257                     0.500000                   0.463680
# 258                     0.401153                   0.277069
# 259                     0.403909                   0.281958
# 260                     0.554156                   0.455672
# 261                     0.491159                   0.405909
#
#      result.genre_reggae.f1-score  result.genre_rock.f1-score  \
# 0                        0.712882                    0.650745
# 1                        0.577878                    0.611617
# 2                        0.232785                    0.331835
# 3                        0.185185                    0.349515
# 4                        0.490206                    0.478212
# ..                            ...                         ...
# 257                      0.576659                    0.557143
# 258                      0.370653                    0.422072
# 259                      0.343257                    0.411581
# 260                      0.652778                    0.576395
# 261                      0.574661                    0.536727
#
#      result.accuracy.f1-score  result.macro avg.f1-score  \
# 0                    0.679274                   0.624253
# 1                    0.624912                   0.535070
# 2                    0.360363                   0.273231
# 3                    0.364083                   0.274398
# 4                    0.475878                   0.398427
# ..                        ...                        ...
# 257                  0.583938                   0.498463
# 258                  0.453103                   0.359808
# 259                  0.454226                   0.357853
# 260                  0.615749                   0.551646
# 261                  0.557247                   0.476193
#
#      result.weighted avg.f1-score
# 0                        0.684742
# 1                        0.635994
# 2                        0.371725
# 3                        0.378184
# 4                        0.488647
# ..                            ...
# 257                      0.587322
# 258                      0.466068
# 259                      0.465236
# 260                      0.620285
# 261                      0.564026
#
# [262 rows x 13 columns]

# %%
df.filter(like="mcc")
# Out:
#      result.genre_blues.mcc  result.genre_classical.mcc  \
# 0                  0.418941                    0.851136
# 1                  0.211731                    0.837050
# 2                  0.057009                    0.690749
# 3                  0.090986                    0.685946
# 4                  0.135505                    0.759543
# ..                      ...                         ...
# 257                0.217396                    0.802723
# 258                0.077544                    0.792780
# 259                0.096154                    0.791148
# 260                0.362619                    0.838831
# 261                0.191705                    0.803014
#
#      result.genre_country.mcc  result.genre_disco.mcc  \
# 0                    0.514351                0.546762
# 1                    0.325062                0.376425
# 2                    0.152490                0.145195
# 3                    0.159796                0.124259
# 4                    0.263241                0.240954
# ..                        ...                     ...
# 257                  0.447107                0.328508
# 258                  0.231850                0.216834
# 259                  0.224454                0.205136
# 260                  0.483520                0.444382
# 261                  0.414460                0.322746
#
#      result.genre_hiphop.mcc  result.genre_jazz.mcc  result.genre_metal.mcc  \
# 0                   0.740925               0.649597                0.685000
# 1                   0.669680               0.565014                0.617252
# 2                   0.149292               0.247801                0.375137
# 3                   0.169574               0.231737                0.380346
# 4                   0.392544               0.406998                0.475479
# ..                       ...                    ...                     ...
# 257                 0.487645               0.484712                0.497448
# 258                 0.337597               0.360416                0.416191
# 259                 0.356988               0.357655                0.421391
# 260                 0.592335               0.583867                0.565131
# 261                 0.473024               0.473981                0.497757
#
#      result.genre_pop.mcc  result.genre_reggae.mcc  result.genre_rock.mcc  \
# 0                0.454770                 0.704654               0.593952
# 1                0.409441                 0.558898               0.540506
# 2                0.138600                 0.193974               0.248298
# 3                0.160577                 0.140383               0.266265
# 4                0.226691                 0.471743               0.395338
# ..                    ...                      ...                    ...
# 257              0.373245                 0.557067               0.479436
# 258              0.240435                 0.352175               0.339453
# 259              0.249390                 0.318877               0.330192
# 260              0.396208                 0.642202               0.509066
# 261              0.329370                 0.555389               0.459401
#
#      result.accuracy.mcc
# 0               0.632108
# 1               0.566060
# 2               0.288502
# 3               0.291271
# 4               0.413770
# ..                   ...
# 257             0.516464
# 258             0.389238
# 259             0.389777
# 260             0.563905
# 261             0.493201
#
# [262 rows x 11 columns]

# %%
df.filter(["model", "dataset", "mcc", "phase", "result.accuracy.f1-score"])
# Out:
#                   model                        dataset  phase  \
# 0    LogisticRegression             dataset_00_all_pca  train
# 1    LogisticRegression             dataset_00_all_pca   test
# 2    LogisticRegression            dataset_01_mean_pca  train
# 3    LogisticRegression            dataset_01_mean_pca   test
# 4    LogisticRegression        dataset_02_mean_cov_pca  train
# ..                  ...                            ...    ...
# 257                 SVC       dataset_07_pvtt_mean_cov   test
# 258                 SVC      dataset_08_pvtt_mean_icov  train
# 259                 SVC      dataset_08_pvtt_mean_icov   test
# 260                 SVC  dataset_09_pvtt_mean_cov_icov  train
# 261                 SVC  dataset_09_pvtt_mean_cov_icov   test
#
#      result.accuracy.f1-score
# 0                    0.679274
# 1                    0.624912
# 2                    0.360363
# 3                    0.364083
# 4                    0.475878
# ..                        ...
# 257                  0.583938
# 258                  0.453103
# 259                  0.454226
# 260                  0.615749
# 261                  0.557247
#
# [262 rows x 4 columns]

# %% [markdown]
# ## Here is a simple example where we look for the test run with the highest mcc score.

# %%
test_df = df[df.phase == "test"]
test_df.loc[test_df["result.accuracy.f1-score"].idxmax()]
# Out:
# model                                       SVC
# dataset                          dataset_00_all
# phase                                      test
# result.genre_blues.precision           0.298611
# result.genre_blues.recall              0.457447
#                                       ...
# result.macro avg.support                   4271
# result.weighted avg.precision          0.702098
# result.weighted avg.recall             0.694217
# result.weighted avg.f1-score           0.692454
# result.weighted avg.support                4271
# Name: 243, Length: 64, dtype: object

# %% [markdown]
# ## We can split the dataframe into train and test data frames and create a merged dataframe where each row represents one complete experiment, i.e., we combine the train data and the test data.

# %%
train_df = df[df.phase == "train"]
test_df = df[df.phase == "test"]
experiment_df = pd.merge(
    train_df,
    test_df,
    suffixes=["_train", "_test"],
    how="left",
    left_on=["model", "dataset"],
    right_on=["model", "dataset"],
)

# %%
train_df
# Out:
#                   model                        dataset  phase  \
# 0    LogisticRegression             dataset_00_all_pca  train
# 2    LogisticRegression            dataset_01_mean_pca  train
# 4    LogisticRegression        dataset_02_mean_cov_pca  train
# 6    LogisticRegression       dataset_03_mean_icov_pca  train
# 8    LogisticRegression   dataset_04_mean_cov_icov_pca  train
# ..                  ...                            ...    ...
# 252                 SVC                dataset_05_pvtt  train
# 254                 SVC           dataset_06_pvtt_mean  train
# 256                 SVC       dataset_07_pvtt_mean_cov  train
# 258                 SVC      dataset_08_pvtt_mean_icov  train
# 260                 SVC  dataset_09_pvtt_mean_cov_icov  train
#
#      result.genre_blues.precision  result.genre_blues.recall  \
# 0                        0.253119                   0.759358
# 2                        0.052905                   0.163102
# 4                        0.093366                   0.304813
# 6                        0.038511                   0.080214
# 8                        0.087449                   0.288770
# ..                            ...                        ...
# 252                      0.071813                   0.106952
# 254                      0.174854                   0.561497
# 256                      0.335973                   0.794118
# 258                      0.062653                   0.205882
# 260                      0.224658                   0.657754
#
#      result.genre_blues.f1-score  result.genre_blues.support  \
# 0                       0.379679                         374
# 2                       0.079895                         374
# 4                       0.142947                         374
# 6                       0.052038                         374
# 8                       0.134245                         374
# ..                           ...                         ...
# 252                     0.085929                         374
# 254                     0.266667                         374
# 256                     0.472178                         374
# 258                     0.096070                         374
# 260                     0.334922                         374
#
#      result.genre_blues.mcc  result.genre_classical.precision  \
# 0                  0.418941                          0.913087
# 2                  0.057009                          0.804692
# 4                  0.135505                          0.866203
# 6                  0.024817                          0.644099
# 8                  0.125052                          0.865537
# ..                      ...                               ...
# 252                0.062624                          0.872914
# 254                0.287439                          0.889610
# 256                0.501387                          0.901762
# 258                0.077544                          0.877446
# 260                0.362619                          0.898659
#
#      result.genre_classical.recall  ...  result.accuracy.support  \
# 0                         0.861170  ...                    17080
# 2                         0.723288  ...                    17080
# 4                         0.766880  ...                    17080
# 6                         0.667140  ...                    17080
# 8                         0.750296  ...                    17080
# ..                             ...  ...                      ...
# 252                       0.805496  ...                    17080
# 254                       0.843876  ...                    17080
# 256                       0.885098  ...                    17080
# 258                       0.807392  ...                    17080
# 260                       0.857143  ...                    17080
#
#      result.accuracy.mcc  result.macro avg.precision  result.macro avg.recall  \
# 0               0.632108                    0.584578                 0.767051
# 2               0.288502                    0.294794                 0.366546
# 4               0.413770                    0.402289                 0.517018
# 6               0.177319                    0.189993                 0.218183
# 8               0.401213                    0.394086                 0.505038
# ..                   ...                         ...                      ...
# 252             0.356004                    0.339103                 0.432926
# 254             0.485472                    0.452905                 0.601516
# 256             0.640362                    0.592145                 0.779301
# 258             0.389238                    0.374711                 0.465066
# 260             0.563905                    0.523249                 0.699207
#
#      result.macro avg.f1-score  result.macro avg.support  \
# 0                     0.624253                     17080
# 2                     0.273231                     17080
# 4                     0.398427                     17080
# 6                     0.160623                     17080
# 8                     0.387598                     17080
# ..                         ...                       ...
# 252                   0.324697                     17080
# 254                   0.467309                     17080
# 256                   0.638352                     17080
# 258                   0.359808                     17080
# 260                   0.551646                     17080
#
#      result.weighted avg.precision  result.weighted avg.recall  \
# 0                         0.738068                    0.679274
# 2                         0.479416                    0.360363
# 4                         0.588666                    0.475878
# 6                         0.333805                    0.264871
# 8                         0.581905                    0.463993
# ..                             ...                         ...
# 252                       0.535577                    0.420199
# 254                       0.637622                    0.544555
# 256                       0.736708                    0.687002
# 258                       0.579781                    0.453103
# 260                       0.692970                    0.615749
#
#      result.weighted avg.f1-score  result.weighted avg.support
# 0                        0.684742                        17080
# 2                        0.371725                        17080
# 4                        0.488647                        17080
# 6                        0.260686                        17080
# 8                        0.478351                        17080
# ..                            ...                          ...
# 252                      0.421872                        17080
# 254                      0.552313                        17080
# 256                      0.686476                        17080
# 258                      0.466068                        17080
# 260                      0.620285                        17080
#
# [131 rows x 64 columns]

# %%
test_df
# Out:
#                   model                        dataset phase  \
# 1    LogisticRegression             dataset_00_all_pca  test
# 3    LogisticRegression            dataset_01_mean_pca  test
# 5    LogisticRegression        dataset_02_mean_cov_pca  test
# 7    LogisticRegression       dataset_03_mean_icov_pca  test
# 9    LogisticRegression   dataset_04_mean_cov_icov_pca  test
# ..                  ...                            ...   ...
# 253                 SVC                dataset_05_pvtt  test
# 255                 SVC           dataset_06_pvtt_mean  test
# 257                 SVC       dataset_07_pvtt_mean_cov  test
# 259                 SVC      dataset_08_pvtt_mean_icov  test
# 261                 SVC  dataset_09_pvtt_mean_cov_icov  test
#
#      result.genre_blues.precision  result.genre_blues.recall  \
# 1                        0.139286                   0.414894
# 3                        0.072993                   0.212766
# 5                        0.101504                   0.287234
# 7                        0.036269                   0.074468
# 9                        0.095941                   0.276596
# ..                            ...                        ...
# 253                      0.027778                   0.042553
# 255                      0.082090                   0.234043
# 257                      0.166667                   0.351064
# 259                      0.073333                   0.234043
# 261                      0.133858                   0.361702
#
#      result.genre_blues.f1-score  result.genre_blues.support  \
# 1                       0.208556                          94
# 3                       0.108696                          94
# 5                       0.150000                          94
# 7                       0.048780                          94
# 9                       0.142466                          94
# ..                           ...                         ...
# 253                     0.033613                          94
# 255                     0.121547                          94
# 257                     0.226027                          94
# 259                     0.111675                          94
# 261                     0.195402                          94
#
#      result.genre_blues.mcc  result.genre_classical.precision  \
# 1                  0.211731                          0.887379
# 3                  0.090986                          0.796046
# 5                  0.139641                          0.866528
# 7                  0.021146                          0.642030
# 9                  0.131166                          0.862395
# ..                      ...                               ...
# 253                0.007345                          0.856436
# 255                0.105960                          0.851224
# 257                0.217396                          0.839154
# 259                0.096154                          0.858128
# 261                0.191705                          0.855502
#
#      result.genre_classical.recall  ...  result.accuracy.support  \
# 1                         0.866351  ...                     4271
# 3                         0.725118  ...                     4271
# 5                         0.787678  ...                     4271
# 7                         0.683412  ...                     4271
# 9                         0.778199  ...                     4271
# ..                             ...  ...                      ...
# 253                       0.819905  ...                     4271
# 255                       0.856872  ...                     4271
# 257                       0.865403  ...                     4271
# 259                       0.825592  ...                     4271
# 261                       0.847393  ...                     4271
#
#      result.accuracy.mcc  result.macro avg.precision  result.macro avg.recall  \
# 1               0.566060                    0.512139                 0.623045
# 3               0.291271                    0.299025                 0.363854
# 5               0.415753                    0.400663                 0.512792
# 7               0.173747                    0.185527                 0.201216
# 9               0.412254                    0.398318                 0.503159
# ..                   ...                         ...                      ...
# 253             0.349325                    0.331535                 0.421373
# 255             0.453567                    0.417269                 0.523274
# 257             0.516464                    0.472718                 0.580623
# 259             0.389777                    0.375954                 0.461111
# 261             0.493201                    0.458072                 0.583348
#
#      result.macro avg.f1-score  result.macro avg.support  \
# 1                     0.535070                      4271
# 3                     0.274398                      4271
# 5                     0.395357                      4271
# 7                     0.153473                      4271
# 9                     0.391096                      4271
# ..                         ...                       ...
# 253                   0.316306                      4271
# 255                   0.423193                      4271
# 257                   0.498463                      4271
# 259                   0.357853                      4271
# 261                   0.476193                      4271
#
#      result.weighted avg.precision  result.weighted avg.recall  \
# 1                         0.684052                    0.624912
# 3                         0.488991                    0.364083
# 5                         0.590083                    0.478576
# 7                         0.338274                    0.261531
# 9                         0.592814                    0.476235
# ..                             ...                         ...
# 253                       0.528770                    0.415359
# 255                       0.608317                    0.519550
# 257                       0.629545                    0.583938
# 259                       0.580991                    0.454226
# 261                       0.627500                    0.557247
#
#      result.weighted avg.f1-score  result.weighted avg.support
# 1                        0.635994                         4271
# 3                        0.378184                         4271
# 5                        0.489426                         4271
# 7                        0.257708                         4271
# 9                        0.490694                         4271
# ..                            ...                          ...
# 253                      0.415748                         4271
# 255                      0.529183                         4271
# 257                      0.587322                         4271
# 259                      0.465236                         4271
# 261                      0.564026                         4271
#
# [131 rows x 64 columns]

# %%
experiment_df
# Out:
#                   model                        dataset phase_train  \
# 0    LogisticRegression             dataset_00_all_pca       train
# 1    LogisticRegression            dataset_01_mean_pca       train
# 2    LogisticRegression        dataset_02_mean_cov_pca       train
# 3    LogisticRegression       dataset_03_mean_icov_pca       train
# 4    LogisticRegression   dataset_04_mean_cov_icov_pca       train
# ..                  ...                            ...         ...
# 126                 SVC                dataset_05_pvtt       train
# 127                 SVC           dataset_06_pvtt_mean       train
# 128                 SVC       dataset_07_pvtt_mean_cov       train
# 129                 SVC      dataset_08_pvtt_mean_icov       train
# 130                 SVC  dataset_09_pvtt_mean_cov_icov       train
#
#      result.genre_blues.precision_train  result.genre_blues.recall_train  \
# 0                              0.253119                         0.759358
# 1                              0.052905                         0.163102
# 2                              0.093366                         0.304813
# 3                              0.038511                         0.080214
# 4                              0.087449                         0.288770
# ..                                  ...                              ...
# 126                            0.071813                         0.106952
# 127                            0.174854                         0.561497
# 128                            0.335973                         0.794118
# 129                            0.062653                         0.205882
# 130                            0.224658                         0.657754
#
#      result.genre_blues.f1-score_train  result.genre_blues.support_train  \
# 0                             0.379679                               374
# 1                             0.079895                               374
# 2                             0.142947                               374
# 3                             0.052038                               374
# 4                             0.134245                               374
# ..                                 ...                               ...
# 126                           0.085929                               374
# 127                           0.266667                               374
# 128                           0.472178                               374
# 129                           0.096070                               374
# 130                           0.334922                               374
#
#      result.genre_blues.mcc_train  result.genre_classical.precision_train  \
# 0                        0.418941                                0.913087
# 1                        0.057009                                0.804692
# 2                        0.135505                                0.866203
# 3                        0.024817                                0.644099
# 4                        0.125052                                0.865537
# ..                            ...                                     ...
# 126                      0.062624                                0.872914
# 127                      0.287439                                0.889610
# 128                      0.501387                                0.901762
# 129                      0.077544                                0.877446
# 130                      0.362619                                0.898659
#
#      result.genre_classical.recall_train  ...  result.accuracy.support_test  \
# 0                               0.861170  ...                          4271
# 1                               0.723288  ...                          4271
# 2                               0.766880  ...                          4271
# 3                               0.667140  ...                          4271
# 4                               0.750296  ...                          4271
# ..                                   ...  ...                           ...
# 126                             0.805496  ...                          4271
# 127                             0.843876  ...                          4271
# 128                             0.885098  ...                          4271
# 129                             0.807392  ...                          4271
# 130                             0.857143  ...                          4271
#
#      result.accuracy.mcc_test  result.macro avg.precision_test  \
# 0                    0.566060                         0.512139
# 1                    0.291271                         0.299025
# 2                    0.415753                         0.400663
# 3                    0.173747                         0.185527
# 4                    0.412254                         0.398318
# ..                        ...                              ...
# 126                  0.349325                         0.331535
# 127                  0.453567                         0.417269
# 128                  0.516464                         0.472718
# 129                  0.389777                         0.375954
# 130                  0.493201                         0.458072
#
#      result.macro avg.recall_test  result.macro avg.f1-score_test  \
# 0                        0.623045                        0.535070
# 1                        0.363854                        0.274398
# 2                        0.512792                        0.395357
# 3                        0.201216                        0.153473
# 4                        0.503159                        0.391096
# ..                            ...                             ...
# 126                      0.421373                        0.316306
# 127                      0.523274                        0.423193
# 128                      0.580623                        0.498463
# 129                      0.461111                        0.357853
# 130                      0.583348                        0.476193
#
#      result.macro avg.support_test  result.weighted avg.precision_test  \
# 0                             4271                            0.684052
# 1                             4271                            0.488991
# 2                             4271                            0.590083
# 3                             4271                            0.338274
# 4                             4271                            0.592814
# ..                             ...                                 ...
# 126                           4271                            0.528770
# 127                           4271                            0.608317
# 128                           4271                            0.629545
# 129                           4271                            0.580991
# 130                           4271                            0.627500
#
#      result.weighted avg.recall_test  result.weighted avg.f1-score_test  \
# 0                           0.624912                           0.635994
# 1                           0.364083                           0.378184
# 2                           0.478576                           0.489426
# 3                           0.261531                           0.257708
# 4                           0.476235                           0.490694
# ..                               ...                                ...
# 126                         0.415359                           0.415748
# 127                         0.519550                           0.529183
# 128                         0.583938                           0.587322
# 129                         0.454226                           0.465236
# 130                         0.557247                           0.564026
#
#      result.weighted avg.support_test
# 0                                4271
# 1                                4271
# 2                                4271
# 3                                4271
# 4                                4271
# ..                                ...
# 126                              4271
# 127                              4271
# 128                              4271
# 129                              4271
# 130                              4271
#
# [131 rows x 126 columns]

# %% [markdown]
# ## Let's look at the difference in mcc between test and train. . .

# %%
df = experiment_df.filter(regex="model|dataset|result.accuracy.mcc").copy()
df["mcc_difference"] = (
    df["result.accuracy.mcc_train"] - df["result.accuracy.mcc_test"]
)
df.sort_values(by=["mcc_difference"])[0:25]
# Out:
#                   model                                   dataset  \
# 4    LogisticRegression              dataset_04_mean_cov_icov_pca
# 6    LogisticRegression                  dataset_06_pvtt_mean_pca
# 100  LogisticRegression                           dataset_01_mean
# 5    LogisticRegression                       dataset_05_pvtt_pca
# 77               KMeans                        dataset_00_all_pca
# 9    LogisticRegression         dataset_09_pvtt_mean_cov_icov_pca
# 84               KMeans              dataset_07_pvtt_mean_cov_pca
# 94      GaussianMixture                  dataset_06_pvtt_mean_pca
# 102  LogisticRegression                      dataset_03_mean_icov
# 87               KMeans  dataset_10_melspectrograms_flattened_pca
# 83               KMeans                  dataset_06_pvtt_mean_pca
# 107  LogisticRegression                 dataset_08_pvtt_mean_icov
# 1    LogisticRegression                       dataset_01_mean_pca
# 82               KMeans                       dataset_05_pvtt_pca
# 105  LogisticRegression                      dataset_06_pvtt_mean
# 30                  SVC             dataset_08_pvtt_mean_icov_pca
# 2    LogisticRegression                   dataset_02_mean_cov_pca
# 86               KMeans         dataset_09_pvtt_mean_cov_icov_pca
# 79               KMeans                   dataset_02_mean_cov_pca
# 27                  SVC                       dataset_05_pvtt_pca
# 124                 SVC                      dataset_03_mean_icov
# 97      GaussianMixture         dataset_09_pvtt_mean_cov_icov_pca
# 92      GaussianMixture              dataset_04_mean_cov_icov_pca
# 129                 SVC                 dataset_08_pvtt_mean_icov
# 91      GaussianMixture                  dataset_03_mean_icov_pca
#
#      result.accuracy.mcc_train  result.accuracy.mcc_test  mcc_difference
# 4                     0.401213                  0.412254       -0.011041
# 6                     0.342112                  0.352430       -0.010317
# 100                   0.310252                  0.317897       -0.007645
# 5                     0.287338                  0.294291       -0.006953
# 77                    0.069918                  0.076663       -0.006745
# 9                     0.419372                  0.425790       -0.006418
# 84                   -0.044524                 -0.038631       -0.005893
# 94                   -0.036374                 -0.032052       -0.004322
# 102                   0.316356                  0.320440       -0.004083
# 87                   -0.030955                 -0.026872       -0.004083
# 83                    0.009948                  0.013876       -0.003927
# 107                   0.397282                  0.400981       -0.003699
# 1                     0.288502                  0.291271       -0.002769
# 82                   -0.006821                 -0.004234       -0.002587
# 105                   0.393908                  0.396381       -0.002473
# 30                    0.290088                  0.292095       -0.002006
# 2                     0.413770                  0.415753       -0.001983
# 86                    0.144633                  0.146570       -0.001937
# 79                    0.022691                  0.024177       -0.001486
# 27                    0.308137                  0.309417       -0.001280
# 124                   0.324195                  0.325426       -0.001230
# 97                   -0.000176                  0.000698       -0.000874
# 92                   -0.033859                 -0.033247       -0.000613
# 129                   0.389238                  0.389777       -0.000539
# 91                   -0.000162                 -0.000061       -0.000101
