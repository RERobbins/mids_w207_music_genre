# %%
import sys

import numpy as np
import pandas as pd

sys.path.append("../../")

from helpers.reduce import load_and_distill
from helpers.split import tag_label_feature_split

# %%
df = load_and_distill(multi_label=False, tags=True)
tags, labels, features = tag_label_feature_split(df)

# %%
df.shape
# Out:
# (21351, 2792)

# %%
tags.columns
# Out:
# Index(['tags_file_name', 'tags_encoding', 'tags_artist', 'tags_date',
#        'tags_title', 'tags_album', 'tags_tracknumber', 'tags_bpm',
#        'tags_composer', 'tags_copyright', 'tags_genre', 'tags_encodedby',
#        'tags_tracktotal', 'tags_artistsort', 'tags_musicbrainz_albumartistid',
#        'tags_musicbrainz_albumid', 'tags_musicbrainz_artistid',
#        'tags_musicbrainz_trackid', 'tags_license', 'tags_albumartist',
#        'tags_discnumber', 'tags_conductor', 'tags_length', 'tags_label',
#        'tags_musicbrainz_discid', 'tags_totaltracks', 'tags_disctotal',
#        'tags_totaldiscs', 'tags_contentgroup', 'tags_taggingdate',
#        'tags_engineer', 'tags_originalartist', 'tags_initialkey',
#        'tags_originaldate', 'tags_originalfilename', 'tags_isrc',
#        'tags_website', 'tags_lyricist', 'tags_albumartistsort'],
#       dtype='object')

# %%
labels.columns
# Out:
# Index(['genre_blues', 'genre_classical', 'genre_country', 'genre_disco',
#        'genre_hiphop', 'genre_jazz', 'genre_metal', 'genre_pop',
#        'genre_reggae', 'genre_rock'],
#       dtype='object')

# %%
features.columns
# Out:
# Index(['lowlevel_average_loudness', 'barkbands_crest_dmean',
#        'barkbands_crest_dmean2', 'barkbands_crest_dvar',
#        'barkbands_crest_dvar2', 'barkbands_crest_max', 'barkbands_crest_mean',
#        'barkbands_crest_median', 'barkbands_crest_min', 'barkbands_crest_var',
#        ...
#        'mfcc_icov_12_8', 'mfcc_icov_12_9', 'mfcc_icov_12_10',
#        'mfcc_icov_12_11', 'mfcc_icov_12_12', 'metadata_track_id',
#        'metadata_artist_id', 'metadata_album_id', 'metadata_path',
#        'metadata_duration'],
#       dtype='object', length=2743)

# %%
tags
# Out:
#       tags_file_name    tags_encoding tags_artist tags_date tags_title  \
# 2        1324898.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# 6        1415798.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# 7         283598.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# 10       1149698.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# 12        285898.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# ...              ...              ...         ...       ...        ...
# 55202      16554.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# 55204      17954.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# 55205      19854.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# 55208      24854.mp3  [Lavf58.20.100]         NaN       NaN        NaN
# 55212      34854.mp3  [Lavf58.20.100]         NaN       NaN        NaN
#
#       tags_album tags_tracknumber tags_bpm tags_composer tags_copyright  ...  \
# 2            NaN              NaN      NaN           NaN            NaN  ...
# 6            NaN              NaN      NaN           NaN            NaN  ...
# 7            NaN              NaN      NaN           NaN            NaN  ...
# 10           NaN              NaN      NaN           NaN            NaN  ...
# 12           NaN              NaN      NaN           NaN            NaN  ...
# ...          ...              ...      ...           ...            ...  ...
# 55202        NaN              NaN      NaN           NaN            NaN  ...
# 55204        NaN              NaN      NaN           NaN            NaN  ...
# 55205        NaN              NaN      NaN           NaN            NaN  ...
# 55208        NaN              NaN      NaN           NaN            NaN  ...
# 55212        NaN              NaN      NaN           NaN            NaN  ...
#
#       tags_taggingdate tags_engineer tags_originalartist tags_initialkey  \
# 2                  NaN           NaN                 NaN             NaN
# 6                  NaN           NaN                 NaN             NaN
# 7                  NaN           NaN                 NaN             NaN
# 10                 NaN           NaN                 NaN             NaN
# 12                 NaN           NaN                 NaN             NaN
# ...                ...           ...                 ...             ...
# 55202              NaN           NaN                 NaN             NaN
# 55204              NaN           NaN                 NaN             NaN
# 55205              NaN           NaN                 NaN             NaN
# 55208              NaN           NaN                 NaN             NaN
# 55212              NaN           NaN                 NaN             NaN
#
#       tags_originaldate tags_originalfilename tags_isrc tags_website  \
# 2                   NaN                   NaN       NaN          NaN
# 6                   NaN                   NaN       NaN          NaN
# 7                   NaN                   NaN       NaN          NaN
# 10                  NaN                   NaN       NaN          NaN
# 12                  NaN                   NaN       NaN          NaN
# ...                 ...                   ...       ...          ...
# 55202               NaN                   NaN       NaN          NaN
# 55204               NaN                   NaN       NaN          NaN
# 55205               NaN                   NaN       NaN          NaN
# 55208               NaN                   NaN       NaN          NaN
# 55212               NaN                   NaN       NaN          NaN
#
#       tags_lyricist tags_albumartistsort
# 2               NaN                  NaN
# 6               NaN                  NaN
# 7               NaN                  NaN
# 10              NaN                  NaN
# 12              NaN                  NaN
# ...             ...                  ...
# 55202           NaN                  NaN
# 55204           NaN                  NaN
# 55205           NaN                  NaN
# 55208           NaN                  NaN
# 55212           NaN                  NaN
#
# [21351 rows x 39 columns]

# %%
labels
# Out:
#        genre_blues  genre_classical  genre_country  genre_disco  genre_hiphop  \
# 2                0                0              0            0             0
# 6                0                0              0            0             0
# 7                0                0              0            0             0
# 10               0                0              0            0             0
# 12               0                1              0            0             0
# ...            ...              ...            ...          ...           ...
# 55202            0                0              0            0             0
# 55204            0                0              0            0             0
# 55205            0                0              0            0             0
# 55208            0                0              0            0             0
# 55212            0                0              0            0             0
#
#        genre_jazz  genre_metal  genre_pop  genre_reggae  genre_rock
# 2               0            0          1             0           0
# 6               0            0          0             0           1
# 7               0            0          1             0           0
# 10              0            0          0             0           1
# 12              0            0          0             0           0
# ...           ...          ...        ...           ...         ...
# 55202           0            0          1             0           0
# 55204           1            0          0             0           0
# 55205           1            0          0             0           0
# 55208           0            0          1             0           0
# 55212           1            0          0             0           0
#
# [21351 rows x 10 columns]

# %%
features
# Out:
#        lowlevel_average_loudness  barkbands_crest_dmean  \
# 2                       0.887838               2.184494
# 6                       0.895204               2.627000
# 7                       0.831109               2.751823
# 10                      0.930873               2.174903
# 12                      0.053346               2.563277
# ...                          ...                    ...
# 55202                   0.956139               1.951989
# 55204                   0.683563               2.990261
# 55205                   0.985355               2.326595
# 55208                   0.883289               1.834368
# 55212                   0.153367               2.351942
#
#        barkbands_crest_dmean2  barkbands_crest_dvar  barkbands_crest_dvar2  \
# 2                    3.610394              6.883740              18.208929
# 6                    4.032068              7.393273              16.594744
# 7                    4.493041              6.612402              16.899881
# 10                   3.433755              5.320028              12.670205
# 12                   4.033148              5.582881              14.306989
# ...                       ...                   ...                    ...
# 55202                3.227405              4.127434              10.812055
# 55204                4.973727              7.534144              18.860088
# 55205                3.671642              6.888914              15.255389
# 55208                3.047448              4.022786              10.589743
# 55212                3.743695              5.111189              12.485005
#
#        barkbands_crest_max  barkbands_crest_mean  barkbands_crest_median  \
# 2                25.042086             10.551719                9.812689
# 6                26.676840             12.006703               10.912039
# 7                26.058989             12.897467               12.871790
# 10               25.756266              9.589929                8.754687
# 12               25.571470             12.786343               12.136279
# ...                    ...                   ...                     ...
# 55202            25.086205              8.933297                8.283859
# 55204            26.503471             11.118818               10.366429
# 55205            25.606565             13.010802               12.432826
# 55208            26.215147             14.509040               14.098436
# 55212            26.245548             11.644878               10.461223
#
#        barkbands_crest_min  barkbands_crest_var  ...  mfcc_icov_12_8  \
# 2                 3.497549            15.491973  ...        0.002265
# 6                 2.413713            30.479668  ...       -0.000359
# 7                 2.864801            17.590498  ...        0.001522
# 10                2.215126            16.154224  ...        0.000763
# 12                3.415840            22.549368  ...        0.000801
# ...                    ...                  ...  ...             ...
# 55202             2.633312            10.762274  ...        0.002077
# 55204             2.100852            20.419930  ...       -0.001775
# 55205             2.537280            17.660580  ...       -0.000037
# 55208             5.116832            18.111525  ...        0.005900
# 55212             2.530016            24.947344  ...        0.003915
#
#        mfcc_icov_12_9  mfcc_icov_12_10  mfcc_icov_12_11  mfcc_icov_12_12  \
# 2           -0.003535         0.000239        -0.008985         0.015440
# 6           -0.000694        -0.000744        -0.003137         0.010271
# 7           -0.001909         0.007664        -0.014271         0.016835
# 10           0.000251        -0.000793        -0.003479         0.014913
# 12           0.000260         0.003242        -0.004188         0.008780
# ...               ...              ...              ...              ...
# 55202       -0.001189         0.002188        -0.004941         0.013427
# 55204        0.000497         0.003126        -0.006707         0.015355
# 55205       -0.002244         0.015353        -0.007607         0.020874
# 55208       -0.005142         0.010031        -0.009525         0.012990
# 55212       -0.001777         0.003381        -0.005818         0.011666
#
#        metadata_track_id  metadata_artist_id  metadata_album_id  \
# 2          track_1324898       artist_366162       album_156908
# 6          track_1415798       artist_005987       album_165278
# 7          track_0283598       artist_008236       album_039593
# 10         track_1149698       artist_369146       album_137873
# 12         track_0285898       artist_003586       album_040850
# ...                  ...                 ...                ...
# 55202      track_0016554       artist_002443       album_002351
# 55204      track_0017954       artist_002278       album_002534
# 55205      track_0019854       artist_001262       album_002789
# 55208      track_0024854       artist_003737       album_003428
# 55212      track_0034854       artist_003031       album_004262
#
#         metadata_path  metadata_duration
# 2      98/1324898.mp3              163.1
# 6      98/1415798.mp3              279.6
# 7       98/283598.mp3              191.7
# 10     98/1149698.mp3              191.7
# 12      98/285898.mp3              265.5
# ...               ...                ...
# 55202    54/16554.mp3              275.6
# 55204    54/17954.mp3              414.8
# 55205    54/19854.mp3               37.9
# 55208    54/24854.mp3              206.8
# 55212    54/34854.mp3              198.3
#
# [21351 rows x 2743 columns]
