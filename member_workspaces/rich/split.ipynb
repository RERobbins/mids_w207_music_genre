# %%
import sys

import numpy as np
import pandas as pd

sys.path.append("../../")

from helpers.split import tag_label_feature_split

# %%
df = pd.read_pickle("../../datasets/baseline_dataset.pickle")
tags, labels, features = tag_label_feature_split(df)

# %%
df.shape
# Out:
# (21351, 23)

# %%
labels.columns
# Out:
# Index(['genre_blues', 'genre_classical', 'genre_country', 'genre_disco',
#        'genre_hiphop', 'genre_jazz', 'genre_metal', 'genre_pop',
#        'genre_reggae', 'genre_rock'],
#       dtype='object')

# %%
features.columns
# Out:
# Index(['mfcc_mean_0', 'mfcc_mean_1', 'mfcc_mean_2', 'mfcc_mean_3',
#        'mfcc_mean_4', 'mfcc_mean_5', 'mfcc_mean_6', 'mfcc_mean_7',
#        'mfcc_mean_8', 'mfcc_mean_9', 'mfcc_mean_10', 'mfcc_mean_11',
#        'mfcc_mean_12'],
#       dtype='object')

# %%
labels
# Out:
#        genre_blues  genre_classical  genre_country  genre_disco  genre_hiphop  \
# 2                0                0              0            0             0
# 6                0                0              0            0             0
# 7                0                0              0            0             0
# 10               0                0              0            0             0
# 12               0                1              0            0             0
# ...            ...              ...            ...          ...           ...
# 55202            0                0              0            0             0
# 55204            0                0              0            0             0
# 55205            0                0              0            0             0
# 55208            0                0              0            0             0
# 55212            0                0              0            0             0
#
# ...

# %%
features
# Out:
#        mfcc_mean_0  mfcc_mean_1  mfcc_mean_2  mfcc_mean_3  mfcc_mean_4  \
# 2      -707.518066   172.924515    -9.369545     3.948954     1.980628
# 6      -679.308899   113.101357   -11.290030    27.696062    -7.500221
# 7      -644.655396    92.231018    51.315403    39.117119    13.334866
# 10     -638.950195   116.760223   -12.944778    29.781858     2.505325
# 12     -727.369507   161.314056   -28.047831    16.271910     5.778194
# ...            ...          ...          ...          ...          ...
# 55202  -663.076965   119.231514    26.110373    35.280354    11.771117
# 55204  -704.559509   137.016068    21.475670    34.512798     3.327875
# 55205  -691.049377   179.724976    25.448507    28.137154    19.806662
# 55208  -831.944580   215.028198    73.213364    23.283628    11.257351
# 55212  -777.413818   168.717896   -48.489017    24.383230   -13.587192
#
#        mfcc_mean_5  mfcc_mean_6  mfcc_mean_7  mfcc_mean_8  mfcc_mean_9  \
# ...
