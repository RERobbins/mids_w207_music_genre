# %%
import json
import pandas as pd

# %%
filename="../rich/bayesian_optimization_aws_gpu_logs.json"

# %%
with open (filename, "r") as infile:
    json_list = [json.loads(line) for line in infile]
df=pd.json_normalize(json_list)

# %% [markdown]
# **Current best mcc, f1_macro and accuracy results, respectively.**

# %%
best_mcc_f1_accuracy_indices = [df['matthews_corrcoef'].idxmax(),
                                df['f1_macro'].idxmax(),
                                df['accuracy'].idxmax()]
df.iloc[best_mcc_f1_accuracy_indices][['model', 'dataset', 'scaled', 'pca_components', 
                                       'resampling', 'matthews_corrcoef', 'f1_macro', 'accuracy']]
# Out:
#                  model                 dataset scaled  pca_components  \
# 38   XGBoostClassifier  dataset_01_mean.pickle     no             0.0
# 524  XGBoostClassifier  dataset_01_mean.pickle    yes             0.0
# 38   XGBoostClassifier  dataset_01_mean.pickle     no             0.0
#
#     resampling  matthews_corrcoef  f1_macro  accuracy
# 38        none           0.446103  0.363238  0.556733
# 524      SMOTE           0.422323  0.397869  0.517096
# 38        none           0.446103  0.363238  0.556733

# %% [markdown]
# **Detailed summary of current best mcc result.**

# %%
df.iloc[best_mcc_f1_accuracy_indices[0]]
# Out:
# model                     XGBoostClassifier
# dataset              dataset_01_mean.pickle
# timestamp                        1657984817
# scaled                                   no
# pca_components                          0.0
# resampling                             none
# learning_rate                      0.018609
# n_estimators                            434
# max_depth                                 8
# gamma                              0.286576
# reg_alpha                          0.522064
# seed                                   1962
# fit_tim                          517.099315
# core_tim                           0.213337
# matthews_corrcoef                  0.446103
# f1_macro                           0.363238
# accuracy                           0.556733
# Name: 38, dtype: object

# %% [markdown]
# **Number of trials logged.**

# %%
df.shape[0]
# Out:
# 880

# %% [markdown]
# **Group results by timestamp, resampling and pca_components, then show current best mcc by group.**

# %%
indices_for_best_mcc = df.groupby(['timestamp', 'resampling', 'pca_components', 'scaled'])['matthews_corrcoef'].idxmax()
df.iloc[indices_for_best_mcc][
    ['model', 'dataset', 'scaled', 'pca_components', 'resampling', 'matthews_corrcoef', 'f1_macro', 'accuracy']
]
# Out:
#                  model                 dataset scaled  pca_components  \
# 84   XGBoostClassifier  dataset_01_mean.pickle     no            0.00
# 524  XGBoostClassifier  dataset_01_mean.pickle    yes            0.00
# 327  XGBoostClassifier  dataset_01_mean.pickle     no            0.95
# 750  XGBoostClassifier  dataset_01_mean.pickle    yes            0.95
# 152  XGBoostClassifier  dataset_01_mean.pickle     no            0.00
# 591  XGBoostClassifier  dataset_01_mean.pickle    yes            0.00
# 378  XGBoostClassifier  dataset_01_mean.pickle     no            0.95
# 811  XGBoostClassifier  dataset_01_mean.pickle    yes            0.95
# 203  XGBoostClassifier  dataset_01_mean.pickle     no            0.00
# 643  XGBoostClassifier  dataset_01_mean.pickle    yes            0.00
# 438  XGBoostClassifier  dataset_01_mean.pickle     no            0.95
# 878  XGBoostClassifier  dataset_01_mean.pickle    yes            0.95
# 38   XGBoostClassifier  dataset_01_mean.pickle     no            0.00
# 478  XGBoostClassifier  dataset_01_mean.pickle    yes            0.00
# 273  XGBoostClassifier  dataset_01_mean.pickle     no            0.95
# 713  XGBoostClassifier  dataset_01_mean.pickle    yes            0.95
#
#      resampling  matthews_corrcoef  f1_macro  accuracy
# 84        SMOTE           0.417633  0.391702  0.512646
# 524       SMOTE           0.422323  0.397869  0.517096
# 327       SMOTE           0.296870  0.273581  0.380386
# 750       SMOTE           0.396496  0.371039  0.495785
# 152    SMOTEENN           0.360060  0.335622  0.428981
# 591    SMOTEENN           0.379060  0.352207  0.450468
# 378    SMOTEENN           0.266744  0.248552  0.338993
# 811    SMOTEENN           0.343730  0.321648  0.411944
# 203  SMOTETOMEK           0.446103  0.363238  0.556733
# 643  SMOTETOMEK           0.446103  0.363238  0.556733
# 438  SMOTETOMEK           0.380927  0.247319  0.509368
# 878  SMOTETOMEK           0.423126  0.336327  0.539637
# 38         none           0.446103  0.363238  0.556733
# 478        none           0.446103  0.363238  0.556733
# 273        none           0.380927  0.247319  0.509368
# 713        none           0.423126  0.336327  0.539637
