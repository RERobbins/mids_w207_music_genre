# %%
import json

import numpy as np
import pandas as pd

# %%
filename = "../bayesian_optimization_undersampling_no_lambda_logs.json"

# %%
with open(filename, "r") as infile:
    json_list = [json.loads(line) for line in infile]
df = pd.json_normalize(json_list)

# %% [markdown]
# **Current best mcc, f1_macro and accuracy results, respectively.**

# %%
best_mcc_f1_accuracy_indices = [
    df["matthews_corrcoef"].idxmax(),
    df["f1_macro"].idxmax(),
    df["balanced_accuracy"].idxmax(),
    df["accuracy"].idxmax(),
]
df.iloc[best_mcc_f1_accuracy_indices][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "matthews_corrcoef",
        "f1_macro", 
        "balanced_accuracy",
        "accuracy",
    ]
]
# Out:
#                 model                dataset scaled  pca_components  \
# 53  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 53  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 53  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 53  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
#
#     matthews_corrcoef  f1_macro  balanced_accuracy  accuracy
# 53            0.60335  0.640675           0.642713  0.642659
# 53            0.60335  0.640675           0.642713  0.642659
# 53            0.60335  0.640675           0.642713  0.642659
# 53            0.60335  0.640675           0.642713  0.642659

# %% [markdown]
# **Distribution of Datasets in Top n Results**

# %%
df.sort_values("matthews_corrcoef", ascending=False)[0:500].value_counts("dataset")
# Out:
# dataset
# dataset_00_all.pickle    500
# dtype: int64

# %% [markdown]
# **Detailed summary of current best mcc result.**

# %%
df.iloc[best_mcc_f1_accuracy_indices[0]]
# Out:
# model                    XGBoostClassifier
# dataset              dataset_00_all.pickle
# timestamp                       1658751145
# scaled                                 yes
# pca_components                         0.0
# resampling                            none
# learning_rate                     0.181088
# n_estimators                           419
# max_depth                                3
# gamma                             0.174787
# reg_alpha                           0.4416
# seed                                  1962
# matthews_corrcoef                  0.60335
# f1_macro                          0.640675
# balanced_accuracy                 0.642713
# accuracy                          0.642659
# Name: 53, dtype: object

# %% [markdown]
# **Number of trials logged.**

# %%
df.shape[0]
# Out:
# 530

# %% [markdown]
# **Group results by timestamp, resampling and pca_components, then show current best mcc by group.**

# %%
indices_for_best_mcc = df.groupby(
    ["timestamp", "pca_components", "scaled"]
)["matthews_corrcoef"].idxmax()
df.iloc[indices_for_best_mcc][
    [
        "model",
        "dataset",
        "pca_components",
        "matthews_corrcoef",
        "f1_macro",
        "balanced_accuracy",
        "accuracy",
    ]
]
# Out:
#                  model                dataset  pca_components  \
# 53   XGBoostClassifier  dataset_00_all.pickle            0.00
# 63   XGBoostClassifier  dataset_00_all.pickle            0.95
# 163  XGBoostClassifier  dataset_00_all.pickle            0.00
# 268  XGBoostClassifier  dataset_00_all.pickle            0.00
# 373  XGBoostClassifier  dataset_00_all.pickle            0.00
# 478  XGBoostClassifier  dataset_00_all.pickle            0.00
#
#      matthews_corrcoef  f1_macro  balanced_accuracy  accuracy
# 53            0.603350  0.640675           0.642713  0.642659
# 63            0.528510  0.566887           0.575038  0.574792
# 163           0.603350  0.640675           0.642713  0.642659
# 268           0.603350  0.640675           0.642713  0.642659
# 373           0.585327  0.616935           0.626408  0.626039
# 478           0.603350  0.640675           0.642713  0.642659

# %% [markdown]
# **Best Result by Dataset**

# %%
indices_for_best_mcc = df.groupby(["dataset"])["matthews_corrcoef"].idxmax()
df.iloc[indices_for_best_mcc][
    [
        "model",
        "dataset",
        "pca_components",
        "matthews_corrcoef",
        "f1_macro",
        "balanced_accuracy",
        "accuracy",
    ]
].sort_values("dataset")
# Out:
#                 model                dataset  pca_components  \
# 53  XGBoostClassifier  dataset_00_all.pickle             0.0
#
#     matthews_corrcoef  f1_macro  balanced_accuracy  accuracy
# 53            0.60335  0.640675           0.642713  0.642659

# %% [markdown]
# **Top Results (mcc > .6)**

# %%
df[df.matthews_corrcoef > 0.6].sort_values("matthews_corrcoef", ascending=False)[
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "learning_rate",
        "n_estimators",
        "max_depth",
        "gamma",
        "reg_alpha",
        "matthews_corrcoef",
        "f1_macro",
        "balanced_accuracy",
        "accuracy",
    ]
]
# Out:
#                  model                dataset scaled  pca_components  \
# 53   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 163  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 268  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 478  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
#
#      learning_rate  n_estimators  max_depth     gamma  reg_alpha  \
# 53        0.181088           419          3  0.174787     0.4416
# 163       0.181088           419          3  0.174787     0.4416
# 268       0.181088           419          3  0.174787     0.4416
# 478       0.181088           419          3  0.174787     0.4416
#
#      matthews_corrcoef  f1_macro  balanced_accuracy  accuracy
# 53             0.60335  0.640675           0.642713  0.642659
# 163            0.60335  0.640675           0.642713  0.642659
# 268            0.60335  0.640675           0.642713  0.642659
# 478            0.60335  0.640675           0.642713  0.642659

# %%
df.value_counts("dataset").sort_index(ascending=True)
# Out:
# dataset
# dataset_00_all.pickle    530
# dtype: int64

# %%
df
# Out:
#                  model                dataset   timestamp scaled  \
# 0    XGBoostClassifier  dataset_00_all.pickle  1658751145    yes
# 1    XGBoostClassifier  dataset_00_all.pickle  1658751145    yes
# 2    XGBoostClassifier  dataset_00_all.pickle  1658751145    yes
# 3    XGBoostClassifier  dataset_00_all.pickle  1658751145    yes
# 4    XGBoostClassifier  dataset_00_all.pickle  1658751145    yes
# ..                 ...                    ...         ...    ...
# 525  XGBoostClassifier  dataset_00_all.pickle  1658770467    yes
# 526  XGBoostClassifier  dataset_00_all.pickle  1658770467    yes
# 527  XGBoostClassifier  dataset_00_all.pickle  1658770467    yes
# 528  XGBoostClassifier  dataset_00_all.pickle  1658770467    yes
# 529  XGBoostClassifier  dataset_00_all.pickle  1658770467    yes
#
#      pca_components resampling  learning_rate  n_estimators  max_depth  \
# 0               0.0       none       0.106177           847          7
# 1               0.0       none       0.817638           202          4
# 2               0.0       none       0.912352           988          8
# 3               0.0       none       0.556415           993          3
# 4               0.0       none       0.114840           426          8
# ..              ...        ...            ...           ...        ...
# 525             0.0       none       0.484099           416          3
# 526             0.0       none       0.350578           424          7
# 527             0.0       none       0.165103           952          8
# 528             0.0       none       0.056950           417          4
# 529             0.0       none       0.875752           954          9
#
#         gamma  reg_alpha  seed  matthews_corrcoef  f1_macro  \
# 0    0.809896  15.199520  1962           0.523757  0.564450
# 1    3.180340  14.920890  1962           0.455661  0.509784
# 2    4.064809  17.454995  1962           0.434301  0.496031
# 3    3.588053   1.935608  1962           0.522013  0.568127
# 4    0.327162   6.880454  1962           0.552933  0.592201
# ..        ...        ...   ...                ...       ...
# 525  0.099597   0.336338  1962           0.563459  0.603580
# 526  1.124034   0.705625  1962           0.529525  0.572768
# 527  0.269528   5.824548  1962           0.546525  0.588078
# 528  1.005806   2.689339  1962           0.573014  0.608962
# 529  0.762036   6.595962  1962           0.447881  0.501408
#
#      balanced_accuracy  accuracy
# 0             0.570795  0.570637
# 1             0.509874  0.509695
# 2             0.490411  0.490305
# 3             0.569349  0.569252
# 4             0.597051  0.596953
# ..                 ...       ...
# 525           0.606678  0.606648
# 526           0.576256  0.576177
# 527           0.591610  0.591413
# 528           0.614992  0.614958
# 529           0.502873  0.502770
#
# [530 rows x 16 columns]
