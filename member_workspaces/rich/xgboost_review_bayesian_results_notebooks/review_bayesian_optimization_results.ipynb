# %%
import json

import pandas as pd

# %%
filename = "../merged_logs.json"

# %%
with open(filename, "r") as infile:
    json_list = [json.loads(line) for line in infile]
df = pd.json_normalize(json_list)

# %% [markdown]
# **Current best mcc, f1_macro and accuracy results, respectively.**

# %%
best_mcc_f1_accuracy_indices = [
    df["matthews_corrcoef"].idxmax(),
    df["f1_macro"].idxmax(),
    df["accuracy"].idxmax(),
]
df.iloc[best_mcc_f1_accuracy_indices][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                  model                dataset scaled  pca_components  \
# 266  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 139  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 266  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
#
#      resampling  matthews_corrcoef  f1_macro  accuracy
# 266  SMOTETOMEK           0.666237  0.608285  0.729215
# 139       SMOTE           0.637998  0.620410  0.702635
# 266  SMOTETOMEK           0.666237  0.608285  0.729215

# %% [markdown]
# **Distribution of Datasets in Top n Results**

# %%
df.sort_values("matthews_corrcoef", ascending=False)[0:500].value_counts("dataset")
# Out:
# dataset
# dataset_00_all.pickle                   322
# dataset_08_pvtt_mean_icov.pickle         62
# dataset_09_pvtt_mean_cov_icov.pickle     48
# dataset_07_pvtt_mean_cov.pickle          46
# dataset_04_mean_cov_icov.pickle          20
# dataset_02_mean_cov.pickle                2
# dtype: int64

# %% [markdown]
# **Detailed summary of current best mcc result.**

# %%
df.iloc[best_mcc_f1_accuracy_indices[0]]
# Out:
# model                    XGBoostClassifier
# dataset              dataset_00_all.pickle
# timestamp                       1658136355
# scaled                                 yes
# pca_components                         0.0
# resampling                      SMOTETOMEK
# learning_rate                     0.221461
# n_estimators                           827
# max_depth                                4
# gamma                             0.524969
# reg_alpha                         4.327827
# seed                                  1962
# fit_tim                         193.808802
# core_tim                           0.37062
# matthews_corrcoef                 0.666237
# f1_macro                          0.608285
# accuracy                          0.729215
# Name: 266, dtype: object

# %% [markdown]
# **Number of trials logged.**

# %%
df.shape[0]
# Out:
# 5329

# %% [markdown]
# **Group results by timestamp, resampling and pca_components, then show current best mcc by group.**

# %%
indices_for_best_mcc = df.groupby(
    ["timestamp", "resampling", "pca_components", "scaled"]
)["matthews_corrcoef"].idxmax()
df.iloc[indices_for_best_mcc][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                   model                               dataset scaled  \
# 573   XGBoostClassifier                dataset_01_mean.pickle     no
# 1013  XGBoostClassifier                dataset_01_mean.pickle    yes
# 816   XGBoostClassifier                dataset_01_mean.pickle     no
# 1239  XGBoostClassifier                dataset_01_mean.pickle    yes
# 641   XGBoostClassifier                dataset_01_mean.pickle     no
# ...                 ...                                   ...    ...
# 5228  XGBoostClassifier  dataset_09_pvtt_mean_cov_icov.pickle    yes
# 5106  XGBoostClassifier  dataset_09_pvtt_mean_cov_icov.pickle    yes
# 5322  XGBoostClassifier  dataset_09_pvtt_mean_cov_icov.pickle    yes
# 4941  XGBoostClassifier  dataset_09_pvtt_mean_cov_icov.pickle    yes
# 5157  XGBoostClassifier  dataset_09_pvtt_mean_cov_icov.pickle    yes
#
#       pca_components  resampling  matthews_corrcoef  f1_macro  accuracy
# 573             0.00       SMOTE           0.417633  0.391702  0.512646
# 1013            0.00       SMOTE           0.422323  0.397869  0.517096
# 816             0.95       SMOTE           0.296870  0.273581  0.380386
# 1239            0.95       SMOTE           0.396496  0.371039  0.495785
# 641             0.00    SMOTEENN           0.360060  0.335622  0.428981
# ...              ...         ...                ...       ...       ...
# 5228            0.95    SMOTEENN           0.437705  0.407819  0.500468
# 5106            0.00  SMOTETOMEK           0.575895  0.511781  0.657143
# 5322            0.95  SMOTETOMEK           0.507854  0.440324  0.603981
# 4941            0.00        none           0.575895  0.511781  0.657143
# 5157            0.95        none           0.507854  0.440324  0.603981
#
# [97 rows x 8 columns]

# %% [markdown]
# **Best Result by Dataset**

# %%
indices_for_best_mcc = df.groupby(["dataset"])["matthews_corrcoef"].idxmax()
df.iloc[indices_for_best_mcc][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
].sort_values("dataset")
# Out:
#                   model                               dataset scaled  \
# 266   XGBoostClassifier                 dataset_00_all.pickle    yes
# 527   XGBoostClassifier                dataset_01_mean.pickle     no
# 1417  XGBoostClassifier            dataset_02_mean_cov.pickle    yes
# 1903  XGBoostClassifier           dataset_03_mean_icov.pickle    yes
# 2301  XGBoostClassifier       dataset_04_mean_cov_icov.pickle    yes
# 2722  XGBoostClassifier                dataset_05_pvtt.pickle    yes
# 3170  XGBoostClassifier           dataset_06_pvtt_mean.pickle    yes
# 3602  XGBoostClassifier       dataset_07_pvtt_mean_cov.pickle    yes
# 4015  XGBoostClassifier      dataset_08_pvtt_mean_icov.pickle     no
# 4996  XGBoostClassifier  dataset_09_pvtt_mean_cov_icov.pickle    yes
#
#       pca_components  resampling  matthews_corrcoef  f1_macro  accuracy
# 266              0.0  SMOTETOMEK           0.666237  0.608285  0.729215
# 527              0.0        none           0.446103  0.363238  0.556733
# 1417             0.0        none           0.546841  0.480513  0.634660
# 1903             0.0       SMOTE           0.541714  0.509942  0.624063
# 2301             0.0        none           0.557263  0.491526  0.643267
# 2722             0.0        none           0.438515  0.334268  0.549824
# 3170             0.0        none           0.511877  0.431531  0.606850
# 3602             0.0        none           0.567610  0.496467  0.650995
# 4015             0.0        none           0.564454  0.500952  0.648361
# 4996             0.0       SMOTE           0.577025  0.550293  0.652927

# %% [markdown]
# **Top Results (mcc > .645)**

# %%
df[df.matthews_corrcoef > 0.645].sort_values("matthews_corrcoef", ascending=False)[
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "learning_rate",
        "n_estimators",
        "max_depth",
        "gamma",
        "reg_alpha",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                  model                dataset scaled  pca_components  \
# 266  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 262  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 48   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 4    XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 218  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 53   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 263  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 214  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 0    XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 49   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 241  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 27   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 76   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 258  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 44   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 99   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 47   XGBoostClassifier  dataset_00_all.pickle    yes             0.0
#
#      resampling  learning_rate  n_estimators  max_depth     gamma  reg_alpha  \
# 266  SMOTETOMEK       0.221461           827          4  0.524969   4.327827
# 262  SMOTETOMEK       0.049392           827          4  1.554884   4.241767
# 48         none       0.049392           827          4  1.554884   4.241767
# 4          none       0.114840           426          8  0.327162   6.880454
# 218  SMOTETOMEK       0.114840           426          8  0.327162   6.880454
# 53         none       0.114840           426          8  0.327162   6.880454
# 263  SMOTETOMEK       0.044751           846          7  0.502530  15.720156
# 214  SMOTETOMEK       0.106177           847          7  0.809896  15.199520
# 0          none       0.106177           847          7  0.809896  15.199520
# 49         none       0.106177           847          7  0.809896  15.199520
# 241  SMOTETOMEK       0.313633           993          3  3.230997   1.680919
# 27         none       0.313633           993          3  3.230997   1.680919
# 76         none       0.313633           993          3  3.230997   1.680919
# 258  SMOTETOMEK       0.079789           768          9  1.204398  12.125154
# 44         none       0.079789           768          9  1.204398  12.125154
# 99         none       0.053754           696          4  4.275888   0.838333
# 47         none       0.221265           768          9  0.747411  11.738537
#
#      matthews_corrcoef  f1_macro  accuracy
# 266           0.666237  0.608285  0.729215
# 262           0.659560  0.597724  0.723888
# 48            0.659560  0.597724  0.723888
# 4             0.658313  0.598556  0.723009
# 218           0.658313  0.598556  0.723009
# 53            0.658313  0.598556  0.723009
# 263           0.652382  0.583239  0.718326
# 214           0.648024  0.579273  0.714871
# 0             0.648024  0.579273  0.714871
# 49            0.648024  0.579273  0.714871
# 241           0.647926  0.589580  0.714461
# 27            0.647926  0.589580  0.714461
# 76            0.647926  0.589580  0.714461
# 258           0.646703  0.576625  0.713817
# 44            0.646703  0.576625  0.713817
# 99            0.645760  0.581131  0.712881
# 47            0.645338  0.584689  0.712588

# %%
df.value_counts("dataset").sort_index(ascending=True)
# Out:
# dataset
# dataset_00_all.pickle                   489
# dataset_01_mean.pickle                  880
# dataset_02_mean_cov.pickle              440
# dataset_03_mean_icov.pickle             440
# dataset_04_mean_cov_icov.pickle         440
# dataset_05_pvtt.pickle                  440
# dataset_06_pvtt_mean.pickle             440
# dataset_07_pvtt_mean_cov.pickle         440
# dataset_08_pvtt_mean_icov.pickle        880
# dataset_09_pvtt_mean_cov_icov.pickle    440
# dtype: int64
