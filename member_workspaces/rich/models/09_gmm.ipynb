# %%
import glob
import sys

import numpy as np
import pandas as pd
from sklearn.mixture import GaussianMixture

sys.path.append("../../../")

from helpers.experiment import experiment

# %%
dataset_folder = "../../../datasets/"
datasets = sorted([name for name in glob.glob(dataset_folder + "dataset_*.pickle")])

for dataset in datasets:
    
    if "spectrogram" in dataset:
        n_components = 2400
    else:
        n_components = .95
        
    n_components=None
        
    model = GaussianMixture(n_components=10)
    experiment(model, dataset, pca_components=n_components, result_filename="rich_results.json")
# Out:
# Commencing Experiment: GaussianMixture_dataset_00_all
#
# Training accuracy: train_accuracy = 6742.077771
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0054  0.0241    0.0088      374  -0.0373
#   genre_classical     0.0094  0.0043    0.0059     4221  -0.1957
#     genre_country     0.0312  0.1865    0.0534      327   0.0315
#       genre_disco     0.0141  0.1869    0.0263      289  -0.0117
#      genre_hiphop     0.0286  0.0547    0.0376     1701  -0.1148
#        genre_jazz     0.0360  0.0105    0.0162     1241  -0.0207
#       genre_metal     0.0069  0.0241    0.0108      665  -0.0654
#         genre_pop     0.3086  0.0952    0.1455     4274   0.0390
#      genre_reggae     0.0000  0.0000    0.0000      788  -0.0029
#        genre_rock     0.0876  0.0128    0.0224     3200  -0.0429
#
#          accuracy                       0.0417    17080  -0.0530
#         macro avg     0.0528  0.0599    0.0327    17080
#      weighted avg     0.1026  0.0417    0.0491    17080
#               min     0.0000  0.0000    0.0000      289  -0.1957
#
# Testing accuracy: test_accuracy = -6387508.976340
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0102  0.0106    0.0104       94  -0.0123
#   genre_classical     0.0000  0.0000    0.0000     1055  -0.0175
#     genre_country     0.0000  0.0000    0.0000       82  -0.0141
#       genre_disco     0.0255  0.9167    0.0495       72   0.0830
#      genre_hiphop     0.0420  0.1435    0.0650      425  -0.1377
#        genre_jazz     0.0000  0.0000    0.0000      311  -0.0086
#       genre_metal     0.0000  0.0000    0.0000      166  -0.0263
#         genre_pop     0.5000  0.0028    0.0056     1069   0.0216
#      genre_reggae     0.0000  0.0000    0.0000      197   0.0000
#        genre_rock     0.0000  0.0000    0.0000      800   0.0000
#
#          accuracy                       0.0307     4271  -0.0236
#         macro avg     0.0578  0.1074    0.0131     4271
#      weighted avg     0.1300  0.0307    0.0089     4271
#               min     0.0000  0.0000    0.0000       72  -0.1377
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Commencing Experiment: GaussianMixture_dataset_01_mean
#
# Training accuracy: train_accuracy = -12.773754
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0296  0.1471    0.0493      374   0.0184
#   genre_classical     0.0320  0.0182    0.0232     4221  -0.2018
#     genre_country     0.0000  0.0000    0.0000      327  -0.0309
#       genre_disco     0.0072  0.0415    0.0123      289  -0.0246
#      genre_hiphop     0.1659  0.3398    0.2230     1701   0.1121
#        genre_jazz     0.0895  0.0911    0.0903     1241   0.0183
#       genre_metal     0.0093  0.0451    0.0155      665  -0.0737
#         genre_pop     0.2542  0.0777    0.1190     4274   0.0026
#      genre_reggae     0.0273  0.0114    0.0161      788  -0.0126
#        genre_rock     0.0079  0.0019    0.0030     3200  -0.0995
#
#          accuracy                       0.0710    17080  -0.0357
#         macro avg     0.0623  0.0774    0.0552    17080
#      weighted avg     0.0984  0.0710    0.0675    17080
#               min     0.0000  0.0000    0.0000      289  -0.2018
#
# Testing accuracy: test_accuracy = -12.931210
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0306  0.1489    0.0507       94   0.0202
#   genre_classical     0.0315  0.0180    0.0229     1055  -0.2026
#     genre_country     0.0000  0.0000    0.0000       82  -0.0315
#       genre_disco     0.0024  0.0139    0.0040       72  -0.0374
#      genre_hiphop     0.1546  0.3059    0.2054      425   0.0911
#        genre_jazz     0.1108  0.1158    0.1132      311   0.0419
#       genre_metal     0.0117  0.0542    0.0192      166  -0.0659
#         genre_pop     0.2849  0.0898    0.1366     1069   0.0234
#      genre_reggae     0.0202  0.0102    0.0135      197  -0.0190
#        genre_rock     0.0000  0.0000    0.0000      800  -0.1086
#
#          accuracy                       0.0719     4271  -0.0355
#         macro avg     0.0647  0.0757    0.0566     4271
#      weighted avg     0.1046  0.0719    0.0711     4271
#               min     0.0000  0.0000    0.0000       72  -0.2026
# Commencing Experiment: GaussianMixture_dataset_02_mean_cov
# /opt/conda/lib/python3.9/site-packages/sklearn/mixture/_base.py:286: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# Training accuracy: train_accuracy = 377.259881
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0052  0.0027    0.0035      374  -0.0121
#   genre_classical     0.1440  0.1208    0.1314     4221  -0.1223
#     genre_country     0.0575  0.5657    0.1044      327   0.1349
#       genre_disco     0.0275  0.0208    0.0237      289   0.0093
#      genre_hiphop     0.1950  0.1464    0.1672     1701   0.0906
#        genre_jazz     0.1278  0.3642    0.1892     1241   0.1085
#       genre_metal     0.0068  0.0090    0.0077      665  -0.0390
#         genre_pop     0.0129  0.0042    0.0063     4274  -0.1636
#      genre_reggae     0.0000  0.0000    0.0000      788  -0.0259
#        genre_rock     0.1884  0.1519    0.1682     3200   0.0012
#
#          accuracy                       0.1120    17080  -0.0207
#         macro avg     0.0765  0.1386    0.0802    17080
#      weighted avg     0.1048  0.1120    0.0988    17080
#               min     0.0000  0.0000    0.0000      289  -0.1636
#
# Testing accuracy: test_accuracy = 372.724718
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0000  0.0000    0.0000       94  -0.0065
#   genre_classical     0.1481  0.1223    0.1340     1055  -0.1161
#     genre_country     0.0674  0.6220    0.1216       82   0.1629
#       genre_disco     0.1000  0.0139    0.0244       72   0.0313
#      genre_hiphop     0.2453  0.2447    0.2450      425   0.1617
#        genre_jazz     0.1278  0.3633    0.1891      311   0.1082
#       genre_metal     0.0047  0.0060    0.0053      166  -0.0405
#         genre_pop     0.0139  0.0047    0.0070     1069  -0.1656
#      genre_reggae     0.0000  0.0000    0.0000      197  -0.0229
#        genre_rock     0.1934  0.1688    0.1802      800   0.0069
#
#          accuracy                       0.1262     4271  -0.0081
#         macro avg     0.0901  0.1546    0.0907     4271
#      weighted avg     0.1132  0.1262    0.1097     4271
#               min     0.0000  0.0000    0.0000       72  -0.1656
# Commencing Experiment: GaussianMixture_dataset_03_mean_icov
#
# Training accuracy: train_accuracy = 986.975838
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0229  0.9920    0.0448      374   0.0297
#   genre_classical     1.0000  0.0002    0.0005     4221   0.0134
#     genre_country     0.0000  0.0000    0.0000      327  -0.0011
#       genre_disco     0.0000  0.0000    0.0000      289  -0.0010
#      genre_hiphop     0.0016  0.0006    0.0009     1701  -0.0635
#        genre_jazz     0.0000  0.0000    0.0000     1241  -0.0030
#       genre_metal     0.0000  0.0000    0.0000      665  -0.0022
#         genre_pop     0.0000  0.0000    0.0000     4274  -0.0044
#      genre_reggae     0.0000  0.0000    0.0000      788  -0.0017
#        genre_rock     0.0038  0.0003    0.0006     3200  -0.0586
#
#          accuracy                       0.0219    17080  -0.0188
#         macro avg     0.1028  0.0993    0.0047    17080
#      weighted avg     0.2485  0.0219    0.0013    17080
#               min     0.0000  0.0000    0.0000      289  -0.0635
#
# Testing accuracy: test_accuracy = 763.384376
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0231  0.9894    0.0452       94   0.0308
#   genre_classical     0.0000  0.0000    0.0000     1055   0.0000
#     genre_country     0.0000  0.0000    0.0000       82   0.0000
#       genre_disco     0.0000  0.0000    0.0000       72   0.0000
#      genre_hiphop     0.0000  0.0000    0.0000      425  -0.0709
#        genre_jazz     0.0000  0.0000    0.0000      311   0.0000
#       genre_metal     0.0000  0.0000    0.0000      166   0.0000
#         genre_pop     0.0000  0.0000    0.0000     1069   0.0000
#      genre_reggae     0.0000  0.0000    0.0000      197   0.0000
#        genre_rock     0.0000  0.0000    0.0000      800  -0.0601
#
#          accuracy                       0.0218     4271  -0.0203
#         macro avg     0.0023  0.0989    0.0045     4271
#      weighted avg     0.0005  0.0218    0.0010     4271
#               min     0.0000  0.0000    0.0000       72  -0.0709
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Commencing Experiment: GaussianMixture_dataset_04_mean_cov_icov
#
# Training accuracy: train_accuracy = 1373.400564
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0000  0.0000    0.0000      374  -0.0337
#   genre_classical     1.0000  0.0002    0.0005     4221   0.0134
#     genre_country     0.0521  0.4465    0.0934      327   0.1066
#       genre_disco     0.0000  0.0000    0.0000      289  -0.0010
#      genre_hiphop     0.0441  0.1329    0.0662     1701  -0.1213
#        genre_jazz     0.0000  0.0000    0.0000     1241  -0.0030
#       genre_metal     0.0274  0.2075    0.0484      665  -0.0385
#         genre_pop     0.0159  0.0007    0.0013     4274  -0.0572
#      genre_reggae     0.0556  0.2005    0.0871      788   0.0201
#        genre_rock     0.0344  0.0028    0.0052     3200  -0.0489
#
#          accuracy                       0.0399    17080  -0.0240
#         macro avg     0.1229  0.0991    0.0302    17080
#      weighted avg     0.2666  0.0399    0.0157    17080
#               min     0.0000  0.0000    0.0000      289  -0.1213
#
# Testing accuracy: test_accuracy = 1123.961014
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0048  0.0106    0.0066       94  -0.0264
#   genre_classical     0.0000  0.0000    0.0000     1055   0.0000
#     genre_country     0.0588  0.4878    0.1050       82   0.1257
#       genre_disco     0.0000  0.0000    0.0000       72   0.0000
#      genre_hiphop     0.0433  0.1365    0.0658      425  -0.1267
#        genre_jazz     0.0000  0.0000    0.0000      311   0.0000
#       genre_metal     0.0239  0.1747    0.0420      166  -0.0489
#         genre_pop     0.0000  0.0000    0.0000     1069  -0.0198
#      genre_reggae     0.0655  0.2538    0.1042      197   0.0431
#        genre_rock     0.0000  0.0000    0.0000      800  -0.0587
#
#          accuracy                       0.0417     4271  -0.0202
#         macro avg     0.0196  0.1063    0.0324     4271
#      weighted avg     0.0095  0.0417    0.0151     4271
#               min     0.0000  0.0000    0.0000       72  -0.1267
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Commencing Experiment: GaussianMixture_dataset_05_pvtt
#
# Training accuracy: train_accuracy = 7.723512
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0245  0.2701    0.0449      374   0.0099
#   genre_classical     0.0403  0.0218    0.0283     4221  -0.1884
#     genre_country     0.0095  0.0092    0.0093      327  -0.0097
#       genre_disco     0.0087  0.0450    0.0145      289  -0.0199
#      genre_hiphop     0.0008  0.0006    0.0007     1701  -0.0938
#        genre_jazz     0.0159  0.0048    0.0074     1241  -0.0328
#       genre_metal     0.0155  0.0602    0.0246      665  -0.0512
#         genre_pop     0.0143  0.0012    0.0022     4274  -0.0788
#      genre_reggae     0.0490  0.2424    0.0816      788   0.0075
#        genre_rock     0.0192  0.0022    0.0039     3200  -0.0636
#
#          accuracy                       0.0269    17080  -0.0579
#         macro avg     0.0198  0.0657    0.0217    17080
#      weighted avg     0.0221  0.0269    0.0150    17080
#               min     0.0008  0.0006    0.0007      289  -0.1884
#
# Testing accuracy: test_accuracy = 7.472902
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0219  0.2340    0.0400       94  -0.0005
#   genre_classical     0.0389  0.0209    0.0272     1055  -0.1884
#     genre_country     0.0000  0.0000    0.0000       82  -0.0208
#       genre_disco     0.0029  0.0139    0.0048       72  -0.0321
#      genre_hiphop     0.0000  0.0000    0.0000      425  -0.0962
#        genre_jazz     0.0200  0.0064    0.0097      311  -0.0315
#       genre_metal     0.0157  0.0602    0.0249      166  -0.0502
#         genre_pop     0.0217  0.0019    0.0034     1069  -0.0783
#      genre_reggae     0.0581  0.2944    0.0970      197   0.0314
#        genre_rock     0.0381  0.0050    0.0088      800  -0.0607
#
#          accuracy                       0.0283     4271  -0.0571
#         macro avg     0.0217  0.0637    0.0216     4271
#      weighted avg     0.0275  0.0283    0.0163     4271
#               min     0.0000  0.0000    0.0000       72  -0.1884
# Commencing Experiment: GaussianMixture_dataset_06_pvtt_mean
#
# Training accuracy: train_accuracy = -2.295102
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0209  0.2540    0.0386      374  -0.0041
#   genre_classical     0.9391  0.2194    0.3557     4221   0.3971
#     genre_country     0.0000  0.0000    0.0000      327  -0.0228
#       genre_disco     0.0025  0.0208    0.0044      289  -0.0455
#      genre_hiphop     0.0030  0.0006    0.0010     1701  -0.0457
#        genre_jazz     0.0515  0.0113    0.0185     1241  -0.0104
#       genre_metal     0.0033  0.0075    0.0046      665  -0.0570
#         genre_pop     0.3426  0.2768    0.3062     4274   0.1073
#      genre_reggae     0.0000  0.0000    0.0000      788  -0.0362
#        genre_rock     0.1526  0.1278    0.1391     3200  -0.0384
#
#          accuracy                       0.1545    17080   0.0530
#         macro avg     0.1516  0.0918    0.0868    17080
#      weighted avg     0.3511  0.1545    0.1931    17080
#               min     0.0000  0.0000    0.0000      289  -0.0570
#
# Testing accuracy: test_accuracy = -2.880712
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0223  0.2553    0.0411       94   0.0013
#   genre_classical     0.9357  0.2209    0.3574     1055   0.3973
#     genre_country     0.0081  0.0122    0.0097       82  -0.0140
#       genre_disco     0.0000  0.0000    0.0000       72  -0.0506
#      genre_hiphop     0.0000  0.0000    0.0000      425  -0.0488
#        genre_jazz     0.0278  0.0064    0.0104      311  -0.0227
#       genre_metal     0.0134  0.0301    0.0186      166  -0.0408
#         genre_pop     0.3280  0.2862    0.3057     1069   0.0948
#      genre_reggae     0.0000  0.0000    0.0000      197  -0.0388
#        genre_rock     0.1803  0.1512    0.1645      800  -0.0077
#
#          accuracy                       0.1620     4271   0.0569
#         macro avg     0.1516  0.0962    0.0907     4271
#      weighted avg     0.3502  0.1620    0.1982     4271
#               min     0.0000  0.0000    0.0000       72  -0.0506
# Commencing Experiment: GaussianMixture_dataset_07_pvtt_mean_cov
#
# Training accuracy: train_accuracy = 386.169498
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0022  0.0080    0.0035      374  -0.0393
#   genre_classical     0.1222  0.1066    0.1139     4221  -0.1518
#     genre_country     0.0000  0.0000    0.0000      327  -0.0165
#       genre_disco     0.0325  0.3633    0.0596      289   0.0582
#      genre_hiphop     0.1412  0.0288    0.0479     1701   0.0200
#        genre_jazz     0.1091  0.0145    0.0256     1241   0.0139
#       genre_metal     0.0324  0.1955    0.0555      665  -0.0188
#         genre_pop     0.3824  0.1654    0.2309     4274   0.1063
#      genre_reggae     0.0007  0.0013    0.0009      788  -0.0636
#        genre_rock     0.1275  0.0338    0.0534     3200  -0.0350
#
#          accuracy                       0.0920    17080  -0.0222
#         macro avg     0.0950  0.0917    0.0591    17080
#      weighted avg     0.1737  0.0920    0.1058    17080
#               min     0.0000  0.0000    0.0000      289  -0.1518
#
# Testing accuracy: test_accuracy = 379.899797
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0000  0.0000    0.0000       94  -0.0450
#   genre_classical     0.1192  0.1024    0.1101     1055  -0.1538
#     genre_country     0.0000  0.0000    0.0000       82  -0.0083
#       genre_disco     0.0356  0.4028    0.0655       72   0.0707
#      genre_hiphop     0.0729  0.0165    0.0269      425  -0.0135
#        genre_jazz     0.0000  0.0000    0.0000      311  -0.0129
#       genre_metal     0.0346  0.1988    0.0589      166  -0.0120
#         genre_pop     0.3463  0.1581    0.2171     1069   0.0796
#      genre_reggae     0.0000  0.0000    0.0000      197  -0.0628
#        genre_rock     0.0987  0.0387    0.0557      800  -0.0640
#
#          accuracy                       0.0883     4271  -0.0315
#         macro avg     0.0707  0.0917    0.0534     4271
#      weighted avg     0.1438  0.0883    0.0980     4271
#               min     0.0000  0.0000    0.0000       72  -0.1538
# Commencing Experiment: GaussianMixture_dataset_08_pvtt_mean_icov
#
# Training accuracy: train_accuracy = 996.926655
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0068  0.0321    0.0113      374  -0.0349
#   genre_classical     1.0000  0.0002    0.0005     4221   0.0134
#     genre_country     0.0000  0.0000    0.0000      327  -0.0011
#       genre_disco     0.0000  0.0000    0.0000      289  -0.0010
#      genre_hiphop     0.1229  0.6855    0.2084     1701   0.0870
#        genre_jazz     0.0000  0.0000    0.0000     1241  -0.0048
#       genre_metal     0.0000  0.0000    0.0000      665  -0.0310
#         genre_pop     0.0000  0.0000    0.0000     4274  -0.0044
#      genre_reggae     0.0160  0.1104    0.0280      788  -0.0979
#        genre_rock     0.0000  0.0000    0.0000     3200  -0.0052
#
#          accuracy                       0.0741    17080   0.0013
#         macro avg     0.1146  0.0828    0.0248    17080
#      weighted avg     0.2603  0.0741    0.0224    17080
#               min     0.0000  0.0000    0.0000      289  -0.0979
#
# Testing accuracy: test_accuracy = 837.366047
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0042  0.0213    0.0070       94  -0.0433
#   genre_classical     0.0000  0.0000    0.0000     1055   0.0000
#     genre_country     0.0000  0.0000    0.0000       82   0.0000
#       genre_disco     0.0000  0.0000    0.0000       72   0.0000
#      genre_hiphop     0.1215  0.6729    0.2059      425   0.0815
#        genre_jazz     0.0000  0.0000    0.0000      311   0.0000
#       genre_metal     0.0000  0.0000    0.0000      166  -0.0327
#         genre_pop     0.0000  0.0000    0.0000     1069   0.0000
#      genre_reggae     0.0173  0.1168    0.0302      197  -0.0922
#        genre_rock     0.0000  0.0000    0.0000      800   0.0000
#
#          accuracy                       0.0728     4271   0.0003
#         macro avg     0.0143  0.0811    0.0243     4271
#      weighted avg     0.0130  0.0728    0.0220     4271
#               min     0.0000  0.0000    0.0000       72  -0.0922
# Commencing Experiment: GaussianMixture_dataset_09_pvtt_mean_cov_icov
#
# Training accuracy: train_accuracy = 1383.098810
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0203  0.1444    0.0357      374  -0.0046
#   genre_classical     1.0000  0.0002    0.0005     4221   0.0134
#     genre_country     0.0144  0.2018    0.0269      327  -0.0208
#       genre_disco     0.0000  0.0000    0.0000      289  -0.0010
#      genre_hiphop     0.0054  0.0071    0.0061     1701  -0.1221
#        genre_jazz     0.0000  0.0000    0.0000     1241  -0.0030
#       genre_metal     0.0066  0.0030    0.0041      665  -0.0224
#         genre_pop     0.3165  0.4860    0.3833     4274   0.1208
#      genre_reggae     0.0000  0.0000    0.0000      788  -0.0024
#        genre_rock     0.0027  0.0006    0.0010     3200  -0.1011
#
#          accuracy                       0.1296    17080   0.0039
#         macro avg     0.1366  0.0843    0.0458    17080
#      weighted avg     0.3283  0.1296    0.0983    17080
#               min     0.0000  0.0000    0.0000      289  -0.1221
#
# Testing accuracy: test_accuracy = 1120.764703
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0126  0.0957    0.0222       94  -0.0290
#   genre_classical     0.0000  0.0000    0.0000     1055   0.0000
#     genre_country     0.0160  0.2195    0.0298       82  -0.0142
#       genre_disco     0.0000  0.0000    0.0000       72   0.0000
#      genre_hiphop     0.0054  0.0071    0.0061      425  -0.1212
#        genre_jazz     0.0000  0.0000    0.0000      311   0.0000
#       genre_metal     0.0000  0.0000    0.0000      166  -0.0283
#         genre_pop     0.3234  0.4864    0.3885     1069   0.1311
#      genre_reggae     0.0000  0.0000    0.0000      197   0.0000
#        genre_rock     0.0000  0.0000    0.0000      800  -0.1013
#
#          accuracy                       0.1288     4271   0.0053
#         macro avg     0.0357  0.0809    0.0447     4271
#      weighted avg     0.0821  0.1288    0.0989     4271
#               min     0.0000  0.0000    0.0000       72  -0.1212
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Commencing Experiment: GaussianMixture_dataset_10_melspectrograms_flattened
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#      11 n_components=None
#      13 model = GaussianMixture(n_components=10)
# ---> 14 experiment(model, dataset, pca_components=n_components, result_filename="rich_results.json")
#
# File ~/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../helpers/experiment.py:89, in experiment(model, dataset, name, samples_per_genre, pca_components, result_filename, model_fit_call_fn, postprocess_y_pred_fn)
#      72     fit_history = model_fit_call_fn(
#      73         model=model,
#      74         X_train=X_train_std,
#    (...)
#      85         },
#      86     )
#      87 # otherwise use the default fit method
#      88 else:
# ---> 89     fit_history = model.fit(X_train_std, y_train)
#      91 y_test_pred = model.predict(X_test_std)
#      92 if postprocess_y_pred_fn is not None:
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/mixture/_base.py:200, in BaseMixture.fit(self, X, y)
#     174 def fit(self, X, y=None):
#     175     """Estimate model parameters with the EM algorithm.
#     176
#     177     The method fits the model ``n_init`` times and sets the parameters with
#    (...)
#     198         The fitted mixture.
#     199     """
# --> 200     self.fit_predict(X, y)
#     201     return self
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/mixture/_base.py:253, in BaseMixture.fit_predict(self, X, y)
#     250 self._print_verbose_msg_init_beg(init)
#     252 if do_init:
# --> 253     self._initialize_parameters(X, random_state)
#     255 lower_bound = -np.inf if do_init else self.lower_bound_
#     257 if self.max_iter == 0:
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/mixture/_base.py:160, in BaseMixture._initialize_parameters(self, X, random_state)
#     155 else:
#     156     raise ValueError(
#     157         "Unimplemented initialization method '%s'" % self.init_params
#     158     )
# --> 160 self._initialize(X, resp)
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/mixture/_gaussian_mixture.py:713, in GaussianMixture._initialize(self, X, resp)
#     703 """Initialization of the Gaussian mixture parameters.
#     704
#     705 Parameters
#    (...)
#     709 resp : array-like of shape (n_samples, n_components)
#     710 """
#     711 n_samples, _ = X.shape
# --> 713 weights, means, covariances = _estimate_gaussian_parameters(
#     714     X, resp, self.reg_covar, self.covariance_type
#     715 )
#     716 weights /= n_samples
#     718 self.weights_ = weights if self.weights_init is None else self.weights_init
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/mixture/_gaussian_mixture.py:291, in _estimate_gaussian_parameters(X, resp, reg_covar, covariance_type)
#     289 nk = resp.sum(axis=0) + 10 * np.finfo(resp.dtype).eps
#     290 means = np.dot(resp.T, X) / nk[:, np.newaxis]
# --> 291 covariances = {
#     292     "full": _estimate_gaussian_covariances_full,
#     293     "tied": _estimate_gaussian_covariances_tied,
#     294     "diag": _estimate_gaussian_covariances_diag,
#     295     "spherical": _estimate_gaussian_covariances_spherical,
#     296 }[covariance_type](resp, X, nk, means, reg_covar)
#     297 return nk, means, covariances
#
# File /opt/conda/lib/python3.9/site-packages/sklearn/mixture/_gaussian_mixture.py:175, in _estimate_gaussian_covariances_full(resp, X, nk, means, reg_covar)
#     155 """Estimate the full covariance matrices.
#     156
#     157 Parameters
#    (...)
#     172     The covariance matrix of the current components.
#     173 """
#     174 n_components, n_features = means.shape
# --> 175 covariances = np.empty((n_components, n_features, n_features))
#     176 for k in range(n_components):
#     177     diff = X - means[k]
#
# MemoryError: Unable to allocate 320. GiB for an array with shape (10, 65568, 65568) and data type float64
