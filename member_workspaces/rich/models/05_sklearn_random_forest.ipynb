# %%
import glob
import sys

import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier

sys.path.append("../../../")

from helpers.experiment import experiment

# %%
dataset_folder = "../../../datasets/"
datasets = sorted([name for name in glob.glob(dataset_folder + "dataset_*.pickle")])

for dataset in datasets:
    model = RandomForestClassifier(class_weight='balanced')
    experiment(model, dataset, result_filename="rich_results.json")
# Out:
# Commencing Experiment: RandomForestClassifier_dataset_00_all
#
# Training accuracy: train_accuracy = 1.000000
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  1.0000    1.0000      374  1.0000
#   genre_classical     1.0000  1.0000    1.0000     4221  1.0000
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     1.0000  1.0000    1.0000     1701  1.0000
#        genre_jazz     1.0000  1.0000    1.0000     1241  1.0000
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     1.0000  1.0000    1.0000     4274  1.0000
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     1.0000  1.0000    1.0000     3200  1.0000
#
#          accuracy                       1.0000    17080  1.0000
#         macro avg     1.0000  1.0000    1.0000    17080
#      weighted avg     1.0000  1.0000    1.0000    17080
#               min     1.0000  1.0000    1.0000      289  1.0000
#
# Testing accuracy: test_accuracy = 0.662842
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.8363  0.8768    0.8561     1055  0.8078
#     genre_country     1.0000  0.4146    0.5862       82  0.6403
#       genre_disco     0.8400  0.2917    0.4330       72  0.4906
#      genre_hiphop     0.7063  0.6565    0.6805      425  0.6471
#        genre_jazz     0.8788  0.3730    0.5237      311  0.5539
#       genre_metal     0.8095  0.3072    0.4454      166  0.4879
#         genre_pop     0.5074  0.7680    0.6111     1069  0.4635
#      genre_reggae     0.7652  0.4467    0.5641      197  0.5703
#        genre_rock     0.6330  0.6188    0.6258      800  0.5408
#
#          accuracy                       0.6628     4271  0.5831
#         macro avg     0.7977  0.4764    0.5347     4271
#      weighted avg     0.7086  0.6628    0.6498     4271
#               min     0.5074  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_01_mean
#
# Training accuracy: train_accuracy = 0.999649
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.9973  1.0000    0.9987      374  0.9986
#   genre_classical     1.0000  0.9995    0.9998     4221  0.9997
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     0.9988  1.0000    0.9994     1701  0.9993
#        genre_jazz     1.0000  0.9992    0.9996     1241  0.9996
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     0.9995  0.9995    0.9995     4274  0.9994
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     0.9997  0.9997    0.9997     3200  0.9996
#
#          accuracy                       0.9996    17080  0.9996
#         macro avg     0.9995  0.9998    0.9997    17080
#      weighted avg     0.9996  0.9996    0.9996    17080
#               min     0.9973  0.9992    0.9987      289  0.9986
#
# Testing accuracy: test_accuracy = 0.564505
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.7554  0.8635    0.8058     1055  0.7394
#     genre_country     1.0000  0.2561    0.4078       82  0.5024
#       genre_disco     0.7778  0.0972    0.1728       72  0.2716
#      genre_hiphop     0.4709  0.3624    0.4096      425  0.3573
#        genre_jazz     0.5701  0.1961    0.2919      311  0.3068
#       genre_metal     0.7600  0.2289    0.3519      166  0.4061
#         genre_pop     0.4309  0.6829    0.5284     1069  0.3381
#      genre_reggae     0.4750  0.0964    0.1603      197  0.1988
#        genre_rock     0.5748  0.5863    0.5804      800  0.4826
#
#          accuracy                       0.5645     4271  0.4542
#         macro avg     0.6815  0.3380    0.3730     4271
#      weighted avg     0.5963  0.5645    0.5343     4271
#               min     0.4309  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_02_mean_cov
#
# Training accuracy: train_accuracy = 0.999649
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.9973  1.0000    0.9987      374  0.9986
#   genre_classical     0.9995  1.0000    0.9998     4221  0.9997
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     0.9988  1.0000    0.9994     1701  0.9993
#        genre_jazz     1.0000  0.9992    0.9996     1241  0.9996
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     1.0000  0.9991    0.9995     4274  0.9994
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     0.9997  0.9997    0.9997     3200  0.9996
#
#          accuracy                       0.9996    17080  0.9996
#         macro avg     0.9995  0.9998    0.9997    17080
#      weighted avg     0.9996  0.9996    0.9996    17080
#               min     0.9973  0.9991    0.9987      289  0.9986
#
# Testing accuracy: test_accuracy = 0.581597
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.7915  0.8493    0.8194     1055  0.7582
#     genre_country     1.0000  0.2439    0.3922       82  0.4903
#       genre_disco     0.6250  0.0694    0.1250       72  0.2046
#      genre_hiphop     0.4803  0.3435    0.4005      425  0.3521
#        genre_jazz     0.8365  0.2797    0.4193      311  0.4643
#       genre_metal     0.7941  0.1627    0.2700      166  0.3500
#         genre_pop     0.4326  0.7091    0.5374     1069  0.3511
#      genre_reggae     0.6449  0.3503    0.4539      197  0.4576
#        genre_rock     0.5871  0.5938    0.5904      800  0.4954
#
#          accuracy                       0.5816     4271  0.4782
#         macro avg     0.7192  0.3612    0.4029     4271
#      weighted avg     0.6348  0.5816    0.5594     4271
#               min     0.4326  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_03_mean_icov
#
# Training accuracy: train_accuracy = 0.999649
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.9973  1.0000    0.9987      374  0.9986
#   genre_classical     1.0000  0.9995    0.9998     4221  0.9997
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     0.9988  1.0000    0.9994     1701  0.9993
#        genre_jazz     1.0000  0.9992    0.9996     1241  0.9996
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     0.9998  0.9993    0.9995     4274  0.9994
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     0.9994  1.0000    0.9997     3200  0.9996
#
#          accuracy                       0.9996    17080  0.9996
#         macro avg     0.9995  0.9998    0.9997    17080
#      weighted avg     0.9996  0.9996    0.9996    17080
#               min     0.9973  0.9992    0.9987      289  0.9986
#
# Testing accuracy: test_accuracy = 0.574339
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.8175  0.8493    0.8331     1055  0.7772
#     genre_country     1.0000  0.2073    0.3434       82  0.4518
#       genre_disco     1.0000  0.0556    0.1053       72  0.2338
#      genre_hiphop     0.5495  0.2612    0.3541      425  0.3349
#        genre_jazz     0.6562  0.2701    0.3827      311  0.3947
#       genre_metal     0.7619  0.1928    0.3077      166  0.3728
#         genre_pop     0.4221  0.7474    0.5395     1069  0.3538
#      genre_reggae     0.6721  0.2081    0.3178      197  0.3592
#        genre_rock     0.5659  0.5850    0.5753      800  0.4755
#
#          accuracy                       0.5743     4271  0.4702
#         macro avg     0.7445  0.3387    0.3780     4271
#      weighted avg     0.6347  0.5743    0.5471     4271
#               min     0.4221  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_04_mean_cov_icov
#
# Training accuracy: train_accuracy = 0.999649
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.9973  1.0000    0.9987      374  0.9986
#   genre_classical     1.0000  0.9995    0.9998     4221  0.9997
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     0.9988  1.0000    0.9994     1701  0.9993
#        genre_jazz     1.0000  0.9992    0.9996     1241  0.9996
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     0.9998  0.9993    0.9995     4274  0.9994
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     0.9994  1.0000    0.9997     3200  0.9996
#
#          accuracy                       0.9996    17080  0.9996
#         macro avg     0.9995  0.9998    0.9997    17080
#      weighted avg     0.9996  0.9996    0.9996    17080
#               min     0.9973  0.9992    0.9987      289  0.9986
#
# Testing accuracy: test_accuracy = 0.575275
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.8215  0.8199    0.8207     1055  0.7619
#     genre_country     1.0000  0.2683    0.4231       82  0.5143
#       genre_disco     0.6364  0.0972    0.1687       72  0.2445
#      genre_hiphop     0.4840  0.2847    0.3585      425  0.3203
#        genre_jazz     0.7458  0.2830    0.4103      311  0.4366
#       genre_metal     0.8485  0.1687    0.2814      166  0.3696
#         genre_pop     0.4201  0.7353    0.5347     1069  0.3461
#      genre_reggae     0.7158  0.3452    0.4658      197  0.4815
#        genre_rock     0.5765  0.5887    0.5826      800  0.4851
#
#          accuracy                       0.5753     4271  0.4723
#         macro avg     0.7248  0.3602    0.4067     4271
#      weighted avg     0.6364  0.5753    0.5551     4271
#               min     0.4201  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_05_pvtt
#
# Training accuracy: train_accuracy = 1.000000
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  1.0000    1.0000      374  1.0000
#   genre_classical     1.0000  1.0000    1.0000     4221  1.0000
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     1.0000  1.0000    1.0000     1701  1.0000
#        genre_jazz     1.0000  1.0000    1.0000     1241  1.0000
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     1.0000  1.0000    1.0000     4274  1.0000
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     1.0000  1.0000    1.0000     3200  1.0000
#
#          accuracy                       1.0000    17080  1.0000
#         macro avg     1.0000  1.0000    1.0000    17080
#      weighted avg     1.0000  1.0000    1.0000    17080
#               min     1.0000  1.0000    1.0000      289  1.0000
#
# Testing accuracy: test_accuracy = 0.546710
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5000  0.0106    0.0208       94  0.0705
#   genre_classical     0.8100  0.8768    0.8421     1055  0.7886
#     genre_country     0.7143  0.1220    0.2083       82  0.2905
#       genre_disco     0.4000  0.0833    0.1379       72  0.1767
#      genre_hiphop     0.3787  0.3012    0.3355      425  0.2734
#        genre_jazz     0.4577  0.2958    0.3594      311  0.3292
#       genre_metal     0.5641  0.1325    0.2146      166  0.2609
#         genre_pop     0.4227  0.6165    0.5015     1069  0.3018
#      genre_reggae     0.4070  0.1777    0.2473      197  0.2466
#        genre_rock     0.5223  0.5713    0.5457      800  0.4358
#
#          accuracy                       0.5467     4271  0.4326
#         macro avg     0.5177  0.3188    0.3413     4271
#      weighted avg     0.5469  0.5467    0.5218     4271
#               min     0.3787  0.0106    0.0208       72  0.0705
# Commencing Experiment: RandomForestClassifier_dataset_06_pvtt_mean
#
# Training accuracy: train_accuracy = 1.000000
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  1.0000    1.0000      374  1.0000
#   genre_classical     1.0000  1.0000    1.0000     4221  1.0000
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     1.0000  1.0000    1.0000     1701  1.0000
#        genre_jazz     1.0000  1.0000    1.0000     1241  1.0000
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     1.0000  1.0000    1.0000     4274  1.0000
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     1.0000  1.0000    1.0000     3200  1.0000
#
#          accuracy                       1.0000    17080  1.0000
#         macro avg     1.0000  1.0000    1.0000    17080
#      weighted avg     1.0000  1.0000    1.0000    17080
#               min     1.0000  1.0000    1.0000      289  1.0000
#
# Testing accuracy: test_accuracy = 0.594474
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.8240  0.8787    0.8505     1055  0.8000
#     genre_country     1.0000  0.2561    0.4078       82  0.5024
#       genre_disco     0.7778  0.1944    0.3111       72  0.3845
#      genre_hiphop     0.4765  0.3812    0.4235      425  0.3704
#        genre_jazz     0.6644  0.3119    0.4245      311  0.4283
#       genre_metal     0.9091  0.2410    0.3810      166  0.4594
#         genre_pop     0.4466  0.6969    0.5444     1069  0.3628
#      genre_reggae     0.5658  0.2183    0.3150      197  0.3335
#        genre_rock     0.5877  0.6112    0.5993      800  0.5048
#
#          accuracy                       0.5945     4271  0.4944
#         macro avg     0.7252  0.3800    0.4278     4271
#      weighted avg     0.6370  0.5945    0.5745     4271
#               min     0.4466  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_07_pvtt_mean_cov
#
# Training accuracy: train_accuracy = 1.000000
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  1.0000    1.0000      374  1.0000
#   genre_classical     1.0000  1.0000    1.0000     4221  1.0000
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     1.0000  1.0000    1.0000     1701  1.0000
#        genre_jazz     1.0000  1.0000    1.0000     1241  1.0000
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     1.0000  1.0000    1.0000     4274  1.0000
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     1.0000  1.0000    1.0000     3200  1.0000
#
#          accuracy                       1.0000    17080  1.0000
#         macro avg     1.0000  1.0000    1.0000    17080
#      weighted avg     1.0000  1.0000    1.0000    17080
#               min     1.0000  1.0000    1.0000      289  1.0000
#
# Testing accuracy: test_accuracy = 0.598221
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.8239  0.8825    0.8522     1055  0.8023
#     genre_country     1.0000  0.2195    0.3600       82  0.4650
#       genre_disco     0.8182  0.1250    0.2169       72  0.3163
#      genre_hiphop     0.4848  0.3388    0.3989      425  0.3519
#        genre_jazz     0.7967  0.3151    0.4516      311  0.4798
#       genre_metal     0.8684  0.1988    0.3235      166  0.4067
#         genre_pop     0.4430  0.7203    0.5486     1069  0.3686
#      genre_reggae     0.7048  0.3756    0.4901      197  0.4985
#        genre_rock     0.5889  0.5962    0.5925      800  0.4979
#
#          accuracy                       0.5982     4271  0.4998
#         macro avg     0.7529  0.3783    0.4255     4271
#      weighted avg     0.6522  0.5982    0.5776     4271
#               min     0.4430  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_08_pvtt_mean_icov
#
# Training accuracy: train_accuracy = 1.000000
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  1.0000    1.0000      374  1.0000
#   genre_classical     1.0000  1.0000    1.0000     4221  1.0000
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     1.0000  1.0000    1.0000     1701  1.0000
#        genre_jazz     1.0000  1.0000    1.0000     1241  1.0000
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     1.0000  1.0000    1.0000     4274  1.0000
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     1.0000  1.0000    1.0000     3200  1.0000
#
#          accuracy                       1.0000    17080  1.0000
#         macro avg     1.0000  1.0000    1.0000    17080
#      weighted avg     1.0000  1.0000    1.0000    17080
#               min     1.0000  1.0000    1.0000      289  1.0000
#
# Testing accuracy: test_accuracy = 0.585577
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.8354  0.8806    0.8574     1055  0.8095
#     genre_country     1.0000  0.2317    0.3762       82  0.4778
#       genre_disco     0.8571  0.0833    0.1519       72  0.2645
#      genre_hiphop     0.5395  0.2729    0.3625      425  0.3384
#        genre_jazz     0.6149  0.2926    0.3965      311  0.3952
#       genre_metal     0.8235  0.1687    0.2800      166  0.3637
#         genre_pop     0.4266  0.7287    0.5382     1069  0.3518
#      genre_reggae     0.6418  0.2183    0.3258      197  0.3585
#        genre_rock     0.5808  0.6112    0.5956      800  0.4997
#
#          accuracy                       0.5856     4271  0.4840
#         macro avg     0.7320  0.3499    0.3905     4271
#      weighted avg     0.6377  0.5856    0.5592     4271
#               min     0.4266  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_09_pvtt_mean_cov_icov
#
# Training accuracy: train_accuracy = 1.000000
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  1.0000    1.0000      374  1.0000
#   genre_classical     1.0000  1.0000    1.0000     4221  1.0000
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     1.0000  1.0000    1.0000     1701  1.0000
#        genre_jazz     1.0000  1.0000    1.0000     1241  1.0000
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     1.0000  1.0000    1.0000     4274  1.0000
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     1.0000  1.0000    1.0000     3200  1.0000
#
#          accuracy                       1.0000    17080  1.0000
#         macro avg     1.0000  1.0000    1.0000    17080
#      weighted avg     1.0000  1.0000    1.0000    17080
#               min     1.0000  1.0000    1.0000      289  1.0000
#
# Testing accuracy: test_accuracy = 0.601967
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0106    0.0211       94  0.1020
#   genre_classical     0.8413  0.8796    0.8601     1055  0.8131
#     genre_country     1.0000  0.2561    0.4078       82  0.5024
#       genre_disco     0.7273  0.1111    0.1928       72  0.2804
#      genre_hiphop     0.5144  0.3365    0.4068      425  0.3657
#        genre_jazz     0.7462  0.3119    0.4399      311  0.4591
#       genre_metal     0.8095  0.2048    0.3269      166  0.3974
#         genre_pop     0.4453  0.7381    0.5554     1069  0.3790
#      genre_reggae     0.7419  0.3503    0.4759      197  0.4949
#        genre_rock     0.5866  0.6012    0.5938      800  0.4988
#
#          accuracy                       0.6020     4271  0.5053
#         macro avg     0.7412  0.3800    0.4280     4271
#      weighted avg     0.6538  0.6020    0.5814     4271
#               min     0.4453  0.0106    0.0211       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_10_melspecs_flat
#
# Training accuracy: train_accuracy = 0.999063
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.9973  1.0000    0.9987      374  0.9986
#   genre_classical     0.9993  0.9993    0.9993     4221  0.9991
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     0.9988  0.9994    0.9991     1701  0.9990
#        genre_jazz     1.0000  0.9992    0.9996     1241  0.9996
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     0.9995  0.9981    0.9988     4274  0.9984
#      genre_reggae     0.9937  1.0000    0.9968      788  0.9967
#        genre_rock     0.9991  0.9991    0.9991     3200  0.9988
#
#          accuracy                       0.9991    17080  0.9989
#         macro avg     0.9988  0.9995    0.9991    17080
#      weighted avg     0.9991  0.9991    0.9991    17080
#               min     0.9937  0.9981    0.9968      289  0.9967
#
# Testing accuracy: test_accuracy = 0.495434
#
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.6667  0.0213    0.0412       94   0.1165
#   genre_classical     0.7422  0.7886    0.7647     1055   0.6849
#     genre_country     0.0000  0.0000    0.0000       82   0.0000
#       genre_disco     1.0000  0.0278    0.0541       72   0.1653
#      genre_hiphop     0.5082  0.0729    0.1276      425   0.1643
#        genre_jazz     0.4639  0.1447    0.2206      311   0.2295
#       genre_metal     0.6111  0.1325    0.2178      166   0.2730
#         genre_pop     0.3515  0.6932    0.4665     1069   0.2307
#      genre_reggae     0.0000  0.0000    0.0000      197  -0.0034
#        genre_rock     0.5238  0.5513    0.5371      800   0.4273
#
#          accuracy                       0.4954     4271   0.3656
#         macro avg     0.4867  0.2432    0.2430     4271
#      weighted avg     0.5091  0.4954    0.4453     4271
#               min     0.0000  0.0000    0.0000       72  -0.0034
# /Users/rerobbins/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rerobbins/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rerobbins/opt/anaconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
