# %%
import glob
import sys

import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier

sys.path.append("../../../")

from helpers.experiment import experiment

# %%
dataset_folder = "../../../datasets/"
datasets = sorted([name for name in glob.glob(dataset_folder + "dataset_*.pickle")])

for dataset in datasets:
    
    if "spectrogram" in dataset:
        n_components = 2400
    else:
        n_components = .95        
    
    model = RandomForestClassifier(max_depth=9, min_samples_leaf=1, class_weight='balanced')
    experiment(model, dataset, pca_components=n_components, result_filename="rich_results.json")
# Out:
# Commencing Experiment: RandomForestClassifier_dataset_00_all
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.746253
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.8372  0.9759    0.9012      374  0.9016
#   genre_classical     0.8747  0.9064    0.8903     4221  0.8537
#     genre_country     0.7403  0.9939    0.8486      327  0.8548
#       genre_disco     0.7559  0.9965    0.8597      289  0.8655
#      genre_hiphop     0.6700  0.9130    0.7728     1701  0.7548
#        genre_jazz     0.5660  0.8912    0.6923     1241  0.6831
#       genre_metal     0.5449  0.9308    0.6874      665  0.6982
#         genre_pop     0.8233  0.4808    0.6071     4274  0.5474
#      genre_reggae     0.6437  0.9264    0.7596      788  0.7597
#        genre_rock     0.7790  0.5872    0.6696     3200  0.6149
#
#          accuracy                       0.7463    17080  0.7070
#         macro avg     0.7235  0.8602    0.7689    17080
#      weighted avg     0.7722  0.7463    0.7370    17080
#               min     0.5449  0.4808    0.6071      289  0.5474
#
# Testing accuracy: test_accuracy = 0.543198
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.2368  0.0957    0.1364       94  0.1387
#   genre_classical     0.7481  0.8616    0.8009     1055  0.7327
#     genre_country     0.4167  0.4878    0.4494       82  0.4392
#       genre_disco     0.3529  0.3333    0.3429       72  0.3321
#      genre_hiphop     0.4490  0.6635    0.5356      425  0.4848
#        genre_jazz     0.3433  0.5916    0.4345      311  0.3943
#       genre_metal     0.3891  0.7289    0.5073      166  0.5078
#         genre_pop     0.5996  0.2675    0.3700     1069  0.2859
#      genre_reggae     0.3805  0.6142    0.4699      197  0.4521
#        genre_rock     0.5890  0.4300    0.4971      800  0.4098
#
#          accuracy                       0.5432     4271  0.4680
#         macro avg     0.4505  0.5074    0.4544     4271
#      weighted avg     0.5667  0.5432    0.5273     4271
#               min     0.2368  0.0957    0.1364       72  0.1387
# Commencing Experiment: RandomForestClassifier_dataset_01_mean
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.547365
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.6208  0.7834    0.6927      374  0.6899
#   genre_classical     0.8098  0.8320    0.8208     4221  0.7610
#     genre_country     0.4252  0.8777    0.5729      327  0.6010
#       genre_disco     0.2650  0.9031    0.4097      289  0.4758
#      genre_hiphop     0.4782  0.3739    0.4197     1701  0.3674
#        genre_jazz     0.3691  0.6406    0.4683     1241  0.4338
#       genre_metal     0.3769  0.8496    0.5222      665  0.5419
#         genre_pop     0.7193  0.2602    0.3821     4274  0.3416
#      genre_reggae     0.2880  0.7069    0.4093      788  0.4120
#        genre_rock     0.6196  0.4159    0.4978     3200  0.4202
#
#          accuracy                       0.5474    17080  0.4875
#         macro avg     0.4972  0.6643    0.5195    17080
#      weighted avg     0.6248  0.5474    0.5398    17080
#               min     0.2650  0.2602    0.3821      289  0.3416
#
# Testing accuracy: test_accuracy = 0.435027
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0741  0.0426    0.0541       94  0.0402
#   genre_classical     0.7485  0.8237    0.7843     1055  0.7104
#     genre_country     0.1694  0.3780    0.2340       82  0.2316
#       genre_disco     0.1239  0.3889    0.1879       72  0.1965
#      genre_hiphop     0.3271  0.2471    0.2815      425  0.2167
#        genre_jazz     0.2608  0.4469    0.3294      311  0.2732
#       genre_metal     0.2913  0.6687    0.4059      166  0.4088
#         genre_pop     0.5691  0.1964    0.2921     1069  0.2263
#      genre_reggae     0.1746  0.4112    0.2451      197  0.2138
#        genre_rock     0.4836  0.3500    0.4061      800  0.3007
#
#          accuracy                       0.4350     4271  0.3507
#         macro avg     0.3222  0.3953    0.3220     4271
#      weighted avg     0.4958  0.4350    0.4308     4271
#               min     0.0741  0.0426    0.0541       72  0.0402
# Commencing Experiment: RandomForestClassifier_dataset_02_mean_cov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.636710
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5504  0.9492    0.6968      374  0.7154
#   genre_classical     0.8351  0.8290    0.8320     4221  0.7771
#     genre_country     0.4922  0.9694    0.6529      327  0.6834
#       genre_disco     0.4930  0.9792    0.6559      289  0.6884
#      genre_hiphop     0.5821  0.7419    0.6524     1701  0.6144
#        genre_jazz     0.5208  0.7953    0.6295     1241  0.6099
#       genre_metal     0.4076  0.9549    0.5713      665  0.6038
#         genre_pop     0.8604  0.2840    0.4271     4274  0.4227
#      genre_reggae     0.5330  0.9023    0.6701      788  0.6755
#        genre_rock     0.6058  0.5038    0.5501     3200  0.4607
#
#          accuracy                       0.6367    17080  0.5898
#         macro avg     0.5880  0.7909    0.6338    17080
#      weighted avg     0.7013  0.6367    0.6183    17080
#               min     0.4076  0.2840    0.4271      289  0.4227
#
# Testing accuracy: test_accuracy = 0.458441
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1176  0.1277    0.1224       94  0.1020
#   genre_classical     0.7380  0.7877    0.7620     1055  0.6812
#     genre_country     0.2390  0.4634    0.3154       82  0.3150
#       genre_disco     0.2180  0.4028    0.2829       72  0.2802
#      genre_hiphop     0.3054  0.4541    0.3652      425  0.2866
#        genre_jazz     0.3242  0.4920    0.3908      311  0.3410
#       genre_metal     0.3051  0.7169    0.4281      166  0.4367
#         genre_pop     0.5823  0.1291    0.2113     1069  0.1858
#      genre_reggae     0.3379  0.6294    0.4397      197  0.4265
#        genre_rock     0.4916  0.4012    0.4418      800  0.3313
#
#          accuracy                       0.4584     4271  0.3812
#         macro avg     0.3659  0.4604    0.3760     4271
#      weighted avg     0.5124  0.4584    0.4391     4271
#               min     0.1176  0.1277    0.1224       72  0.1020
# Commencing Experiment: RandomForestClassifier_dataset_03_mean_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.415749
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.4793  0.4947    0.4868      374  0.4752
#   genre_classical     0.7667  0.6804    0.7210     4221  0.6384
#     genre_country     0.1513  0.7431    0.2514      327  0.3107
#       genre_disco     0.2040  0.7128    0.3172      289  0.3636
#      genre_hiphop     0.4127  0.2640    0.3220     1701  0.2727
#        genre_jazz     0.2631  0.5552    0.3570     1241  0.3122
#       genre_metal     0.2940  0.7895    0.4284      665  0.4505
#         genre_pop     0.5786  0.0999    0.1704     4274  0.1611
#      genre_reggae     0.2113  0.6206    0.3153      788  0.3117
#        genre_rock     0.5686  0.3175    0.4075     3200  0.3340
#
#          accuracy                       0.4157    17080  0.3551
#         macro avg     0.3929  0.5278    0.3777    17080
#      weighted avg     0.5390  0.4157    0.4072    17080
#               min     0.1513  0.0999    0.1704      289  0.1611
#
# Testing accuracy: test_accuracy = 0.347460
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0571  0.0426    0.0488       94  0.0309
#   genre_classical     0.7369  0.6825    0.7087     1055  0.6187
#     genre_country     0.0713  0.3659    0.1193       82  0.1255
#       genre_disco     0.0759  0.2500    0.1165       72  0.1113
#      genre_hiphop     0.2822  0.1600    0.2042      425  0.1492
#        genre_jazz     0.2271  0.4952    0.3114      311  0.2580
#       genre_metal     0.2534  0.6687    0.3675      166  0.3753
#         genre_pop     0.4524  0.0711    0.1229     1069  0.0944
#      genre_reggae     0.1634  0.4721    0.2428      197  0.2193
#        genre_rock     0.4449  0.2625    0.3302      800  0.2327
#
#          accuracy                       0.3475     4271  0.2729
#         macro avg     0.2765  0.3470    0.2572     4271
#      weighted avg     0.4445  0.3475    0.3415     4271
#               min     0.0571  0.0426    0.0488       72  0.0309
# Commencing Experiment: RandomForestClassifier_dataset_04_mean_cov_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.596897
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5293  0.9171    0.6712      374  0.6885
#   genre_classical     0.8404  0.7934    0.8162     4221  0.7587
#     genre_country     0.3921  0.9450    0.5543      327  0.5986
#       genre_disco     0.3915  0.9550    0.5553      289  0.6026
#      genre_hiphop     0.5015  0.6802    0.5773     1701  0.5304
#        genre_jazz     0.4870  0.7679    0.5960     1241  0.5742
#       genre_metal     0.3829  0.9338    0.5431      665  0.5759
#         genre_pop     0.8664  0.2230    0.3547     4274  0.3732
#      genre_reggae     0.5112  0.8693    0.6438      788  0.6468
#        genre_rock     0.5894  0.4841    0.5316     3200  0.4394
#
#          accuracy                       0.5969    17080  0.5488
#         macro avg     0.5492  0.7569    0.5844    17080
#      weighted avg     0.6845  0.5969    0.5764    17080
#               min     0.3829  0.2230    0.3547      289  0.3732
#
# Testing accuracy: test_accuracy = 0.427066
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0862  0.1064    0.0952       94  0.0731
#   genre_classical     0.7375  0.7431    0.7403     1055  0.6547
#     genre_country     0.1896  0.4878    0.2730       82  0.2830
#       genre_disco     0.1385  0.3750    0.2022       72  0.2066
#      genre_hiphop     0.2779  0.4282    0.3370      425  0.2536
#        genre_jazz     0.3217  0.4759    0.3839      311  0.3328
#       genre_metal     0.2916  0.6867    0.4093      166  0.4150
#         genre_pop     0.6080  0.1001    0.1719     1069  0.1712
#      genre_reggae     0.3235  0.6142    0.4238      197  0.4097
#        genre_rock     0.4619  0.3638    0.4070      800  0.2928
#
#          accuracy                       0.4271     4271  0.3509
#         macro avg     0.3436  0.4381    0.3444     4271
#      weighted avg     0.5061  0.4271    0.4098     4271
#               min     0.0862  0.1001    0.0952       72  0.0731
# Commencing Experiment: RandomForestClassifier_dataset_05_pvtt
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.467916
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.2415  0.4920    0.3239      374  0.3242
#   genre_classical     0.8756  0.8391    0.8570     4221  0.8117
#     genre_country     0.1509  0.6820    0.2471      327  0.2959
#       genre_disco     0.3073  0.5571    0.3961      289  0.4005
#      genre_hiphop     0.4140  0.1981    0.2680     1701  0.2349
#        genre_jazz     0.2955  0.6132    0.3988     1241  0.3618
#       genre_metal     0.2940  0.7895    0.4284      665  0.4505
#         genre_pop     0.6278  0.1788    0.2783     4274  0.2414
#      genre_reggae     0.2309  0.6624    0.3424      788  0.3440
#        genre_rock     0.6014  0.3041    0.4039     3200  0.3432
#
#          accuracy                       0.4679    17080  0.4088
#         macro avg     0.4039  0.5316    0.3944    17080
#      weighted avg     0.5843  0.4679    0.4638    17080
#               min     0.1509  0.1788    0.2471      289  0.2349
#
# Testing accuracy: test_accuracy = 0.402482
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0785  0.1596    0.1053       94  0.0834
#   genre_classical     0.8253  0.8417    0.8334     1055  0.7781
#     genre_country     0.0623  0.2805    0.1020       82  0.0967
#       genre_disco     0.1565  0.2500    0.1925       72  0.1805
#      genre_hiphop     0.3081  0.1247    0.1776      425  0.1428
#        genre_jazz     0.2426  0.5016    0.3270      311  0.2751
#       genre_metal     0.2400  0.6145    0.3452      166  0.3459
#         genre_pop     0.5451  0.1469    0.2314     1069  0.1830
#      genre_reggae     0.1701  0.4670    0.2493      197  0.2250
#        genre_rock     0.4767  0.2687    0.3437      800  0.2549
#
#          accuracy                       0.4025     4271  0.3281
#         macro avg     0.3105  0.3655    0.2907     4271
#      weighted avg     0.5007  0.4025    0.4021     4271
#               min     0.0623  0.1247    0.1020       72  0.0834
# Commencing Experiment: RandomForestClassifier_dataset_06_pvtt_mean
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.558548
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5975  0.7620    0.6698      374  0.6666
#   genre_classical     0.8644  0.8548    0.8596     4221  0.8138
#     genre_country     0.3527  0.8532    0.4991      327  0.5364
#       genre_disco     0.3029  0.9170    0.4553      289  0.5152
#      genre_hiphop     0.4542  0.3851    0.4168     1701  0.3596
#        genre_jazz     0.3489  0.6962    0.4649     1241  0.4383
#       genre_metal     0.3728  0.8526    0.5188      665  0.5396
#         genre_pop     0.7554  0.2277    0.3499     4274  0.3331
#      genre_reggae     0.3312  0.7703    0.4632      788  0.4711
#        genre_rock     0.6523  0.4491    0.5319     3200  0.4585
#
#          accuracy                       0.5585    17080  0.5048
#         macro avg     0.5032  0.6768    0.5229    17080
#      weighted avg     0.6502  0.5585    0.5484    17080
#               min     0.3029  0.2277    0.3499      289  0.3331
#
# Testing accuracy: test_accuracy = 0.463123
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1250  0.0957    0.1084       94  0.0919
#   genre_classical     0.7963  0.8521    0.8233     1055  0.7634
#     genre_country     0.1976  0.4024    0.2651       82  0.2623
#       genre_disco     0.1498  0.4306    0.2222       72  0.2330
#      genre_hiphop     0.3414  0.2659    0.2989      425  0.2342
#        genre_jazz     0.2684  0.5498    0.3608      311  0.3152
#       genre_metal     0.3179  0.7048    0.4382      166  0.4434
#         genre_pop     0.5969  0.1787    0.2750     1069  0.2277
#      genre_reggae     0.2169  0.5076    0.3040      197  0.2832
#        genre_rock     0.5423  0.3925    0.4554      800  0.3603
#
#          accuracy                       0.4631     4271  0.3877
#         macro avg     0.3553  0.4380    0.3551     4271
#      weighted avg     0.5326  0.4631    0.4558     4271
#               min     0.1250  0.0957    0.1084       72  0.0919
# Commencing Experiment: RandomForestClassifier_dataset_07_pvtt_mean_cov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.656850
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5463  0.9305    0.6884      374  0.7053
#   genre_classical     0.8463  0.8794    0.8626     4221  0.8165
#     genre_country     0.4577  0.9755    0.6230      327  0.6601
#       genre_disco     0.4563  0.9758    0.6218      289  0.6601
#      genre_hiphop     0.6231  0.7531    0.6819     1701  0.6467
#        genre_jazz     0.5325  0.8308    0.6490     1241  0.6335
#       genre_metal     0.4351  0.9474    0.5963      665  0.6233
#         genre_pop     0.8783  0.2770    0.4212     4274  0.4245
#      genre_reggae     0.5269  0.9061    0.6664      788  0.6728
#        genre_rock     0.6610  0.5369    0.5925     3200  0.5143
#
#          accuracy                       0.6569    17080  0.6139
#         macro avg     0.5964  0.8012    0.6403    17080
#      weighted avg     0.7232  0.6569    0.6361    17080
#               min     0.4351  0.2770    0.4212      289  0.4245
#
# Testing accuracy: test_accuracy = 0.476469
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1753  0.1809    0.1780       94  0.1592
#   genre_classical     0.7531  0.8559    0.8012     1055  0.7331
#     genre_country     0.2283  0.5122    0.3158       82  0.3233
#       genre_disco     0.1753  0.3750    0.2389       72  0.2381
#      genre_hiphop     0.3375  0.4471    0.3846      425  0.3098
#        genre_jazz     0.3362  0.5113    0.4056      311  0.3577
#       genre_metal     0.3120  0.6747    0.4267      166  0.4281
#         genre_pop     0.6274  0.1244    0.2077     1069  0.1989
#      genre_reggae     0.3370  0.6193    0.4365      197  0.4220
#        genre_rock     0.4940  0.4125    0.4496      800  0.3385
#
#          accuracy                       0.4765     4271  0.4019
#         macro avg     0.3776  0.4713    0.3845     4271
#      weighted avg     0.5325  0.4765    0.4526     4271
#               min     0.1753  0.1244    0.1780       72  0.1592
# Commencing Experiment: RandomForestClassifier_dataset_08_pvtt_mean_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.479157
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.3565  0.5214    0.4235      374  0.4159
#   genre_classical     0.8680  0.8332    0.8502     4221  0.8027
#     genre_country     0.1763  0.7554    0.2859      327  0.3428
#       genre_disco     0.2360  0.6574    0.3473      289  0.3778
#      genre_hiphop     0.3795  0.2563    0.3060     1701  0.2510
#        genre_jazz     0.2852  0.5842    0.3833     1241  0.3424
#       genre_metal     0.3517  0.7789    0.4846      665  0.4967
#         genre_pop     0.7024  0.1104    0.1909     4274  0.2113
#      genre_reggae     0.2660  0.7221    0.3888      788  0.3966
#        genre_rock     0.5717  0.4109    0.4782     3200  0.3886
#
#          accuracy                       0.4792    17080  0.4223
#         macro avg     0.4193  0.5630    0.4139    17080
#      weighted avg     0.5970  0.4792    0.4632    17080
#               min     0.1763  0.1104    0.1909      289  0.2113
#
# Testing accuracy: test_accuracy = 0.410677
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0545  0.0638    0.0588       94  0.0361
#   genre_classical     0.8233  0.8389    0.8310     1055  0.7749
#     genre_country     0.0769  0.3293    0.1247       82  0.1259
#       genre_disco     0.1217  0.3194    0.1762       72  0.1752
#      genre_hiphop     0.2963  0.1882    0.2302      425  0.1708
#        genre_jazz     0.2419  0.5048    0.3271      311  0.2755
#       genre_metal     0.2951  0.6506    0.4060      166  0.4058
#         genre_pop     0.4756  0.0730    0.1265     1069  0.1039
#      genre_reggae     0.2034  0.5431    0.2960      197  0.2810
#        genre_rock     0.4956  0.3538    0.4128      800  0.3104
#
#          accuracy                       0.4107     4271  0.3390
#         macro avg     0.3084  0.3865    0.2989     4271
#      weighted avg     0.4879  0.4107    0.3971     4271
#               min     0.0545  0.0638    0.0588       72  0.0361
# Commencing Experiment: RandomForestClassifier_dataset_09_pvtt_mean_cov_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.606265
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.4230  0.9251    0.5805      374  0.6147
#   genre_classical     0.8503  0.8491    0.8497     4221  0.8004
#     genre_country     0.3829  0.9297    0.5424      327  0.5861
#       genre_disco     0.3874  0.9585    0.5518      289  0.6004
#      genre_hiphop     0.5332  0.6802    0.5978     1701  0.5524
#        genre_jazz     0.4856  0.7631    0.5935     1241  0.5712
#       genre_metal     0.3968  0.9278    0.5559      665  0.5855
#         genre_pop     0.8908  0.2024    0.3298     4274  0.3631
#      genre_reggae     0.4905  0.8541    0.6231      788  0.6261
#        genre_rock     0.6290  0.4953    0.5542     3200  0.4708
#
#          accuracy                       0.6063    17080  0.5610
#         macro avg     0.5469  0.7585    0.5779    17080
#      weighted avg     0.7005  0.6063    0.5818    17080
#               min     0.3829  0.2024    0.3298      289  0.3631
#
# Testing accuracy: test_accuracy = 0.448139
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1176  0.1702    0.1391       94  0.1182
#   genre_classical     0.7778  0.8095    0.7933     1055  0.7240
#     genre_country     0.1805  0.4512    0.2578       82  0.2639
#       genre_disco     0.1742  0.4306    0.2480       72  0.2548
#      genre_hiphop     0.3207  0.4588    0.3775      425  0.3011
#        genre_jazz     0.3239  0.5145    0.3975      311  0.3495
#       genre_metal     0.3003  0.6747    0.4156      166  0.4184
#         genre_pop     0.5352  0.0711    0.1255     1069  0.1220
#      genre_reggae     0.3163  0.6294    0.4211      197  0.4095
#        genre_rock     0.4791  0.3862    0.4277      800  0.3154
#
#          accuracy                       0.4481     4271  0.3764
#         macro avg     0.3526  0.4596    0.3603     4271
#      weighted avg     0.5066  0.4481    0.4218     4271
#               min     0.1176  0.0711    0.1255       72  0.1182
# Commencing Experiment: RandomForestClassifier_dataset_10_melspectrograms_flattened
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.679684
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.9307  0.9332    0.9319      374  0.9304
#   genre_classical     0.7981  0.8242    0.8110     4221  0.7477
#     genre_country     0.9906  0.9664    0.9783      327  0.9780
#       genre_disco     1.0000  0.9723    0.9860      289  0.9858
#      genre_hiphop     0.7806  0.8348    0.8068     1701  0.7852
#        genre_jazz     0.6511  0.8977    0.7547     1241  0.7435
#       genre_metal     0.1848  0.9489    0.3093      665  0.3769
#         genre_pop     0.8615  0.5604    0.6790     4274  0.6222
#      genre_reggae     0.9250  0.9543    0.9394      788  0.9366
#        genre_rock     0.7219  0.2725    0.3956     3200  0.3779
#
#          accuracy                       0.6797    17080  0.6430
#         macro avg     0.7844  0.8165    0.7592    17080
#      weighted avg     0.7792  0.6797    0.6909    17080
#               min     0.1848  0.2725    0.3093      289  0.3769
#
# Testing accuracy: test_accuracy = 0.345587
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.1111  0.0213    0.0357       94   0.0395
#   genre_classical     0.6166  0.7621    0.6816     1055   0.5681
#     genre_country     0.0000  0.0000    0.0000       82  -0.0030
#       genre_disco     1.0000  0.0139    0.0274       72   0.1169
#      genre_hiphop     0.2586  0.2824    0.2700      425   0.1856
#        genre_jazz     0.2048  0.3537    0.2594      311   0.1927
#       genre_metal     0.1275  0.8313    0.2212      166   0.2672
#         genre_pop     0.3902  0.1862    0.2521     1069   0.1189
#      genre_reggae     0.1932  0.0863    0.1193      197   0.1017
#        genre_rock     0.3208  0.1062    0.1596      800   0.0880
#
#          accuracy                       0.3456     4271   0.2446
#         macro avg     0.3223  0.2643    0.2026     4271
#      weighted avg     0.3839  0.3456    0.3225     4271
#               min     0.0000  0.0000    0.0000       72  -0.0030
