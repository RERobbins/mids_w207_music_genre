# %%
import glob
import sys

import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier

sys.path.append("../../../")

from helpers.experiment import experiment

# %%
dataset_folder = "../../../datasets/"
datasets = sorted([name for name in glob.glob(dataset_folder + "dataset_*.pickle")])

for dataset in datasets:
    
    if "spectrogram" in dataset:
        n_components = 2400
    else:
        n_components = .95        
    
    model = RandomForestClassifier(max_depth=7, class_weight='balanced')
    experiment(model, dataset, pca_components=n_components, result_filename="rich_results.json")
# Out:
# Commencing Experiment: RandomForestClassifier_dataset_00_all
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.565867
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.3556  0.8824    0.5069      374  0.5466
#   genre_classical     0.8377  0.8410    0.8393     4221  0.7865
#     genre_country     0.3322  0.9174    0.4878      327  0.5398
#       genre_disco     0.3859  0.9827    0.5541      289  0.6071
#      genre_hiphop     0.5816  0.7125    0.6404     1701  0.6000
#        genre_jazz     0.4029  0.7639    0.5275     1241  0.5085
#       genre_metal     0.3369  0.8617    0.4844      665  0.5122
#         genre_pop     0.7019  0.1631    0.2647     4274  0.2591
#      genre_reggae     0.4318  0.8439    0.5713      788  0.5788
#        genre_rock     0.6895  0.3456    0.4604     3200  0.4143
#
#          accuracy                       0.5659    17080  0.5207
#         macro avg     0.5056  0.7314    0.5337    17080
#      weighted avg     0.6527  0.5659    0.5371    17080
#               min     0.3322  0.1631    0.2647      289  0.2591
#
# Testing accuracy: test_accuracy = 0.478811
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0674  0.1383    0.0906       94  0.0672
#   genre_classical     0.7873  0.8455    0.8154     1055  0.7527
#     genre_country     0.2222  0.5854    0.3221       82  0.3415
#       genre_disco     0.2138  0.4722    0.2944       72  0.3009
#      genre_hiphop     0.4713  0.5600    0.5118      425  0.4548
#        genre_jazz     0.3234  0.6270    0.4267      311  0.3910
#       genre_metal     0.2964  0.7892    0.4309      166  0.4527
#         genre_pop     0.6181  0.1151    0.1940     1069  0.1877
#      genre_reggae     0.3225  0.6548    0.4322      197  0.4235
#        genre_rock     0.5748  0.3025    0.3964      800  0.3284
#
#          accuracy                       0.4788     4271  0.4171
#         macro avg     0.3897  0.5090    0.3914     4271
#      weighted avg     0.5630  0.4788    0.4560     4271
#               min     0.0674  0.1151    0.0906       72  0.0672
# Commencing Experiment: RandomForestClassifier_dataset_01_mean
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.410480
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.3160  0.4706    0.3781      374  0.3689
#   genre_classical     0.7827  0.7749    0.7788     4221  0.7067
#     genre_country     0.1743  0.7492    0.2827      327  0.3390
#       genre_disco     0.1495  0.6920    0.2459      289  0.2996
#      genre_hiphop     0.3743  0.2005    0.2611     1701  0.2178
#        genre_jazz     0.2690  0.4899    0.3473     1241  0.2954
#       genre_metal     0.2508  0.8015    0.3821      665  0.4129
#         genre_pop     0.6368  0.1165    0.1970     4274  0.1955
#      genre_reggae     0.2062  0.5584    0.3012      788  0.2883
#        genre_rock     0.5036  0.2184    0.3047     3200  0.2410
#
#          accuracy                       0.4105    17080  0.3488
#         macro avg     0.3663  0.5072    0.3479    17080
#      weighted avg     0.5360  0.4105    0.3967    17080
#               min     0.1495  0.1165    0.1970      289  0.1955
#
# Testing accuracy: test_accuracy = 0.372746
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0893  0.1064    0.0971       94  0.0753
#   genre_classical     0.7491  0.7754    0.7620     1055  0.6823
#     genre_country     0.1022  0.4512    0.1667       82  0.1841
#       genre_disco     0.0938  0.4167    0.1531       72  0.1700
#      genre_hiphop     0.3562  0.1953    0.2523      425  0.2060
#        genre_jazz     0.2532  0.4437    0.3224      311  0.2655
#       genre_metal     0.2237  0.7289    0.3423      166  0.3641
#         genre_pop     0.5556  0.0935    0.1601     1069  0.1478
#      genre_reggae     0.1553  0.4162    0.2262      197  0.1955
#        genre_rock     0.4832  0.2162    0.2988      800  0.2294
#
#          accuracy                       0.3727     4271  0.3026
#         macro avg     0.3062  0.3844    0.2781     4271
#      weighted avg     0.4899  0.3727    0.3645     4271
#               min     0.0893  0.0935    0.0971       72  0.0753
# Commencing Experiment: RandomForestClassifier_dataset_02_mean_cov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.457436
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.2689  0.7139    0.3906      374  0.4193
#   genre_classical     0.7721  0.7771    0.7746     4221  0.7003
#     genre_country     0.2289  0.8379    0.3596      327  0.4202
#       genre_disco     0.2105  0.9031    0.3414      289  0.4199
#      genre_hiphop     0.4483  0.4562    0.4522     1701  0.3911
#        genre_jazz     0.4052  0.5802    0.4771     1241  0.4365
#       genre_metal     0.2516  0.8541    0.3886      665  0.4290
#         genre_pop     0.7405  0.0501    0.0938     4274  0.1485
#      genre_reggae     0.3752  0.8071    0.5123      788  0.5207
#        genre_rock     0.4946  0.2553    0.3368     3200  0.2576
#
#          accuracy                       0.4574    17080  0.4059
#         macro avg     0.4196  0.6235    0.4127    17080
#      weighted avg     0.5838  0.4574    0.4177    17080
#               min     0.2105  0.0501    0.0938      289  0.1485
#
# Testing accuracy: test_accuracy = 0.383048
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0777  0.1596    0.1045       94  0.0826
#   genre_classical     0.7350  0.7545    0.7446     1055  0.6595
#     genre_country     0.1498  0.5244    0.2331       82  0.2555
#       genre_disco     0.1156  0.5556    0.1914       72  0.2277
#      genre_hiphop     0.2840  0.2847    0.2844      425  0.2052
#        genre_jazz     0.3028  0.4244    0.3534      311  0.2984
#       genre_metal     0.2299  0.7590    0.3529      166  0.3793
#         genre_pop     0.6452  0.0374    0.0707     1069  0.1106
#      genre_reggae     0.2742  0.6193    0.3801      197  0.3708
#        genre_rock     0.4517  0.2512    0.3229      800  0.2311
#
#          accuracy                       0.3830     4271  0.3164
#         macro avg     0.3266  0.4370    0.3038     4271
#      weighted avg     0.5061  0.3830    0.3574     4271
#               min     0.0777  0.0374    0.0707       72  0.0826
# Commencing Experiment: RandomForestClassifier_dataset_03_mean_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.332319
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.2923  0.2219    0.2523      374  0.2402
#   genre_classical     0.7397  0.6442    0.6886     4221  0.5980
#     genre_country     0.0858  0.5474    0.1484      327  0.1815
#       genre_disco     0.1055  0.4083    0.1676      289  0.1818
#      genre_hiphop     0.3416  0.1382    0.1967     1701  0.1655
#        genre_jazz     0.2237  0.5270    0.3140     1241  0.2644
#       genre_metal     0.2344  0.7729    0.3597      665  0.3878
#         genre_pop     0.4485  0.0143    0.0277     4274  0.0410
#      genre_reggae     0.1666  0.5622    0.2570      788  0.2466
#        genre_rock     0.5095  0.2094    0.2968     3200  0.2384
#
#          accuracy                       0.3323    17080  0.2746
#         macro avg     0.3147  0.4046    0.2709    17080
#      weighted avg     0.4674  0.3323    0.3122    17080
#               min     0.0858  0.0143    0.0277      289  0.0410
#
# Testing accuracy: test_accuracy = 0.311871
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0339  0.0213    0.0261       94  0.0096
#   genre_classical     0.7302  0.6464    0.6858     1055  0.5927
#     genre_country     0.0547  0.3537    0.0948       82  0.0974
#       genre_disco     0.0657  0.2500    0.1040       72  0.0993
#      genre_hiphop     0.3290  0.1200    0.1759      425  0.1488
#        genre_jazz     0.2079  0.5048    0.2946      311  0.2410
#       genre_metal     0.2232  0.7289    0.3418      166  0.3637
#         genre_pop     0.3659  0.0140    0.0270     1069  0.0263
#      genre_reggae     0.1561  0.5127    0.2393      197  0.2215
#        genre_rock     0.4671  0.1950    0.2751      800  0.2088
#
#          accuracy                       0.3119     4271  0.2490
#         macro avg     0.2634  0.3347    0.2264     4271
#      weighted avg     0.4261  0.3119    0.2951     4271
#               min     0.0339  0.0140    0.0261       72  0.0096
# Commencing Experiment: RandomForestClassifier_dataset_04_mean_cov_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.418384
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.2041  0.6150    0.3065      374  0.3309
#   genre_classical     0.7930  0.7081    0.7482     4221  0.6735
#     genre_country     0.1907  0.7859    0.3069      327  0.3664
#       genre_disco     0.1703  0.8547    0.2841      289  0.3623
#      genre_hiphop     0.3818  0.3998    0.3906     1701  0.3216
#        genre_jazz     0.3658  0.5238    0.4307     1241  0.3848
#       genre_metal     0.2458  0.8361    0.3799      665  0.4178
#         genre_pop     0.6840  0.0339    0.0646     4274  0.1123
#      genre_reggae     0.3529  0.7690    0.4838      788  0.4889
#        genre_rock     0.4801  0.2456    0.3250     3200  0.2443
#
#          accuracy                       0.4184    17080  0.3665
#         macro avg     0.3869  0.5772    0.3720    17080
#      weighted avg     0.5586  0.4184    0.3867    17080
#               min     0.1703  0.0339    0.0646      289  0.1123
#
# Testing accuracy: test_accuracy = 0.354718
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0478  0.1170    0.0679       94  0.0420
#   genre_classical     0.7520  0.7014    0.7258     1055  0.6407
#     genre_country     0.1163  0.4878    0.1878       82  0.2094
#       genre_disco     0.0958  0.5417    0.1628       72  0.1991
#      genre_hiphop     0.2691  0.2824    0.2755      425  0.1934
#        genre_jazz     0.2991  0.4116    0.3464      311  0.2906
#       genre_metal     0.2199  0.7470    0.3397      166  0.3653
#         genre_pop     0.5938  0.0178    0.0345     1069  0.0689
#      genre_reggae     0.2765  0.6345    0.3852      197  0.3779
#        genre_rock     0.4401  0.2112    0.2855      800  0.2036
#
#          accuracy                       0.3547     4271  0.2921
#         macro avg     0.3110  0.4152    0.2811     4271
#      weighted avg     0.4916  0.3547    0.3329     4271
#               min     0.0478  0.0178    0.0345       72  0.0420
# Commencing Experiment: RandomForestClassifier_dataset_05_pvtt
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.380621
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1162  0.2701    0.1625      374  0.1492
#   genre_classical     0.8381  0.8280    0.8330     4221  0.7787
#     genre_country     0.0904  0.5443    0.1551      327  0.1878
#       genre_disco     0.1533  0.3114    0.2055      289  0.1995
#      genre_hiphop     0.3306  0.0952    0.1479     1701  0.1326
#        genre_jazz     0.2486  0.5133    0.3350     1241  0.2848
#       genre_metal     0.2191  0.7654    0.3407      665  0.3696
#         genre_pop     0.5388  0.0894    0.1533     4274  0.1386
#      genre_reggae     0.1925  0.6218    0.2940      788  0.2920
#        genre_rock     0.5333  0.1428    0.2253     3200  0.2037
#
#          accuracy                       0.3806    17080  0.3230
#         macro avg     0.3261  0.4182    0.2852    17080
#      weighted avg     0.5171  0.3806    0.3623    17080
#               min     0.0904  0.0894    0.1479      289  0.1326
#
# Testing accuracy: test_accuracy = 0.362913
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0551  0.1383    0.0788       94  0.0545
#   genre_classical     0.8190  0.8408    0.8297     1055  0.7730
#     genre_country     0.0610  0.3659    0.1045       82  0.1098
#       genre_disco     0.1135  0.2222    0.1502       72  0.1387
#      genre_hiphop     0.3113  0.0776    0.1243      425  0.1129
#        genre_jazz     0.2376  0.4920    0.3204      311  0.2672
#       genre_metal     0.2042  0.7108    0.3172      166  0.3383
#         genre_pop     0.5276  0.0804    0.1396     1069  0.1275
#      genre_reggae     0.1641  0.4924    0.2462      197  0.2255
#        genre_rock     0.4937  0.1462    0.2257      800  0.1903
#
#          accuracy                       0.3629     4271  0.3002
#         macro avg     0.2987  0.3567    0.2537     4271
#      weighted avg     0.4949  0.3629    0.3478     4271
#               min     0.0551  0.0776    0.0788       72  0.0545
# Commencing Experiment: RandomForestClassifier_dataset_06_pvtt_mean
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.436593
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.3146  0.4492    0.3700      374  0.3593
#   genre_classical     0.8196  0.8299    0.8247     4221  0.7667
#     genre_country     0.1758  0.7187    0.2825      327  0.3331
#       genre_disco     0.1676  0.7232    0.2721      289  0.3279
#      genre_hiphop     0.3624  0.2199    0.2737     1701  0.2226
#        genre_jazz     0.2779  0.5995    0.3798     1241  0.3409
#       genre_metal     0.2623  0.8256    0.3981      665  0.4315
#         genre_pop     0.7353  0.0819    0.1474     4274  0.1896
#      genre_reggae     0.2607  0.6434    0.3710      788  0.3666
#        genre_rock     0.5584  0.2556    0.3507     3200  0.2912
#
#          accuracy                       0.4366    17080  0.3817
#         macro avg     0.3935  0.5347    0.3670    17080
#      weighted avg     0.5828  0.4366    0.4120    17080
#               min     0.1676  0.0819    0.1474      289  0.1896
#
# Testing accuracy: test_accuracy = 0.400843
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0885  0.1064    0.0966       94  0.0747
#   genre_classical     0.7952  0.8427    0.8182     1055  0.7568
#     genre_country     0.1154  0.4756    0.1857       82  0.2055
#       genre_disco     0.0990  0.4306    0.1610       72  0.1795
#      genre_hiphop     0.3238  0.1859    0.2362      425  0.1844
#        genre_jazz     0.2552  0.5531    0.3492      311  0.3038
#       genre_metal     0.2433  0.7651    0.3692      166  0.3947
#         genre_pop     0.6174  0.0664    0.1199     1069  0.1410
#      genre_reggae     0.2082  0.4873    0.2918      197  0.2688
#        genre_rock     0.5308  0.2475    0.3376      800  0.2724
#
#          accuracy                       0.4008     4271  0.3373
#         macro avg     0.3277  0.4160    0.2966     4271
#      weighted avg     0.5261  0.4008    0.3805     4271
#               min     0.0885  0.0664    0.0966       72  0.0747
# Commencing Experiment: RandomForestClassifier_dataset_07_pvtt_mean_cov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.474473
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.2788  0.7193    0.4018      374  0.4295
#   genre_classical     0.8048  0.8254    0.8150     4221  0.7533
#     genre_country     0.2170  0.8440    0.3452      327  0.4095
#       genre_disco     0.1974  0.8893    0.3231      289  0.4020
#      genre_hiphop     0.4888  0.4633    0.4757     1701  0.4196
#        genre_jazz     0.4190  0.6068    0.4957     1241  0.4576
#       genre_metal     0.2512  0.8617    0.3890      665  0.4308
#         genre_pop     0.7589  0.0501    0.0939     4274  0.1521
#      genre_reggae     0.3725  0.8084    0.5100      788  0.5189
#        genre_rock     0.5575  0.2666    0.3607     3200  0.2976
#
#          accuracy                       0.4745    17080  0.4272
#         macro avg     0.4346  0.6335    0.4210    17080
#      weighted avg     0.6129  0.4745    0.4354    17080
#               min     0.1974  0.0501    0.0939      289  0.1521
#
# Testing accuracy: test_accuracy = 0.401779
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0838  0.1702    0.1123       94  0.0911
#   genre_classical     0.7765  0.8199    0.7976     1055  0.7293
#     genre_country     0.1315  0.5244    0.2103       82  0.2356
#       genre_disco     0.1250  0.5972    0.2067       72  0.2486
#      genre_hiphop     0.3359  0.3106    0.3227      425  0.2514
#        genre_jazz     0.3378  0.4823    0.3974      311  0.3474
#       genre_metal     0.2252  0.7651    0.3479      166  0.3760
#         genre_pop     0.6857  0.0225    0.0435     1069  0.0914
#      genre_reggae     0.2777  0.6497    0.3891      197  0.3840
#        genre_rock     0.4724  0.2350    0.3139      800  0.2342
#
#          accuracy                       0.4018     4271  0.3416
#         macro avg     0.3451  0.4577    0.3141     4271
#      weighted avg     0.5380  0.4018    0.3692     4271
#               min     0.0838  0.0225    0.0435       72  0.0911
# Commencing Experiment: RandomForestClassifier_dataset_08_pvtt_mean_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.404742
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.2301  0.2005    0.2143      374  0.1984
#   genre_classical     0.8333  0.8147    0.8239     4221  0.7671
#     genre_country     0.1060  0.6116    0.1808      327  0.2234
#       genre_disco     0.1487  0.4152    0.2190      289  0.2275
#      genre_hiphop     0.3000  0.1817    0.2263     1701  0.1695
#        genre_jazz     0.2476  0.5246    0.3364     1241  0.2875
#       genre_metal     0.2771  0.7564    0.4056      665  0.4246
#         genre_pop     0.6608  0.0351    0.0667     4274  0.1100
#      genre_reggae     0.2160  0.6688    0.3265      788  0.3305
#        genre_rock     0.5237  0.2934    0.3761     3200  0.2952
#
#          accuracy                       0.4047    17080  0.3467
#         macro avg     0.3543  0.4502    0.3176    17080
#      weighted avg     0.5476  0.4047    0.3805    17080
#               min     0.1060  0.0351    0.0667      289  0.1100
#
# Testing accuracy: test_accuracy = 0.381878
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0465  0.0426    0.0444       94  0.0239
#   genre_classical     0.8175  0.8322    0.8248     1055  0.7667
#     genre_country     0.0667  0.3902    0.1139       82  0.1231
#       genre_disco     0.1348  0.3333    0.1920       72  0.1911
#      genre_hiphop     0.2828  0.1624    0.2063      425  0.1507
#        genre_jazz     0.2389  0.5016    0.3237      311  0.2715
#       genre_metal     0.2646  0.7108    0.3856      166  0.3988
#         genre_pop     0.4000  0.0206    0.0391     1069  0.0395
#      genre_reggae     0.1900  0.5787    0.2861      197  0.2773
#        genre_rock     0.4703  0.2675    0.3410      800  0.2505
#
#          accuracy                       0.3819     4271  0.3177
#         macro avg     0.2912  0.3840    0.2757     4271
#      weighted avg     0.4593  0.3819    0.3561     4271
#               min     0.0465  0.0206    0.0391       72  0.0239
# Commencing Experiment: RandomForestClassifier_dataset_09_pvtt_mean_cov_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.437412
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1895  0.5989    0.2879      374  0.3123
#   genre_classical     0.8189  0.7937    0.8061     4221  0.7439
#     genre_country     0.2017  0.7431    0.3172      327  0.3669
#       genre_disco     0.1772  0.8547    0.2935      289  0.3704
#      genre_hiphop     0.4113  0.3980    0.4045     1701  0.3399
#        genre_jazz     0.3551  0.5439    0.4297     1241  0.3850
#       genre_metal     0.2487  0.8361    0.3833      665  0.4208
#         genre_pop     0.7669  0.0292    0.0563     4274  0.1171
#      genre_reggae     0.3366  0.7487    0.4644      788  0.4682
#        genre_rock     0.5195  0.2450    0.3330     3200  0.2650
#
#          accuracy                       0.4374    17080  0.3877
#         macro avg     0.4025  0.5791    0.3776    17080
#      weighted avg     0.5946  0.4374    0.4009    17080
#               min     0.1772  0.0292    0.0563      289  0.1171
#
# Testing accuracy: test_accuracy = 0.382112
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0702  0.1809    0.1012       94  0.0806
#   genre_classical     0.7883  0.7801    0.7842     1055  0.7139
#     genre_country     0.1250  0.4634    0.1969       82  0.2134
#       genre_disco     0.1059  0.5694    0.1786       72  0.2184
#      genre_hiphop     0.3093  0.2824    0.2952      425  0.2215
#        genre_jazz     0.3142  0.4759    0.3785      311  0.3271
#       genre_metal     0.2298  0.7530    0.3521      166  0.3774
#         genre_pop     0.6250  0.0140    0.0274     1069  0.0650
#      genre_reggae     0.2715  0.6244    0.3785      197  0.3701
#        genre_rock     0.4396  0.2275    0.2998      800  0.2119
#
#          accuracy                       0.3821     4271  0.3214
#         macro avg     0.3279  0.4371    0.2992     4271
#      weighted avg     0.5143  0.3821    0.3538     4271
#               min     0.0702  0.0140    0.0274       72  0.0650
# Commencing Experiment: RandomForestClassifier_dataset_10_melspectrograms_flattened
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.523478
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5793  0.8690    0.6952      374  0.7019
#   genre_classical     0.6975  0.7626    0.7286     4221  0.6353
#     genre_country     0.7964  0.9450    0.8643      327  0.8647
#       genre_disco     0.8576  0.9377    0.8959      289  0.8949
#      genre_hiphop     0.5696  0.6684    0.6151     1701  0.5710
#        genre_jazz     0.5055  0.7454    0.6024     1241  0.5776
#       genre_metal     0.1485  0.9278    0.2561      665  0.3212
#         genre_pop     0.7893  0.2550    0.3855     4274  0.3691
#      genre_reggae     0.5964  0.9226    0.7245      788  0.7272
#        genre_rock     0.5177  0.1003    0.1681     3200  0.1643
#
#          accuracy                       0.5235    17080  0.4803
#         macro avg     0.6058  0.7134    0.5936    17080
#      weighted avg     0.6361  0.5235    0.5034    17080
#               min     0.1485  0.1003    0.1681      289  0.1643
#
# Testing accuracy: test_accuracy = 0.316788
#
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0412  0.0426    0.0419       94  0.0200
#   genre_classical     0.6122  0.7318    0.6667     1055  0.5481
#     genre_country     0.1000  0.0244    0.0392       82  0.0404
#       genre_disco     0.2273  0.0694    0.1064       72  0.1176
#      genre_hiphop     0.2937  0.2965    0.2951      425  0.2168
#        genre_jazz     0.2077  0.3280    0.2544      311  0.1871
#       genre_metal     0.1133  0.8675    0.2004      166  0.2507
#         genre_pop     0.4118  0.1244    0.1911     1069  0.1066
#      genre_reggae     0.1286  0.1371    0.1327      197  0.0894
#        genre_rock     0.2585  0.0475    0.0803      800  0.0345
#
#          accuracy                       0.3168     4271  0.2303
#         macro avg     0.2394  0.2669    0.2008     4271
#      weighted avg     0.3641  0.3168    0.2928     4271
#               min     0.0412  0.0244    0.0392       72  0.0200
