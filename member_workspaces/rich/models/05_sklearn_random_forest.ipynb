# %%
import glob
import sys

import numpy as np
import pandas as pd

from sklearn.ensemble import RandomForestClassifier

sys.path.append("../../../")

from helpers.experiment import experiment

# %%
dataset_folder = "../../../datasets/"
datasets = sorted([name for name in glob.glob(dataset_folder + "dataset_*.pickle")])

for dataset in datasets:
    
    if "spectrogram" in dataset:
        n_components = 2400
    else:
        n_components = .95
        
    n_components = None
    
    model = RandomForestClassifier(max_depth=9, min_samples_leaf=1, class_weight='balanced')
    experiment(model, dataset, pca_components=n_components, result_filename="rich_results.json")
# Out:
# Commencing Experiment: RandomForestClassifier_dataset_00_all
#
# Training accuracy: train_accuracy = 0.687529
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5939  0.8797    0.7091      374  0.7156
#   genre_classical     0.9073  0.8510    0.8782     4221  0.8407
#     genre_country     0.5590  0.9266    0.6974      327  0.7132
#       genre_disco     0.4268  0.9689    0.5926      289  0.6352
#      genre_hiphop     0.5818  0.8089    0.6768     1701  0.6456
#        genre_jazz     0.4742  0.7470    0.5801     1241  0.5561
#       genre_metal     0.7672  0.8571    0.8097      665  0.8028
#         genre_pop     0.7208  0.3811    0.4986     4274  0.4242
#      genre_reggae     0.5588  0.8680    0.6799      788  0.6790
#        genre_rock     0.7275  0.6416    0.6818     3200  0.6159
#
#          accuracy                       0.6875    17080  0.6396
#         macro avg     0.6317  0.7930    0.6804    17080
#      weighted avg     0.7199  0.6875    0.6809    17080
#               min     0.4268  0.3811    0.4986      289  0.4242
#
# Testing accuracy: test_accuracy = 0.580660
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1649  0.1702    0.1675       94  0.1485
#   genre_classical     0.8422  0.8597    0.8508     1055  0.8013
#     genre_country     0.3451  0.5976    0.4375       82  0.4404
#       genre_disco     0.3289  0.6944    0.4464       72  0.4657
#      genre_hiphop     0.5136  0.6682    0.5808      425  0.5335
#        genre_jazz     0.3875  0.5981    0.4703      311  0.4309
#       genre_metal     0.5654  0.6506    0.6050      166  0.5895
#         genre_pop     0.5916  0.2900    0.3892     1069  0.2946
#      genre_reggae     0.4013  0.6294    0.4901      197  0.4729
#        genre_rock     0.5979  0.5575    0.5770      800  0.4841
#
#          accuracy                       0.5807     4271  0.5107
#         macro avg     0.4738  0.5716    0.5015     4271
#      weighted avg     0.6037  0.5807    0.5734     4271
#               min     0.1649  0.1702    0.1675       72  0.1485
# Commencing Experiment: RandomForestClassifier_dataset_01_mean
#
# Training accuracy: train_accuracy = 0.543267
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.4071  0.7620    0.5307      374  0.5442
#   genre_classical     0.8163  0.8361    0.8261     4221  0.7682
#     genre_country     0.3099  0.8624    0.4559      327  0.5033
#       genre_disco     0.2508  0.8304    0.3852      289  0.4418
#      genre_hiphop     0.5652  0.3874    0.4597     1701  0.4209
#        genre_jazz     0.3338  0.6366    0.4379     1241  0.4034
#       genre_metal     0.4169  0.7880    0.5453      665  0.5507
#         genre_pop     0.7587  0.2295    0.3524     4274  0.3360
#      genre_reggae     0.2871  0.7462    0.4147      788  0.4240
#        genre_rock     0.6804  0.4378    0.5328     3200  0.4679
#
#          accuracy                       0.5433    17080  0.4879
#         macro avg     0.4826  0.6516    0.4941    17080
#      weighted avg     0.6482  0.5433    0.5370    17080
#               min     0.2508  0.2295    0.3524      289  0.3360
#
# Testing accuracy: test_accuracy = 0.431983
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0846  0.1170    0.0982       94  0.0756
#   genre_classical     0.7564  0.8180    0.7860     1055  0.7131
#     genre_country     0.1696  0.4756    0.2500       82  0.2614
#       genre_disco     0.1250  0.4167    0.1923       72  0.2050
#      genre_hiphop     0.3960  0.2329    0.2933      425  0.2470
#        genre_jazz     0.2410  0.4759    0.3200      311  0.2653
#       genre_metal     0.3153  0.5964    0.4125      166  0.4029
#         genre_pop     0.5681  0.1600    0.2496     1069  0.2020
#      genre_reggae     0.1712  0.4518    0.2483      197  0.2219
#        genre_rock     0.5574  0.3700    0.4448      800  0.3575
#
#          accuracy                       0.4320     4271  0.3548
#         macro avg     0.3385  0.4114    0.3295     4271
#      weighted avg     0.5178  0.4320    0.4301     4271
#               min     0.0846  0.1170    0.0982       72  0.0756
# Commencing Experiment: RandomForestClassifier_dataset_02_mean_cov
#
# Training accuracy: train_accuracy = 0.657728
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.6415  0.9332    0.7603      374  0.7680
#   genre_classical     0.8797  0.8451    0.8620     4221  0.8182
#     genre_country     0.6082  0.9541    0.7429      327  0.7564
#       genre_disco     0.3636  0.9827    0.5308      289  0.5885
#      genre_hiphop     0.5856  0.6332    0.6085     1701  0.5638
#        genre_jazz     0.4812  0.7744    0.5936     1241  0.5727
#       genre_metal     0.5520  0.9263    0.6917      665  0.7012
#         genre_pop     0.8209  0.3334    0.4742     4274  0.4431
#      genre_reggae     0.4832  0.8744    0.6224      788  0.6288
#        genre_rock     0.6359  0.6106    0.6230     3200  0.5384
#
#          accuracy                       0.6577    17080  0.6094
#         macro avg     0.6052  0.7867    0.6509    17080
#      weighted avg     0.7108  0.6577    0.6476    17080
#               min     0.3636  0.3334    0.4742      289  0.4431
#
# Testing accuracy: test_accuracy = 0.495200
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1370  0.1064    0.1198       94  0.1033
#   genre_classical     0.7889  0.8218    0.8050     1055  0.7396
#     genre_country     0.2806  0.4756    0.3529       82  0.3494
#       genre_disco     0.1627  0.4722    0.2420       72  0.2569
#      genre_hiphop     0.3677  0.3859    0.3766      425  0.3059
#        genre_jazz     0.3154  0.5273    0.3947      311  0.3476
#       genre_metal     0.3799  0.6386    0.4764      166  0.4665
#         genre_pop     0.6028  0.2030    0.3037     1069  0.2469
#      genre_reggae     0.3404  0.6548    0.4479      197  0.4378
#        genre_rock     0.5020  0.4813    0.4914      800  0.3773
#
#          accuracy                       0.4952     4271  0.4172
#         macro avg     0.3877  0.4767    0.4010     4271
#      weighted avg     0.5409  0.4952    0.4858     4271
#               min     0.1370  0.1064    0.1198       72  0.1033
# Commencing Experiment: RandomForestClassifier_dataset_03_mean_icov
#
# Training accuracy: train_accuracy = 0.515515
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5649  0.7219    0.6338      374  0.6295
#   genre_classical     0.9036  0.7553    0.8228     4221  0.7766
#     genre_country     0.2234  0.8685    0.3554      327  0.4227
#       genre_disco     0.1992  0.8997    0.3262      289  0.4066
#      genre_hiphop     0.6718  0.2563    0.3711     1701  0.3798
#        genre_jazz     0.3312  0.6720    0.4437     1241  0.4142
#       genre_metal     0.4333  0.8346    0.5704      665  0.5805
#         genre_pop     0.6664  0.2103    0.3198     4274  0.2814
#      genre_reggae     0.2369  0.7424    0.3592      788  0.3739
#        genre_rock     0.6694  0.4669    0.5501     3200  0.4789
#
#          accuracy                       0.5155    17080  0.4641
#         macro avg     0.4900  0.6428    0.4753    17080
#      weighted avg     0.6543  0.5155    0.5206    17080
#               min     0.1992  0.2103    0.3198      289  0.2814
#
# Testing accuracy: test_accuracy = 0.412550
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0506  0.0426    0.0462       94  0.0268
#   genre_classical     0.8629  0.7517    0.8034     1055  0.7477
#     genre_country     0.1424  0.5732    0.2282       82  0.2598
#       genre_disco     0.1083  0.5278    0.1797       72  0.2125
#      genre_hiphop     0.3089  0.0894    0.1387      425  0.1205
#        genre_jazz     0.2635  0.5177    0.3492      311  0.2998
#       genre_metal     0.2956  0.6446    0.4053      166  0.4042
#         genre_pop     0.4940  0.1534    0.2341     1069  0.1633
#      genre_reggae     0.1963  0.5990    0.2957      197  0.2898
#        genre_rock     0.5187  0.3650    0.4285      800  0.3309
#
#          accuracy                       0.4125     4271  0.3420
#         macro avg     0.3241  0.4264    0.3109     4271
#      weighted avg     0.5101  0.4125    0.4144     4271
#               min     0.0506  0.0426    0.0462       72  0.0268
# Commencing Experiment: RandomForestClassifier_dataset_04_mean_cov_icov
#
# Training accuracy: train_accuracy = 0.586944
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5636  0.8529    0.6787      374  0.6853
#   genre_classical     0.9294  0.7456    0.8274     4221  0.7865
#     genre_country     0.3571  0.9205    0.5145      327  0.5619
#       genre_disco     0.2716  0.9585    0.4232      289  0.4976
#      genre_hiphop     0.5353  0.5209    0.5280     1701  0.4767
#        genre_jazz     0.3982  0.7156    0.5117     1241  0.4860
#       genre_metal     0.5144  0.8887    0.6516      665  0.6601
#         genre_pop     0.6596  0.2857    0.3987     4274  0.3295
#      genre_reggae     0.4224  0.8122    0.5558      788  0.5596
#        genre_rock     0.6126  0.5484    0.5787     3200  0.4892
#
#          accuracy                       0.5869    17080  0.5319
#         macro avg     0.5264  0.7249    0.5668    17080
#      weighted avg     0.6551  0.5869    0.5853    17080
#               min     0.2716  0.2857    0.3987      289  0.3295
#
# Testing accuracy: test_accuracy = 0.460782
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1034  0.0957    0.0994       94  0.0800
#   genre_classical     0.8838  0.7280    0.7983     1055  0.7462
#     genre_country     0.1864  0.5366    0.2767       82  0.2947
#       genre_disco     0.1514  0.5972    0.2416       72  0.2789
#      genre_hiphop     0.3198  0.2965    0.3077      425  0.2346
#        genre_jazz     0.2807  0.5145    0.3632      311  0.3140
#       genre_metal     0.3610  0.6024    0.4515      166  0.4389
#         genre_pop     0.5383  0.1974    0.2888     1069  0.2113
#      genre_reggae     0.3248  0.6447    0.4320      197  0.4218
#        genre_rock     0.4929  0.4750    0.4838      800  0.3676
#
#          accuracy                       0.4608     4271  0.3849
#         macro avg     0.3643  0.4688    0.3743     4271
#      weighted avg     0.5350  0.4608    0.4662     4271
#               min     0.1034  0.0957    0.0994       72  0.0800
# Commencing Experiment: RandomForestClassifier_dataset_05_pvtt
#
# Training accuracy: train_accuracy = 0.525644
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.4013  0.6417    0.4938      374  0.4939
#   genre_classical     0.8837  0.8422    0.8624     4221  0.8191
#     genre_country     0.2644  0.7584    0.3921      327  0.4314
#       genre_disco     0.3528  0.7958    0.4888      289  0.5188
#      genre_hiphop     0.4385  0.3545    0.3921     1701  0.3349
#        genre_jazz     0.3349  0.6446    0.4408     1241  0.4074
#       genre_metal     0.3726  0.8271    0.5138      665  0.5306
#         genre_pop     0.6854  0.1851    0.2915     4274  0.2705
#      genre_reggae     0.2637  0.7525    0.3905      788  0.4038
#        genre_rock     0.6146  0.4275    0.5042     3200  0.4238
#
#          accuracy                       0.5256    17080  0.4695
#         macro avg     0.4612  0.6230    0.4770    17080
#      weighted avg     0.6195  0.5256    0.5162    17080
#               min     0.2637  0.1851    0.2915      289  0.2705
#
# Testing accuracy: test_accuracy = 0.435261
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0265  0.0319    0.0290       94  0.0051
#   genre_classical     0.8426  0.8474    0.8450     1055  0.7940
#     genre_country     0.1046  0.3049    0.1558       82  0.1515
#       genre_disco     0.1627  0.3750    0.2269       72  0.2277
#      genre_hiphop     0.2973  0.2329    0.2612      425  0.1921
#        genre_jazz     0.2569  0.5080    0.3413      311  0.2906
#       genre_metal     0.2637  0.5783    0.3623      166  0.3551
#         genre_pop     0.5720  0.1413    0.2266     1069  0.1906
#      genre_reggae     0.2039  0.5330    0.2949      197  0.2785
#        genre_rock     0.5008  0.3762    0.4297      800  0.3252
#
#          accuracy                       0.4353     4271  0.3600
#         macro avg     0.3231  0.3929    0.3173     4271
#      weighted avg     0.5184  0.4353    0.4319     4271
#               min     0.0265  0.0319    0.0290       72  0.0051
# Commencing Experiment: RandomForestClassifier_dataset_06_pvtt_mean
#
# Training accuracy: train_accuracy = 0.567916
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.3698  0.7674    0.4991      374  0.5187
#   genre_classical     0.8931  0.8548    0.8735     4221  0.8335
#     genre_country     0.3280  0.8807    0.4780      327  0.5247
#       genre_disco     0.3916  0.8685    0.5398      289  0.5736
#      genre_hiphop     0.5312  0.4051    0.4596     1701  0.4132
#        genre_jazz     0.3664  0.6753    0.4751     1241  0.4450
#       genre_metal     0.4329  0.8541    0.5746      665  0.5875
#         genre_pop     0.7642  0.2199    0.3416     4274  0.3306
#      genre_reggae     0.3048  0.8401    0.4473      788  0.4706
#        genre_rock     0.6412  0.4903    0.5557     3200  0.4756
#
#          accuracy                       0.5679    17080  0.5167
#         macro avg     0.5023  0.6856    0.5244    17080
#      weighted avg     0.6635  0.5679    0.5580    17080
#               min     0.3048  0.2199    0.3416      289  0.3306
#
# Testing accuracy: test_accuracy = 0.467338
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0828  0.1277    0.1004       94  0.0776
#   genre_classical     0.8343  0.8493    0.8417     1055  0.7892
#     genre_country     0.1822  0.5000    0.2671       82  0.2802
#       genre_disco     0.2015  0.3750    0.2621       72  0.2581
#      genre_hiphop     0.3770  0.2776    0.3198      425  0.2607
#        genre_jazz     0.2922  0.5402    0.3792      311  0.3330
#       genre_metal     0.3313  0.6446    0.4376      166  0.4327
#         genre_pop     0.5777  0.1600    0.2505     1069  0.2063
#      genre_reggae     0.2257  0.6142    0.3302      197  0.3244
#        genre_rock     0.5154  0.4188    0.4621      800  0.3563
#
#          accuracy                       0.4673     4271  0.3944
#         macro avg     0.3620  0.4507    0.3651     4271
#      weighted avg     0.5380  0.4673    0.4606     4271
#               min     0.0828  0.1277    0.1004       72  0.0776
# Commencing Experiment: RandomForestClassifier_dataset_07_pvtt_mean_cov
#
# Training accuracy: train_accuracy = 0.664110
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.6720  0.8984    0.7689      374  0.7714
#   genre_classical     0.9014  0.8730    0.8870     4221  0.8509
#     genre_country     0.6489  0.9327    0.7654      327  0.7731
#       genre_disco     0.3398  0.9689    0.5031      289  0.5636
#      genre_hiphop     0.5968  0.6179    0.6072     1701  0.5630
#        genre_jazz     0.4238  0.7800    0.5492     1241  0.5315
#       genre_metal     0.5697  0.9158    0.7024      665  0.7090
#         genre_pop     0.8033  0.3467    0.4844     4274  0.4443
#      genre_reggae     0.4872  0.8693    0.6244      788  0.6297
#        genre_rock     0.6855  0.6069    0.6438     3200  0.5693
#
#          accuracy                       0.6641    17080  0.6170
#         macro avg     0.6128  0.7810    0.6536    17080
#      weighted avg     0.7200  0.6641    0.6576    17080
#               min     0.3398  0.3467    0.4844      289  0.4443
#
# Testing accuracy: test_accuracy = 0.507375
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0989  0.0957    0.0973       94  0.0773
#   genre_classical     0.8221  0.8540    0.8377     1055  0.7834
#     genre_country     0.3130  0.4390    0.3655       82  0.3562
#       genre_disco     0.1875  0.5833    0.2838       72  0.3118
#      genre_hiphop     0.3907  0.3741    0.3822      425  0.3157
#        genre_jazz     0.3048  0.5723    0.3978      311  0.3553
#       genre_metal     0.4131  0.6446    0.5035      166  0.4920
#         genre_pop     0.5637  0.1946    0.2893     1069  0.2225
#      genre_reggae     0.3544  0.6548    0.4599      197  0.4486
#        genre_rock     0.5223  0.4975    0.5096      800  0.4001
#
#          accuracy                       0.5074     4271  0.4319
#         macro avg     0.3971  0.4910    0.4127     4271
#      weighted avg     0.5468  0.5074    0.4965     4271
#               min     0.0989  0.0957    0.0973       72  0.0773
# Commencing Experiment: RandomForestClassifier_dataset_08_pvtt_mean_icov
#
# Training accuracy: train_accuracy = 0.566979
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.7053  0.7487    0.7263      374  0.7204
#   genre_classical     0.8952  0.8557    0.8750     4221  0.8356
#     genre_country     0.4022  0.8807    0.5523      327  0.5848
#       genre_disco     0.1988  0.8893    0.3249      289  0.4035
#      genre_hiphop     0.6809  0.2634    0.3798     1701  0.3885
#        genre_jazz     0.3545  0.7002    0.4707     1241  0.4445
#       genre_metal     0.4221  0.8511    0.5643      665  0.5781
#         genre_pop     0.7212  0.2766    0.3998     4274  0.3542
#      genre_reggae     0.2868  0.7817    0.4196      788  0.4351
#        genre_rock     0.6520  0.4894    0.5591     3200  0.4817
#
#          accuracy                       0.5670    17080  0.5137
#         macro avg     0.5319  0.6737    0.5272    17080
#      weighted avg     0.6736  0.5670    0.5664    17080
#               min     0.1988  0.2634    0.3249      289  0.3542
#
# Testing accuracy: test_accuracy = 0.462889
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1111  0.0638    0.0811       94  0.0687
#   genre_classical     0.8398  0.8645    0.8519     1055  0.8026
#     genre_country     0.2300  0.5610    0.3262       82  0.3405
#       genre_disco     0.1126  0.5694    0.1881       72  0.2271
#      genre_hiphop     0.4034  0.1129    0.1765      425  0.1718
#        genre_jazz     0.2928  0.5884    0.3910      311  0.3505
#       genre_metal     0.3153  0.6687    0.4286      166  0.4287
#         genre_pop     0.5629  0.1759    0.2680     1069  0.2102
#      genre_reggae     0.2365  0.6244    0.3431      197  0.3380
#        genre_rock     0.5170  0.3987    0.4502      800  0.3473
#
#          accuracy                       0.4629     4271  0.3921
#         macro avg     0.3621  0.4628    0.3505     4271
#      weighted avg     0.5385  0.4629    0.4516     4271
#               min     0.1111  0.0638    0.0811       72  0.0687
# Commencing Experiment: RandomForestClassifier_dataset_09_pvtt_mean_cov_icov
#
# Training accuracy: train_accuracy = 0.612002
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5989  0.8422    0.7000      374  0.7028
#   genre_classical     0.9032  0.8467    0.8741     4221  0.8352
#     genre_country     0.4008  0.9144    0.5573      327  0.5952
#       genre_disco     0.2766  0.9619    0.4297      289  0.5035
#      genre_hiphop     0.5957  0.5050    0.5466     1701  0.5031
#        genre_jazz     0.3919  0.7349    0.5112     1241  0.4885
#       genre_metal     0.4963  0.9038    0.6407      665  0.6531
#         genre_pop     0.7268  0.2913    0.4159     4274  0.3673
#      genre_reggae     0.4270  0.8236    0.5624      788  0.5674
#        genre_rock     0.6536  0.5378    0.5901     3200  0.5101
#
#          accuracy                       0.6120    17080  0.5605
#         macro avg     0.5471  0.7362    0.5828    17080
#      weighted avg     0.6798  0.6120    0.6064    17080
#               min     0.2766  0.2913    0.4159      289  0.3673
#
# Testing accuracy: test_accuracy = 0.485835
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1429  0.1383    0.1405       94  0.1215
#   genre_classical     0.8443  0.8531    0.8487     1055  0.7987
#     genre_country     0.1982  0.5244    0.2876       82  0.3017
#       genre_disco     0.1581  0.5556    0.2462       72  0.2753
#      genre_hiphop     0.3696  0.2800    0.3186      425  0.2576
#        genre_jazz     0.2961  0.5627    0.3880      311  0.3444
#       genre_metal     0.3607  0.6627    0.4671      166  0.4617
#         genre_pop     0.5653  0.1740    0.2661     1069  0.2101
#      genre_reggae     0.3316  0.6396    0.4367      197  0.4253
#        genre_rock     0.5063  0.4537    0.4786      800  0.3672
#
#          accuracy                       0.4858     4271  0.4126
#         macro avg     0.3773  0.4844    0.3878     4271
#      weighted avg     0.5421  0.4858    0.4769     4271
#               min     0.1429  0.1383    0.1405       72  0.1215
# Commencing Experiment: RandomForestClassifier_dataset_10_melspectrograms_flattened
#
# Training accuracy: train_accuracy = 0.638466
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.9291  0.9813    0.9545      374  0.9538
#   genre_classical     0.8271  0.7501    0.7867     4221  0.7226
#     genre_country     0.3519  0.9847    0.5185      327  0.5777
#       genre_disco     0.9565  0.9896    0.9728      289  0.9725
#      genre_hiphop     0.5915  0.8266    0.6896     1701  0.6605
#        genre_jazz     0.3828  0.7623    0.5097     1241  0.4915
#       genre_metal     0.5031  0.8436    0.6303      665  0.6342
#         genre_pop     0.7665  0.3210    0.4525     4274  0.4078
#      genre_reggae     0.6191  0.9467    0.7486      788  0.7525
#        genre_rock     0.6454  0.5416    0.5890     3200  0.5070
#
#          accuracy                       0.6385    17080  0.5892
#         macro avg     0.6573  0.7947    0.6852    17080
#      weighted avg     0.6953  0.6385    0.6301    17080
#               min     0.3519  0.3210    0.4525      289  0.4078
#
# Testing accuracy: test_accuracy = 0.406462
#
# /home/jovyan/github/mids-w207/mids_w207_music_genre/member_workspaces/rich/models/../../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1600  0.0426    0.0672       94  0.0722
#   genre_classical     0.7590  0.7166    0.7372     1055  0.6547
#     genre_country     0.0797  0.2439    0.1201       82  0.1101
#       genre_disco     0.4211  0.1111    0.1758       72  0.2099
#      genre_hiphop     0.2949  0.4094    0.3429      425  0.2613
#        genre_jazz     0.2424  0.5627    0.3388      311  0.2943
#       genre_metal     0.3276  0.5723    0.4167      166  0.4032
#         genre_pop     0.4062  0.1235    0.1894     1069  0.1033
#      genre_reggae     0.1475  0.2284    0.1793      197  0.1341
#        genre_rock     0.4372  0.4088    0.4225      800  0.2951
#
#          accuracy                       0.4065     4271  0.3159
#         macro avg     0.3276  0.3419    0.2990     4271
#      weighted avg     0.4497  0.4065    0.3986     4271
#               min     0.0797  0.0426    0.0672       72  0.0722
