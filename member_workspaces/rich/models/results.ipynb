# %%
import numpy as np
import pandas as pd
import json

# %%
with open ("../../results/rich_results.json") as f:
    test_results = json.load(f)

# %%
test_results
# Out:
# {'LogisticRegression_dataset_01_mean_train': {'results': {'genre_blues': {'precision': 0.06787330316742081,
#     'recall': 0.08021390374331551,
#     'f1-score': 0.07352941176470587,
#     'support': 374,
#     'mcc': 0.05120482304095185},
#    'genre_classical': {'precision': 0.738494623655914,
#     'recall': 0.8135512911632314,
#     'f1-score': 0.7742080937887498,
#     'support': 4221,
#     'mcc': 0.6967394088789689},
#    'genre_country': {'precision': 0.10887573964497041,
#     'recall': 0.28134556574923547,
#     'f1-score': 0.15699658703071673,
#     'support': 327,
#     'mcc': 0.14938609951271625},
#    'genre_disco': {'precision': 0.0801068090787717,
#     'recall': 0.20761245674740483,
#     'f1-score': 0.11560693641618497,
#     'support': 289,
#     'mcc': 0.10492018128312011},
#    'genre_hiphop': {'precision': 0.3615477629987908,
#     'recall': 0.3515579071134627,
#     'f1-score': 0.3564828614008942,
#     'support': 1701,
#     'mcc': 0.2864466526069751},
# ...

# %%
df.LogisticRegression_dataset_00_all_test
