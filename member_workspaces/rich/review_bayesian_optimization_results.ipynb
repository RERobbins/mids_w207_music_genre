# %%
import json

import pandas as pd

# %%
filename = "../rich/merged_results.json"

# %%
with open(filename, "r") as infile:
    json_list = [json.loads(line) for line in infile]
df = pd.json_normalize(json_list)

# %% [markdown]
# **Current best mcc, f1_macro and accuracy results, respectively.**

# %%
best_mcc_f1_accuracy_indices = [
    df["matthews_corrcoef"].idxmax(),
    df["f1_macro"].idxmax(),
    df["accuracy"].idxmax(),
]
df.iloc[best_mcc_f1_accuracy_indices][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                   model                dataset scaled  pca_components  \
# 1586  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 1459  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 1586  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
#
#       resampling  matthews_corrcoef  f1_macro  accuracy
# 1586  SMOTETOMEK           0.666237  0.608285  0.729215
# 1459       SMOTE           0.637998  0.620410  0.702635
# 1586  SMOTETOMEK           0.666237  0.608285  0.729215

# %%
df.sort_values("matthews_corrcoef", ascending=False)[0:200][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
].value_counts('dataset')
# Out:
# dataset
# dataset_00_all.pickle    200
# dtype: int64

# %% [markdown]
# **Detailed summary of current best mcc result.**

# %%
df.iloc[best_mcc_f1_accuracy_indices[0]]
# Out:
# model                    XGBoostClassifier
# dataset              dataset_00_all.pickle
# timestamp                       1658136355
# scaled                                 yes
# pca_components                         0.0
# resampling                      SMOTETOMEK
# learning_rate                     0.221461
# n_estimators                           827
# max_depth                                4
# gamma                             0.524969
# reg_alpha                         4.327827
# seed                                  1962
# fit_tim                         193.808802
# core_tim                           0.37062
# matthews_corrcoef                 0.666237
# f1_macro                          0.608285
# accuracy                          0.729215
# Name: 1586, dtype: object

# %% [markdown]
# **Number of trials logged.**

# %%
df.shape[0]
# Out:
# 2249

# %% [markdown]
# **Group results by timestamp, resampling and pca_components, then show current best mcc by group.**

# %%
indices_for_best_mcc = df.groupby(
    ["timestamp", "resampling", "pca_components", "scaled"]
)["matthews_corrcoef"].idxmax()
df.iloc[indices_for_best_mcc][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                   model                          dataset scaled  \
# 84    XGBoostClassifier           dataset_01_mean.pickle     no
# 524   XGBoostClassifier           dataset_01_mean.pickle    yes
# 327   XGBoostClassifier           dataset_01_mean.pickle     no
# 750   XGBoostClassifier           dataset_01_mean.pickle    yes
# 152   XGBoostClassifier           dataset_01_mean.pickle     no
# 591   XGBoostClassifier           dataset_01_mean.pickle    yes
# 378   XGBoostClassifier           dataset_01_mean.pickle     no
# 811   XGBoostClassifier           dataset_01_mean.pickle    yes
# 203   XGBoostClassifier           dataset_01_mean.pickle     no
# 643   XGBoostClassifier           dataset_01_mean.pickle    yes
# 438   XGBoostClassifier           dataset_01_mean.pickle     no
# 878   XGBoostClassifier           dataset_01_mean.pickle    yes
# 38    XGBoostClassifier           dataset_01_mean.pickle     no
# 478   XGBoostClassifier           dataset_01_mean.pickle    yes
# 273   XGBoostClassifier           dataset_01_mean.pickle     no
# 713   XGBoostClassifier           dataset_01_mean.pickle    yes
# 1368  XGBoostClassifier            dataset_00_all.pickle    yes
# 939   XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1192  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1000  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1255  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1078  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1295  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 913   XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1130  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1459  XGBoostClassifier            dataset_00_all.pickle    yes
# 1483  XGBoostClassifier            dataset_00_all.pickle    yes
# 1586  XGBoostClassifier            dataset_00_all.pickle    yes
# 1373  XGBoostClassifier            dataset_00_all.pickle    yes
# 1678  XGBoostClassifier            dataset_00_all.pickle    yes
# 1751  XGBoostClassifier            dataset_00_all.pickle    yes
# 1806  XGBoostClassifier            dataset_00_all.pickle    yes
# 1641  XGBoostClassifier            dataset_00_all.pickle    yes
# 1880  XGBoostClassifier           dataset_05_pvtt.pickle    yes
# 2094  XGBoostClassifier           dataset_05_pvtt.pickle    yes
# 1969  XGBoostClassifier           dataset_05_pvtt.pickle    yes
# 2164  XGBoostClassifier           dataset_05_pvtt.pickle    yes
# 2007  XGBoostClassifier           dataset_05_pvtt.pickle    yes
# 2194  XGBoostClassifier           dataset_05_pvtt.pickle    yes
# 1842  XGBoostClassifier           dataset_05_pvtt.pickle    yes
# 2029  XGBoostClassifier           dataset_05_pvtt.pickle    yes
#
#       pca_components  resampling  matthews_corrcoef  f1_macro  accuracy
# 84              0.00       SMOTE           0.417633  0.391702  0.512646
# 524             0.00       SMOTE           0.422323  0.397869  0.517096
# 327             0.95       SMOTE           0.296870  0.273581  0.380386
# 750             0.95       SMOTE           0.396496  0.371039  0.495785
# 152             0.00    SMOTEENN           0.360060  0.335622  0.428981
# 591             0.00    SMOTEENN           0.379060  0.352207  0.450468
# 378             0.95    SMOTEENN           0.266744  0.248552  0.338993
# 811             0.95    SMOTEENN           0.343730  0.321648  0.411944
# 203             0.00  SMOTETOMEK           0.446103  0.363238  0.556733
# 643             0.00  SMOTETOMEK           0.446103  0.363238  0.556733
# 438             0.95  SMOTETOMEK           0.380927  0.247319  0.509368
# 878             0.95  SMOTETOMEK           0.423126  0.336327  0.539637
# 38              0.00        none           0.446103  0.363238  0.556733
# 478             0.00        none           0.446103  0.363238  0.556733
# 273             0.95        none           0.380927  0.247319  0.509368
# 713             0.95        none           0.423126  0.336327  0.539637
# 1368            0.00        none           0.659560  0.597724  0.723888
# 939             0.00       SMOTE           0.559983  0.532049  0.637354
# 1192            0.95       SMOTE           0.507308  0.482160  0.593443
# 1000            0.00    SMOTEENN           0.483481  0.451981  0.538759
# 1255            0.95    SMOTEENN           0.434471  0.406634  0.497307
# 1078            0.00  SMOTETOMEK           0.567610  0.496467  0.650995
# 1295            0.95  SMOTETOMEK           0.518244  0.441687  0.612529
# 913             0.00        none           0.567610  0.496467  0.650995
# 1130            0.95        none           0.518244  0.441687  0.612529
# 1459            0.00       SMOTE           0.637998  0.620410  0.702635
# 1483            0.00    SMOTEENN           0.566431  0.540275  0.617447
# 1586            0.00  SMOTETOMEK           0.666237  0.608285  0.729215
# 1373            0.00        none           0.658313  0.598556  0.723009
# 1678            0.95       SMOTE           0.619474  0.589227  0.688993
# 1751            0.95    SMOTEENN           0.523813  0.497720  0.578864
# 1806            0.95  SMOTETOMEK           0.609650  0.534660  0.684602
# 1641            0.95        none           0.609650  0.534660  0.684602
# 1880            0.00       SMOTE           0.398013  0.364117  0.490925
# 2094            0.95       SMOTE           0.315690  0.283151  0.393150
# 1969            0.00    SMOTEENN           0.352095  0.321239  0.413993
# 2164            0.95    SMOTEENN           0.287467  0.256963  0.350995
# 2007            0.00  SMOTETOMEK           0.438515  0.334268  0.549824
# 2194            0.95  SMOTETOMEK           0.389592  0.234468  0.515105
# 1842            0.00        none           0.438515  0.334268  0.549824
# 2029            0.95        none           0.389592  0.234468  0.515105

# %%
indices_for_best_mcc = df.groupby(["timestamp"])["matthews_corrcoef"].idxmax()
df.iloc[indices_for_best_mcc][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                   model                          dataset scaled  \
# 38    XGBoostClassifier           dataset_01_mean.pickle     no
# 1368  XGBoostClassifier            dataset_00_all.pickle    yes
# 913   XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1586  XGBoostClassifier            dataset_00_all.pickle    yes
# 1678  XGBoostClassifier            dataset_00_all.pickle    yes
# 1842  XGBoostClassifier           dataset_05_pvtt.pickle    yes
#
#       pca_components  resampling  matthews_corrcoef  f1_macro  accuracy
# 38              0.00        none           0.446103  0.363238  0.556733
# 1368            0.00        none           0.659560  0.597724  0.723888
# 913             0.00        none           0.567610  0.496467  0.650995
# 1586            0.00  SMOTETOMEK           0.666237  0.608285  0.729215
# 1678            0.95       SMOTE           0.619474  0.589227  0.688993
# 1842            0.00        none           0.438515  0.334268  0.549824
