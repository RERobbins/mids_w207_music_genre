# %%
import json
import pandas as pd

# %%
filename="../rich/bayesian_optimization_logs.json"

# %%
with open (filename, "r") as infile:
    json_list = [json.loads(line) for line in infile]
df=pd.json_normalize(json_list)

# %% [markdown]
# **Current best mcc, f1_macro and accuracy results, respectively.**

# %%
best_mcc_f1_accuracy_indices = [df['matthews_corrcoef'].idxmax(),
                                df['f1_macro'].idxmax(),
                                df['accuracy'].idxmax()]
df.iloc[best_mcc_f1_accuracy_indices][['model', 'dataset', 'scaled', 'pca_components', 
                                       'resampling', 'matthews_corrcoef', 'f1_macro', 'accuracy']]
# Out:
#                  model                          dataset scaled  \
# 913  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 939  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 913  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
#
#      pca_components resampling  matthews_corrcoef  f1_macro  accuracy
# 913             0.0       none           0.567610  0.496467  0.650995
# 939             0.0      SMOTE           0.559983  0.532049  0.637354
# 913             0.0       none           0.567610  0.496467  0.650995

# %% [markdown]
# **Detailed summary of current best mcc result.**

# %%
df.iloc[best_mcc_f1_accuracy_indices[0]]
# Out:
# model                              XGBoostClassifier
# dataset              dataset_07_pvtt_mean_cov.pickle
# timestamp                                 1658093789
# scaled                                           yes
# pca_components                                   0.0
# resampling                                      none
# learning_rate                               0.025562
# n_estimators                                     426
# max_depth                                          8
# gamma                                       0.313288
# reg_alpha                                   3.993472
# seed                                            1962
# fit_tim                                   795.653963
# core_tim                                     0.22103
# matthews_corrcoef                            0.56761
# f1_macro                                    0.496467
# accuracy                                    0.650995
# Name: 913, dtype: object

# %% [markdown]
# **Number of trials logged.**

# %%
df.shape[0]
# Out:
# 1320

# %% [markdown]
# **Group results by timestamp, resampling and pca_components, then show current best mcc by group.**

# %%
indices_for_best_mcc = df.groupby(['timestamp', 'resampling', 'pca_components', 'scaled'])['matthews_corrcoef'].idxmax()
df.iloc[indices_for_best_mcc][
    ['model', 'dataset', 'scaled', 'pca_components', 'resampling', 'matthews_corrcoef', 'f1_macro', 'accuracy']
]
# Out:
#                   model                          dataset scaled  \
# 84    XGBoostClassifier           dataset_01_mean.pickle     no
# 524   XGBoostClassifier           dataset_01_mean.pickle    yes
# 327   XGBoostClassifier           dataset_01_mean.pickle     no
# 750   XGBoostClassifier           dataset_01_mean.pickle    yes
# 152   XGBoostClassifier           dataset_01_mean.pickle     no
# 591   XGBoostClassifier           dataset_01_mean.pickle    yes
# 378   XGBoostClassifier           dataset_01_mean.pickle     no
# 811   XGBoostClassifier           dataset_01_mean.pickle    yes
# 203   XGBoostClassifier           dataset_01_mean.pickle     no
# 643   XGBoostClassifier           dataset_01_mean.pickle    yes
# 438   XGBoostClassifier           dataset_01_mean.pickle     no
# 878   XGBoostClassifier           dataset_01_mean.pickle    yes
# 38    XGBoostClassifier           dataset_01_mean.pickle     no
# 478   XGBoostClassifier           dataset_01_mean.pickle    yes
# 273   XGBoostClassifier           dataset_01_mean.pickle     no
# 713   XGBoostClassifier           dataset_01_mean.pickle    yes
# 939   XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1192  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1000  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1255  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1078  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1295  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 913   XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
# 1130  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
#
#       pca_components  resampling  matthews_corrcoef  f1_macro  accuracy
# 84              0.00       SMOTE           0.417633  0.391702  0.512646
# 524             0.00       SMOTE           0.422323  0.397869  0.517096
# 327             0.95       SMOTE           0.296870  0.273581  0.380386
# 750             0.95       SMOTE           0.396496  0.371039  0.495785
# 152             0.00    SMOTEENN           0.360060  0.335622  0.428981
# 591             0.00    SMOTEENN           0.379060  0.352207  0.450468
# 378             0.95    SMOTEENN           0.266744  0.248552  0.338993
# 811             0.95    SMOTEENN           0.343730  0.321648  0.411944
# 203             0.00  SMOTETOMEK           0.446103  0.363238  0.556733
# 643             0.00  SMOTETOMEK           0.446103  0.363238  0.556733
# 438             0.95  SMOTETOMEK           0.380927  0.247319  0.509368
# 878             0.95  SMOTETOMEK           0.423126  0.336327  0.539637
# 38              0.00        none           0.446103  0.363238  0.556733
# 478             0.00        none           0.446103  0.363238  0.556733
# 273             0.95        none           0.380927  0.247319  0.509368
# 713             0.95        none           0.423126  0.336327  0.539637
# 939             0.00       SMOTE           0.559983  0.532049  0.637354
# 1192            0.95       SMOTE           0.507308  0.482160  0.593443
# 1000            0.00    SMOTEENN           0.483481  0.451981  0.538759
# 1255            0.95    SMOTEENN           0.434471  0.406634  0.497307
# 1078            0.00  SMOTETOMEK           0.567610  0.496467  0.650995
# 1295            0.95  SMOTETOMEK           0.518244  0.441687  0.612529
# 913             0.00        none           0.567610  0.496467  0.650995
# 1130            0.95        none           0.518244  0.441687  0.612529

# %%
indices_for_best_mcc = df.groupby(['timestamp'])['matthews_corrcoef'].idxmax()
df.iloc[indices_for_best_mcc][
    ['model', 'dataset', 'scaled', 'pca_components', 'resampling', 'matthews_corrcoef', 'f1_macro', 'accuracy']
]
# Out:
#                  model                          dataset scaled  \
# 38   XGBoostClassifier           dataset_01_mean.pickle     no
# 913  XGBoostClassifier  dataset_07_pvtt_mean_cov.pickle    yes
#
#      pca_components resampling  matthews_corrcoef  f1_macro  accuracy
# 38              0.0       none           0.446103  0.363238  0.556733
# 913             0.0       none           0.567610  0.496467  0.650995
