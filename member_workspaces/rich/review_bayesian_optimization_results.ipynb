# %%
import json
import pandas as pd

# %%
filename="../../rich/bayesian_optimization_logs.json"

# %%
with open (filename, "r") as infile:
    json_list = [json.loads(line) for line in infile]
df=pd.json_normalize(json_list)

# %%
df['matthews_corrcoef'].idxmax()
# Out:
# 34

# %%
df['f1_macro'].idxmax()
# Out:
# 34

# %%
df['accuracy'].idxmax()
# Out:
# 34

# %%
df.iloc[34]
# Out:
# model                XGBoostClassifier
# dataset                 dataset_00_all
# timestamp                   1657898711
# scaled                             yes
# pca_components                    0.95
# resampling                        none
# learning_rate                  0.09087
# n_estimators                       846
# max_depth                            8
# gamma                         0.103085
# reg_alpha                    14.734839
# seed                              1962
# fit_tim                      489.05432
# core_tim                      0.124999
# matthews_corrcoef             0.603903
# f1_macro                      0.526095
# accuracy                      0.680035
# Name: 34, dtype: object

# %%
df
# Out:
#                  model                 dataset   timestamp scaled  \
# 0    XGBoostClassifier          dataset_00_all  1657898711    yes
# 1    XGBoostClassifier          dataset_00_all  1657898711    yes
# 2    XGBoostClassifier          dataset_00_all  1657898711    yes
# 3    XGBoostClassifier          dataset_00_all  1657898711    yes
# 4    XGBoostClassifier          dataset_00_all  1657898711    yes
# ..                 ...                     ...         ...    ...
# 118  XGBoostClassifier  dataset_01_mean.pickle  1657921565     no
# 119  XGBoostClassifier  dataset_01_mean.pickle  1657921565     no
# 120  XGBoostClassifier  dataset_01_mean.pickle  1657921565     no
# 121  XGBoostClassifier  dataset_01_mean.pickle  1657921565     no
# 122  XGBoostClassifier  dataset_01_mean.pickle  1657921565     no
#
#      pca_components resampling  learning_rate  n_estimators  max_depth  \
# 0              0.95       none       0.106177           847          7
# 1              0.95       none       0.817638           202          4
# 2              0.95       none       0.912352           988          8
# 3              0.95       none       0.556415           993          3
# 4              0.95       none       0.114840           426          8
# ..              ...        ...            ...           ...        ...
# 118            0.00       none       0.019368           431          4
# 119            0.00       none       0.260529           426          8
# 120            0.00       none       0.876342           425          9
# 121            0.00       none       0.814499           426          6
# 122            0.00       none       0.296367           429          9
#
#         gamma  reg_alpha  seed     fit_tim  core_tim  matthews_corrcoef  \
# 0    0.809896  15.199520  1962  262.438874  0.075653           0.588490
# 1    3.180340  14.920890  1962   31.833685  0.016026           0.533100
# 2    4.064809  17.454995  1962  157.511351  0.031116           0.504691
# 3    3.588053   1.935608  1962  130.878088  0.034916           0.565404
# 4    0.327162   6.880454  1962  342.182162  0.084514           0.597161
# ..        ...        ...   ...         ...       ...                ...
# 118  3.893144   2.932606  1962   67.941765  0.053699           0.414483
# 119  0.602752   7.861804  1962   50.396447  0.022481           0.434587
# 120  2.841564   4.949709  1962   36.123869  0.012977           0.403373
# 121  0.098363   7.621656  1962   43.853090  0.017191           0.422734
# 122  0.456750   8.110952  1962   53.661883  0.022990           0.432818
#
#      f1_macro  accuracy
# 0    0.509233  0.667857
# 1    0.458352  0.623478
# 2    0.432476  0.600410
# 3    0.498041  0.649063
# 4    0.525327  0.674649
# ..        ...       ...
# 118  0.286021  0.534309
# 119  0.338152  0.548068
# 120  0.318349  0.522365
# 121  0.348304  0.536827
# 122  0.339615  0.546429
#
# [123 rows x 17 columns]

# %%
arg_scaling = [False, True]
arg_pca = [None, .95]
arg_resampling = [None, 'SMOTE', 'SMOTEENN', 'SMOTETOMEK']
arg_dicts = [{'scaling': scaling,
              'pca_components': pca_components,
              'resampling': resampling}
             for scaling in arg_scaling
             for pca_components in arg_pca
             for resampling in arg_resampling]
arg_dicts
# Out:
# [{'scaling': False, 'pca_components': None, 'resampling': None},
#  {'scaling': False, 'pca_components': None, 'resampling': 'SMOTE'},
#  {'scaling': False, 'pca_components': None, 'resampling': 'SMOTEENN'},
#  {'scaling': False, 'pca_components': None, 'resampling': 'SMOTETOMEK'},
#  {'scaling': False, 'pca_components': 0.95, 'resampling': None},
#  {'scaling': False, 'pca_components': 0.95, 'resampling': 'SMOTE'},
#  {'scaling': False, 'pca_components': 0.95, 'resampling': 'SMOTEENN'},
#  {'scaling': False, 'pca_components': 0.95, 'resampling': 'SMOTETOMEK'},
#  {'scaling': True, 'pca_components': None, 'resampling': None},
#  {'scaling': True, 'pca_components': None, 'resampling': 'SMOTE'},
#  {'scaling': True, 'pca_components': None, 'resampling': 'SMOTEENN'},
#  {'scaling': True, 'pca_components': None, 'resampling': 'SMOTETOMEK'},
#  {'scaling': True, 'pca_components': 0.95, 'resampling': None},
#  {'scaling': True, 'pca_components': 0.95, 'resampling': 'SMOTE'},
#  {'scaling': True, 'pca_components': 0.95, 'resampling': 'SMOTEENN'},
#  {'scaling': True, 'pca_components': 0.95, 'resampling': 'SMOTETOMEK'}]
