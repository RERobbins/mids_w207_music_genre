# %%
import json

import pandas as pd

# %%
filename = "../rich/merged_results.json"

# %%
with open(filename, "r") as infile:
    json_list = [json.loads(line) for line in infile]
df = pd.json_normalize(json_list)

# %% [markdown]
# **Current best mcc, f1_macro and accuracy results, respectively.**

# %%
best_mcc_f1_accuracy_indices = [
    df["matthews_corrcoef"].idxmax(),
    df["f1_macro"].idxmax(),
    df["accuracy"].idxmax(),
]
df.iloc[best_mcc_f1_accuracy_indices][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                  model                dataset scaled  pca_components  \
# 266  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 139  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
# 266  XGBoostClassifier  dataset_00_all.pickle    yes             0.0
#
#      resampling  matthews_corrcoef  f1_macro  accuracy
# 266  SMOTETOMEK           0.666237  0.608285  0.729215
# 139       SMOTE           0.637998  0.620410  0.702635
# 266  SMOTETOMEK           0.666237  0.608285  0.729215

# %%
df.sort_values("matthews_corrcoef", ascending=False)[0:200][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
].value_counts('dataset')
# Out:
# dataset
# dataset_00_all.pickle    200
# dtype: int64

# %% [markdown]
# **Detailed summary of current best mcc result.**

# %%
df.iloc[best_mcc_f1_accuracy_indices[0]]
# Out:
# model                    XGBoostClassifier
# dataset              dataset_00_all.pickle
# timestamp                       1658136355
# scaled                                 yes
# pca_components                         0.0
# resampling                      SMOTETOMEK
# learning_rate                     0.221461
# n_estimators                           827
# max_depth                                4
# gamma                             0.524969
# reg_alpha                         4.327827
# seed                                  1962
# fit_tim                         193.808802
# core_tim                           0.37062
# matthews_corrcoef                 0.666237
# f1_macro                          0.608285
# accuracy                          0.729215
# Name: 266, dtype: object

# %% [markdown]
# **Number of trials logged.**

# %%
df.shape[0]
# Out:
# 1369

# %% [markdown]
# **Group results by timestamp, resampling and pca_components, then show current best mcc by group.**

# %%
indices_for_best_mcc = df.groupby(
    ["timestamp", "resampling", "pca_components", "scaled"]
)["matthews_corrcoef"].idxmax()
df.iloc[indices_for_best_mcc][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                  model                 dataset scaled  pca_components  \
# 48   XGBoostClassifier   dataset_00_all.pickle    yes            0.00
# 139  XGBoostClassifier   dataset_00_all.pickle    yes            0.00
# 163  XGBoostClassifier   dataset_00_all.pickle    yes            0.00
# 266  XGBoostClassifier   dataset_00_all.pickle    yes            0.00
# 53   XGBoostClassifier   dataset_00_all.pickle    yes            0.00
# 358  XGBoostClassifier   dataset_00_all.pickle    yes            0.95
# 431  XGBoostClassifier   dataset_00_all.pickle    yes            0.95
# 486  XGBoostClassifier   dataset_00_all.pickle    yes            0.95
# 321  XGBoostClassifier   dataset_00_all.pickle    yes            0.95
# 560  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.00
# 774  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.95
# 649  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.00
# 844  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.95
# 687  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.00
# 874  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.95
# 522  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.00
# 709  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.95
#
#      resampling  matthews_corrcoef  f1_macro  accuracy
# 48         none           0.659560  0.597724  0.723888
# 139       SMOTE           0.637998  0.620410  0.702635
# 163    SMOTEENN           0.566431  0.540275  0.617447
# 266  SMOTETOMEK           0.666237  0.608285  0.729215
# 53         none           0.658313  0.598556  0.723009
# 358       SMOTE           0.619474  0.589227  0.688993
# 431    SMOTEENN           0.523813  0.497720  0.578864
# 486  SMOTETOMEK           0.609650  0.534660  0.684602
# 321        none           0.609650  0.534660  0.684602
# 560       SMOTE           0.398013  0.364117  0.490925
# 774       SMOTE           0.315690  0.283151  0.393150
# 649    SMOTEENN           0.352095  0.321239  0.413993
# 844    SMOTEENN           0.287467  0.256963  0.350995
# 687  SMOTETOMEK           0.438515  0.334268  0.549824
# 874  SMOTETOMEK           0.389592  0.234468  0.515105
# 522        none           0.438515  0.334268  0.549824
# 709        none           0.389592  0.234468  0.515105

# %%
indices_for_best_mcc = df.groupby(["timestamp"])["matthews_corrcoef"].idxmax()
df.iloc[indices_for_best_mcc][
    [
        "model",
        "dataset",
        "scaled",
        "pca_components",
        "resampling",
        "matthews_corrcoef",
        "f1_macro",
        "accuracy",
    ]
]
# Out:
#                  model                 dataset scaled  pca_components  \
# 48   XGBoostClassifier   dataset_00_all.pickle    yes            0.00
# 266  XGBoostClassifier   dataset_00_all.pickle    yes            0.00
# 358  XGBoostClassifier   dataset_00_all.pickle    yes            0.95
# 522  XGBoostClassifier  dataset_05_pvtt.pickle    yes            0.00
#
#      resampling  matthews_corrcoef  f1_macro  accuracy
# 48         none           0.659560  0.597724  0.723888
# 266  SMOTETOMEK           0.666237  0.608285  0.729215
# 358       SMOTE           0.619474  0.589227  0.688993
# 522        none           0.438515  0.334268  0.549824
