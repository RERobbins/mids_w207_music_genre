# %%
import glob
import sys

import numpy as np
import pandas as pd
from sklearn.mixture import GaussianMixture

sys.path.append("../../")

from helpers.experiment import experiment

# %%
dataset_folder = "../../datasets/"
datasets = sorted([name for name in glob.glob(dataset_folder + "dataset_*.pickle")])

for dataset in datasets:
    
    if "spectrogram" in dataset:
        n_components = 2400
    else:
        n_components = 2
        
    model = GaussianMixture(
        n_components=10,
        max_iter=200
    )
    # experiment(model, dataset, pca_components=n_components, result_filename="gmm_results.json")
    experiment(model, dataset, result_filename="gmm_results.json")
# Out:
# Commencing Experiment: GaussianMixture_dataset_01_mean
#
# Training accuracy: train_accuracy = -12.855025
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\gmm_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0177  0.1310    0.0311      374  -0.0127
#   genre_classical     0.8333  0.2357    0.3675     4221   0.3726
#     genre_country     0.0123  0.0917    0.0216      327  -0.0205
#       genre_disco     0.0000  0.0000    0.0000      289  -0.0365
#      genre_hiphop     0.0372  0.0453    0.0409     1701  -0.0773
#        genre_jazz     0.0688  0.0790    0.0735     1241  -0.0045
#       genre_metal     0.0104  0.0421    0.0167      665  -0.0638
#         genre_pop     0.2605  0.0480    0.0810     4274   0.0052
#      genre_reggae     0.0199  0.0114    0.0145      788  -0.0207
# ...
