# %%
import glob
import sys

import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression

sys.path.append("../../")

from helpers.experiment import experiment

# %%
dataset_folder = "../../datasets/"
datasets = sorted([name for name in glob.glob(dataset_folder + "dataset_*.pickle")])

for dataset in datasets:

    if "spectrogram" in dataset:
        n_components = 2400
    else:
        n_components = .95
      
    model = LogisticRegression(
        C=5.0,
        multi_class="auto",
        max_iter=500,
        class_weight="balanced",
    )

    experiment(model, dataset, pca_components=n_components, result_filename="test_results.json")
# Out:
# Commencing Experiment: LogisticRegression_dataset_01_mean
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.360363
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# File do not exist, creating file now
# saving model logisticregression_dataset_01_mean_pca_train
# Empty DataFrame
# Columns: []
# Index: []
#                 model              dataset  phase  \
# 0  LogisticRegression  dataset_01_mean_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.05290546400693...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0529  0.1631    0.0799      374  0.0570
#   genre_classical     0.8047  0.7233    0.7618     4221  0.6907
#     genre_country     0.0844  0.4098    0.1400      327  0.1525
#       genre_disco     0.0739  0.4256    0.1260      289  0.1452
#      genre_hiphop     0.2870  0.1552    0.2014     1701  0.1493
#        genre_jazz     0.2572  0.3836    0.3079     1241  0.2478
#       genre_metal     0.2430  0.7008    0.3608      665  0.3751
#         genre_pop     0.4865  0.1179    0.1898     4274  0.1386
#      genre_reggae     0.1791  0.3325    0.2328      788  0.1940
#        genre_rock     0.4793  0.2537    0.3318     3200  0.2483
#
#          accuracy                       0.3604    17080  0.2885
#         macro avg     0.2948  0.3665    0.2732    17080
#      weighted avg     0.4794  0.3604    0.3717    17080
#               min     0.0529  0.1179    0.0799      289  0.0570
#
# Testing accuracy: test_accuracy = 0.364083
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_01_mean_pca_test
#                 model              dataset  phase  \
# 0  LogisticRegression  dataset_01_mean_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
#                 model              dataset  phase  \
# 0  LogisticRegression  dataset_01_mean_pca  train
# 0  LogisticRegression  dataset_01_mean_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 0  {'genre_blues': {'precision': 0.07299270072992...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0730  0.2128    0.1087       94  0.0910
#   genre_classical     0.7960  0.7251    0.7589     1055  0.6859
#     genre_country     0.0855  0.4390    0.1431       82  0.1598
#       genre_disco     0.0660  0.3750    0.1123       72  0.1243
#      genre_hiphop     0.3194  0.1624    0.2153      425  0.1696
#        genre_jazz     0.2436  0.3698    0.2937      311  0.2317
#       genre_metal     0.2489  0.6988    0.3671      166  0.3803
#         genre_pop     0.5165  0.1319    0.2101     1069  0.1606
#      genre_reggae     0.1458  0.2538    0.1852      197  0.1404
#        genre_rock     0.4954  0.2700    0.3495      800  0.2663
#
#          accuracy                       0.3641     4271  0.2913
#         macro avg     0.2990  0.3639    0.2744     4271
#      weighted avg     0.4890  0.3641    0.3782     4271
#               min     0.0660  0.1319    0.1087       72  0.0910
# Commencing Experiment: LogisticRegression_dataset_02_mean_cov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.475761
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_02_mean_cov_pca_train
#                 model              dataset  phase  \
# 0  LogisticRegression  dataset_01_mean_pca  train
# 1  LogisticRegression  dataset_01_mean_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
#                 model                  dataset  phase  \
# 0  LogisticRegression      dataset_01_mean_pca  train
# 1  LogisticRegression      dataset_01_mean_pca   test
# 0  LogisticRegression  dataset_02_mean_cov_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 0  {'genre_blues': {'precision': 0.09344262295081...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0934  0.3048    0.1430      374  0.1356
#   genre_classical     0.8662  0.7669    0.8135     4221  0.7595
#     genre_country     0.1390  0.6024    0.2259      327  0.2631
#       genre_disco     0.1230  0.5675    0.2022      289  0.2394
#      genre_hiphop     0.5011  0.3962    0.4425     1701  0.3920
#        genre_jazz     0.3930  0.5310    0.4517     1241  0.4072
#       genre_metal     0.3204  0.7940    0.4565      665  0.4755
#         genre_pop     0.5881  0.1827    0.2788     4274  0.2265
#      genre_reggae     0.4050  0.6193    0.4897      788  0.4713
#        genre_rock     0.5917  0.4012    0.4782     3200  0.3953
#
#          accuracy                       0.4758    17080  0.4136
#         macro avg     0.4021  0.5166    0.3982    17080
#      weighted avg     0.5885  0.4758    0.4886    17080
#               min     0.0934  0.1827    0.1430      289  0.1356
#
# Testing accuracy: test_accuracy = 0.478576
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_02_mean_cov_pca_test
#                 model                  dataset  phase  \
# 0  LogisticRegression      dataset_01_mean_pca  train
# 1  LogisticRegression      dataset_01_mean_pca   test
# 2  LogisticRegression  dataset_02_mean_cov_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
#                 model                  dataset  phase  \
# 0  LogisticRegression      dataset_01_mean_pca  train
# 1  LogisticRegression      dataset_01_mean_pca   test
# 2  LogisticRegression  dataset_02_mean_cov_pca  train
# 0  LogisticRegression  dataset_02_mean_cov_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 0  {'genre_blues': {'precision': 0.10150375939849...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1015  0.2872    0.1500       94  0.1396
#   genre_classical     0.8665  0.7877    0.8252     1055  0.7730
#     genre_country     0.1401  0.6098    0.2278       82  0.2660
#       genre_disco     0.1268  0.6111    0.2100       72  0.2540
#      genre_hiphop     0.4766  0.3600    0.4102      425  0.3591
#        genre_jazz     0.4009  0.5659    0.4693      311  0.4274
#       genre_metal     0.3027  0.7530    0.4318      166  0.4466
#         genre_pop     0.6132  0.1824    0.2812     1069  0.2376
#      genre_reggae     0.3993  0.5533    0.4638      197  0.4399
#        genre_rock     0.5779  0.4175    0.4848      800  0.3960
#
#          accuracy                       0.4786     4271  0.4157
#         macro avg     0.4005  0.5128    0.3954     4271
#      weighted avg     0.5896  0.4786    0.4894     4271
#               min     0.1015  0.1824    0.1500       72  0.1396
# Commencing Experiment: LogisticRegression_dataset_03_mean_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.264988
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_03_mean_icov_pca_train
#                 model                  dataset  phase  \
# 0  LogisticRegression      dataset_01_mean_pca  train
# 1  LogisticRegression      dataset_01_mean_pca   test
# 2  LogisticRegression  dataset_02_mean_cov_pca  train
# 3  LogisticRegression  dataset_02_mean_cov_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
#                 model                   dataset  phase  \
# 0  LogisticRegression       dataset_01_mean_pca  train
# 1  LogisticRegression       dataset_01_mean_pca   test
# 2  LogisticRegression   dataset_02_mean_cov_pca  train
# 3  LogisticRegression   dataset_02_mean_cov_pca   test
# 0  LogisticRegression  dataset_03_mean_icov_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 0  {'genre_blues': {'precision': 0.03797468354430...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0380  0.0802    0.0515      374  0.0242
#   genre_classical     0.6441  0.6671    0.6554     4221  0.5398
#     genre_country     0.0346  0.2477    0.0607      327  0.0449
#       genre_disco     0.0231  0.0450    0.0305      289  0.0088
#      genre_hiphop     0.1618  0.0523    0.0791     1701  0.0379
#        genre_jazz     0.1936  0.1612    0.1759     1241  0.1182
#       genre_metal     0.0999  0.6466    0.1730      665  0.1829
#         genre_pop     0.3119  0.0498    0.0859     4274  0.0290
#      genre_reggae     0.0820  0.0381    0.0520      788  0.0253
#        genre_rock     0.3007  0.1950    0.2366     3200  0.1080
#
#          accuracy                       0.2650    17080  0.1776
#         macro avg     0.1890  0.2183    0.1601    17080
#      weighted avg     0.3333  0.2650    0.2604    17080
#               min     0.0231  0.0381    0.0305      289  0.0088
#
# Testing accuracy: test_accuracy = 0.261297
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_03_mean_icov_pca_test
#                 model                   dataset  phase  \
# 0  LogisticRegression       dataset_01_mean_pca  train
# 1  LogisticRegression       dataset_01_mean_pca   test
# 2  LogisticRegression   dataset_02_mean_cov_pca  train
# 3  LogisticRegression   dataset_02_mean_cov_pca   test
# 4  LogisticRegression  dataset_03_mean_icov_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
#                 model                   dataset  phase  \
# 0  LogisticRegression       dataset_01_mean_pca  train
# 1  LogisticRegression       dataset_01_mean_pca   test
# 2  LogisticRegression   dataset_02_mean_cov_pca  train
# 3  LogisticRegression   dataset_02_mean_cov_pca   test
# 4  LogisticRegression  dataset_03_mean_icov_pca  train
# 0  LogisticRegression  dataset_03_mean_icov_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 0  {'genre_blues': {'precision': 0.03553299492385...
# record saved
#                    precision  recall  f1-score  support      mcc
#
#       genre_blues     0.0355  0.0745    0.0481       94   0.0203
#   genre_classical     0.6420  0.6834    0.6621     1055   0.5471
#     genre_country     0.0186  0.1341    0.0327       82  -0.0017
#       genre_disco     0.0000  0.0000    0.0000       72  -0.0241
#      genre_hiphop     0.1143  0.0376    0.0566      425   0.0091
#        genre_jazz     0.1905  0.1672    0.1781      311   0.1183
#       genre_metal     0.0965  0.6205    0.1671      166   0.1722
#         genre_pop     0.3688  0.0552    0.0960     1069   0.0539
#      genre_reggae     0.1020  0.0508    0.0678      197   0.0409
#        genre_rock     0.2842  0.1713    0.2137      800   0.0886
#
#          accuracy                       0.2613     4271   0.1735
#         macro avg     0.1852  0.1995    0.1522     4271
#      weighted avg     0.3390  0.2613    0.2575     4271
#               min     0.0000  0.0000    0.0000       72  -0.0241
# Commencing Experiment: LogisticRegression_dataset_04_mean_cov_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.463934
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_04_mean_cov_icov_pca_train
#                 model                   dataset  phase  \
# 0  LogisticRegression       dataset_01_mean_pca  train
# 1  LogisticRegression       dataset_01_mean_pca   test
# 2  LogisticRegression   dataset_02_mean_cov_pca  train
# 3  LogisticRegression   dataset_02_mean_cov_pca   test
# 4  LogisticRegression  dataset_03_mean_icov_pca  train
# 5  LogisticRegression  dataset_03_mean_icov_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 0  LogisticRegression  dataset_04_mean_cov_icov_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 0  {'genre_blues': {'precision': 0.08752025931928...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0875  0.2888    0.1343      374  0.1251
#   genre_classical     0.8653  0.7505    0.8039     4221  0.7486
#     genre_country     0.1335  0.6024    0.2185      327  0.2566
#       genre_disco     0.1218  0.5536    0.1996      289  0.2347
#      genre_hiphop     0.4882  0.3768    0.4253     1701  0.3745
#        genre_jazz     0.3912  0.5230    0.4476     1241  0.4025
#       genre_metal     0.3008  0.7880    0.4354      665  0.4562
#         genre_pop     0.5927  0.1825    0.2791     4274  0.2284
#      genre_reggae     0.3921  0.6015    0.4747      788  0.4551
#        genre_rock     0.5673  0.3822    0.4567     3200  0.3701
#
#          accuracy                       0.4639    17080  0.4011
#         macro avg     0.3940  0.5049    0.3875    17080
#      weighted avg     0.5818  0.4639    0.4783    17080
#               min     0.0875  0.1825    0.1343      289  0.1251
#
# Testing accuracy: test_accuracy = 0.476469
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_04_mean_cov_icov_pca_test
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 6  LogisticRegression  dataset_04_mean_cov_icov_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 6  {'genre_blues': {'precision': 0.0875202593, 'r...
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 6  LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 0  LogisticRegression  dataset_04_mean_cov_icov_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 6  {'genre_blues': {'precision': 0.0875202593, 'r...
# 0  {'genre_blues': {'precision': 0.09594095940959...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0959  0.2766    0.1425       94  0.1312
#   genre_classical     0.8625  0.7791    0.8187     1055  0.7649
#     genre_country     0.1342  0.5976    0.2192       82  0.2563
#       genre_disco     0.1193  0.5417    0.1955       72  0.2291
#      genre_hiphop     0.4645  0.3388    0.3918      425  0.3411
#        genre_jazz     0.4044  0.5370    0.4613      311  0.4175
#       genre_metal     0.3047  0.7892    0.4396      166  0.4601
#         genre_pop     0.6443  0.2067    0.3130     1069  0.2688
#      genre_reggae     0.3846  0.5584    0.4555      197  0.4323
#        genre_rock     0.5689  0.4075    0.4749      800  0.3850
#
#          accuracy                       0.4765     4271  0.4125
#         macro avg     0.3983  0.5033    0.3912     4271
#      weighted avg     0.5928  0.4765    0.4909     4271
#               min     0.0959  0.2067    0.1425       72  0.1312
# Commencing Experiment: LogisticRegression_dataset_05_pvtt
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.365515
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_05_pvtt_pca_train
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 6  LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7  LogisticRegression  dataset_04_mean_cov_icov_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 6  {'genre_blues': {'precision': 0.0875202593, 'r...
# 7  {'genre_blues': {'precision': 0.0959409594, 'r...
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 6  LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7  LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 0  LogisticRegression           dataset_05_pvtt_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 6  {'genre_blues': {'precision': 0.0875202593, 'r...
# 7  {'genre_blues': {'precision': 0.0959409594, 'r...
# 0  {'genre_blues': {'precision': 0.04139433551198...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0414  0.0508    0.0456      374  0.0221
#   genre_classical     0.8612  0.7555    0.8049     4221  0.7490
#     genre_country     0.0699  0.2508    0.1093      327  0.1006
#       genre_disco     0.0516  0.1696    0.0792      289  0.0653
#      genre_hiphop     0.2412  0.1570    0.1902     1701  0.1245
#        genre_jazz     0.2571  0.3409    0.2931     1241  0.2320
#       genre_metal     0.1951  0.7729    0.3116      665  0.3448
#         genre_pop     0.5197  0.1324    0.2111     4274  0.1624
#      genre_reggae     0.1755  0.4492    0.2524      788  0.2257
#        genre_rock     0.3385  0.2437    0.2834     3200  0.1530
#
#          accuracy                       0.3655    17080  0.2873
#         macro avg     0.2751  0.3323    0.2581    17080
#      weighted avg     0.4678  0.3655    0.3733    17080
#               min     0.0414  0.0508    0.0456      289  0.0221
#
# Testing accuracy: test_accuracy = 0.372981
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_05_pvtt_pca_test
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 6  LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7  LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8  LogisticRegression           dataset_05_pvtt_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 6  {'genre_blues': {'precision': 0.0875202593, 'r...
# 7  {'genre_blues': {'precision': 0.0959409594, 'r...
# 8  {'genre_blues': {'precision': 0.0413943355, 'r...
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 6  LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7  LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8  LogisticRegression           dataset_05_pvtt_pca  train
# 0  LogisticRegression           dataset_05_pvtt_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 6  {'genre_blues': {'precision': 0.0875202593, 'r...
# 7  {'genre_blues': {'precision': 0.0959409594, 'r...
# 8  {'genre_blues': {'precision': 0.0413943355, 'r...
# 0  {'genre_blues': {'precision': 0.07207207207207...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0721  0.0851    0.0780       94  0.0557
#   genre_classical     0.8522  0.7763    0.8125     1055  0.7562
#     genre_country     0.0825  0.3049    0.1299       82  0.1275
#       genre_disco     0.0876  0.2361    0.1278       72  0.1199
#      genre_hiphop     0.2204  0.1624    0.1870      425  0.1136
#        genre_jazz     0.2790  0.3794    0.3215      311  0.2630
#       genre_metal     0.1904  0.7410    0.3030      166  0.3310
#         genre_pop     0.5149  0.1132    0.1856     1069  0.1474
#      genre_reggae     0.1772  0.4264    0.2504      197  0.2208
#        genre_rock     0.3421  0.2612    0.2962      800  0.1621
#
#          accuracy                       0.3730     4271  0.2945
#         macro avg     0.2818  0.3486    0.2692     4271
#      weighted avg     0.4659  0.3730    0.3743     4271
#               min     0.0721  0.0851    0.0780       72  0.0557
# Commencing Experiment: LogisticRegression_dataset_06_pvtt_mean
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.411944
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_06_pvtt_mean_pca_train
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 6  LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7  LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8  LogisticRegression           dataset_05_pvtt_pca  train
# 9  LogisticRegression           dataset_05_pvtt_pca   test
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 6  {'genre_blues': {'precision': 0.0875202593, 'r...
# 7  {'genre_blues': {'precision': 0.0959409594, 'r...
# 8  {'genre_blues': {'precision': 0.0413943355, 'r...
# 9  {'genre_blues': {'precision': 0.0720720721, 'r...
#                 model                       dataset  phase  \
# 0  LogisticRegression           dataset_01_mean_pca  train
# 1  LogisticRegression           dataset_01_mean_pca   test
# 2  LogisticRegression       dataset_02_mean_cov_pca  train
# 3  LogisticRegression       dataset_02_mean_cov_pca   test
# 4  LogisticRegression      dataset_03_mean_icov_pca  train
# 5  LogisticRegression      dataset_03_mean_icov_pca   test
# 6  LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7  LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8  LogisticRegression           dataset_05_pvtt_pca  train
# 9  LogisticRegression           dataset_05_pvtt_pca   test
# 0  LogisticRegression      dataset_06_pvtt_mean_pca  train
#
#                                               result
# 0  {'genre_blues': {'precision': 0.052905464, 're...
# 1  {'genre_blues': {'precision': 0.0729927007, 'r...
# 2  {'genre_blues': {'precision': 0.093442623, 're...
# 3  {'genre_blues': {'precision': 0.1015037594, 'r...
# 4  {'genre_blues': {'precision': 0.0379746835, 'r...
# 5  {'genre_blues': {'precision': 0.0355329949, 'r...
# 6  {'genre_blues': {'precision': 0.0875202593, 'r...
# 7  {'genre_blues': {'precision': 0.0959409594, 'r...
# 8  {'genre_blues': {'precision': 0.0413943355, 'r...
# 9  {'genre_blues': {'precision': 0.0720720721, 'r...
# 0  {'genre_blues': {'precision': 0.05288932419196...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0529  0.1444    0.0774      374  0.0534
#   genre_classical     0.8620  0.7797    0.8188     4221  0.7648
#     genre_country     0.0962  0.4006    0.1551      327  0.1655
#       genre_disco     0.1012  0.4498    0.1653      289  0.1864
#      genre_hiphop     0.3236  0.1558    0.2103     1701  0.1679
#        genre_jazz     0.2902  0.4666    0.3578     1241  0.3048
#       genre_metal     0.2518  0.7278    0.3742      665  0.3919
#         genre_pop     0.5513  0.1458    0.2306     4274  0.1850
#      genre_reggae     0.2452  0.4822    0.3251      788  0.2997
#        genre_rock     0.5044  0.3434    0.4086     3200  0.3107
#
#          accuracy                       0.4119    17080  0.3421
#         macro avg     0.3279  0.4096    0.3123    17080
#      weighted avg     0.5246  0.4119    0.4206    17080
#               min     0.0529  0.1444    0.0774      289  0.0534
#
# Testing accuracy: test_accuracy = 0.423086
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_06_pvtt_mean_pca_test
#                  model                       dataset  phase  \
# 0   LogisticRegression           dataset_01_mean_pca  train
# 1   LogisticRegression           dataset_01_mean_pca   test
# 2   LogisticRegression       dataset_02_mean_cov_pca  train
# 3   LogisticRegression       dataset_02_mean_cov_pca   test
# 4   LogisticRegression      dataset_03_mean_icov_pca  train
# 5   LogisticRegression      dataset_03_mean_icov_pca   test
# 6   LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression           dataset_05_pvtt_pca  train
# 9   LogisticRegression           dataset_05_pvtt_pca   test
# 10  LogisticRegression      dataset_06_pvtt_mean_pca  train
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
#                  model                       dataset  phase  \
# 0   LogisticRegression           dataset_01_mean_pca  train
# 1   LogisticRegression           dataset_01_mean_pca   test
# 2   LogisticRegression       dataset_02_mean_cov_pca  train
# 3   LogisticRegression       dataset_02_mean_cov_pca   test
# 4   LogisticRegression      dataset_03_mean_icov_pca  train
# 5   LogisticRegression      dataset_03_mean_icov_pca   test
# 6   LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression           dataset_05_pvtt_pca  train
# 9   LogisticRegression           dataset_05_pvtt_pca   test
# 10  LogisticRegression      dataset_06_pvtt_mean_pca  train
# 0   LogisticRegression      dataset_06_pvtt_mean_pca   test
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 0   {'genre_blues': {'precision': 0.07883817427385...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0788  0.2021    0.1134       94  0.0947
#   genre_classical     0.8545  0.8019    0.8274     1055  0.7738
#     genre_country     0.1020  0.4390    0.1655       82  0.1811
#       genre_disco     0.0987  0.4167    0.1596       72  0.1759
#      genre_hiphop     0.3508  0.1576    0.2175      425  0.1816
#        genre_jazz     0.2874  0.4695    0.3565      311  0.3034
#       genre_metal     0.2624  0.7349    0.3867      166  0.4042
#         genre_pop     0.5690  0.1581    0.2474     1069  0.2011
#      genre_reggae     0.2403  0.4416    0.3113      197  0.2818
#        genre_rock     0.5089  0.3563    0.4191      800  0.3202
#
#          accuracy                       0.4231     4271  0.3524
#         macro avg     0.3353  0.4178    0.3204     4271
#      weighted avg     0.5313  0.4231    0.4302     4271
#               min     0.0788  0.1576    0.1134       72  0.0947
# Commencing Experiment: LogisticRegression_dataset_07_pvtt_mean_cov
#
# PCA pre_processing started
# PCA pre_processing completed
# c:\Users\alvin\anaconda3\envs\W207\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Training accuracy: train_accuracy = 0.489227
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_07_pvtt_mean_cov_pca_train
#                  model                       dataset  phase  \
# 0   LogisticRegression           dataset_01_mean_pca  train
# 1   LogisticRegression           dataset_01_mean_pca   test
# 2   LogisticRegression       dataset_02_mean_cov_pca  train
# 3   LogisticRegression       dataset_02_mean_cov_pca   test
# 4   LogisticRegression      dataset_03_mean_icov_pca  train
# 5   LogisticRegression      dataset_03_mean_icov_pca   test
# 6   LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression           dataset_05_pvtt_pca  train
# 9   LogisticRegression           dataset_05_pvtt_pca   test
# 10  LogisticRegression      dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression      dataset_06_pvtt_mean_pca   test
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
#                  model                       dataset  phase  \
# 0   LogisticRegression           dataset_01_mean_pca  train
# 1   LogisticRegression           dataset_01_mean_pca   test
# 2   LogisticRegression       dataset_02_mean_cov_pca  train
# 3   LogisticRegression       dataset_02_mean_cov_pca   test
# 4   LogisticRegression      dataset_03_mean_icov_pca  train
# 5   LogisticRegression      dataset_03_mean_icov_pca   test
# 6   LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression           dataset_05_pvtt_pca  train
# 9   LogisticRegression           dataset_05_pvtt_pca   test
# 10  LogisticRegression      dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression      dataset_06_pvtt_mean_pca   test
# 0   LogisticRegression  dataset_07_pvtt_mean_cov_pca  train
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 0   {'genre_blues': {'precision': 0.09975267930750...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0998  0.3235    0.1525      374  0.1471
#   genre_classical     0.8835  0.7889    0.8335     4221  0.7851
#     genre_country     0.1477  0.6116    0.2380      327  0.2753
#       genre_disco     0.1333  0.6159    0.2192      289  0.2628
#      genre_hiphop     0.5164  0.4156    0.4606     1701  0.4109
#        genre_jazz     0.4094  0.5568    0.4718     1241  0.4296
#       genre_metal     0.3151  0.7880    0.4502      665  0.4689
#         genre_pop     0.6014  0.1818    0.2792     4274  0.2319
#      genre_reggae     0.4174  0.6320    0.5028      788  0.4850
#        genre_rock     0.6034  0.4156    0.4922     3200  0.4105
#
#          accuracy                       0.4892    17080  0.4291
#         macro avg     0.4127  0.5330    0.4100    17080
#      weighted avg     0.6019  0.4892    0.5006    17080
#               min     0.0998  0.1818    0.1525      289  0.1471
#
# Testing accuracy: test_accuracy = 0.490049
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_07_pvtt_mean_cov_pca_test
#                  model                       dataset  phase  \
# 0   LogisticRegression           dataset_01_mean_pca  train
# 1   LogisticRegression           dataset_01_mean_pca   test
# 2   LogisticRegression       dataset_02_mean_cov_pca  train
# 3   LogisticRegression       dataset_02_mean_cov_pca   test
# 4   LogisticRegression      dataset_03_mean_icov_pca  train
# 5   LogisticRegression      dataset_03_mean_icov_pca   test
# 6   LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression           dataset_05_pvtt_pca  train
# 9   LogisticRegression           dataset_05_pvtt_pca   test
# 10  LogisticRegression      dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression      dataset_06_pvtt_mean_pca   test
# 12  LogisticRegression  dataset_07_pvtt_mean_cov_pca  train
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 12  {'genre_blues': {'precision': 0.0997526793, 'r...
#                  model                       dataset  phase  \
# 0   LogisticRegression           dataset_01_mean_pca  train
# 1   LogisticRegression           dataset_01_mean_pca   test
# 2   LogisticRegression       dataset_02_mean_cov_pca  train
# 3   LogisticRegression       dataset_02_mean_cov_pca   test
# 4   LogisticRegression      dataset_03_mean_icov_pca  train
# 5   LogisticRegression      dataset_03_mean_icov_pca   test
# 6   LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression           dataset_05_pvtt_pca  train
# 9   LogisticRegression           dataset_05_pvtt_pca   test
# 10  LogisticRegression      dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression      dataset_06_pvtt_mean_pca   test
# 12  LogisticRegression  dataset_07_pvtt_mean_cov_pca  train
# 0   LogisticRegression  dataset_07_pvtt_mean_cov_pca   test
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 12  {'genre_blues': {'precision': 0.0997526793, 'r...
# 0   {'genre_blues': {'precision': 0.09219858156028...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0922  0.2766    0.1383       94  0.1272
#   genre_classical     0.8785  0.8085    0.8421     1055  0.7942
#     genre_country     0.1543  0.6341    0.2482       82  0.2882
#       genre_disco     0.1429  0.6250    0.2326       72  0.2762
#      genre_hiphop     0.4865  0.3812    0.4274      425  0.3759
#        genre_jazz     0.4050  0.5756    0.4754      311  0.4343
#       genre_metal     0.3071  0.7530    0.4363      166  0.4505
#         genre_pop     0.6202  0.1955    0.2973     1069  0.2499
#      genre_reggae     0.4138  0.5482    0.4716      197  0.4472
#        genre_rock     0.5700  0.4175    0.4820      800  0.3911
#
#          accuracy                       0.4900     4271  0.4269
#         macro avg     0.4070  0.5215    0.4051     4271
#      weighted avg     0.5953  0.4900    0.5003     4271
#               min     0.0922  0.1955    0.1383       72  0.1272
# Commencing Experiment: LogisticRegression_dataset_08_pvtt_mean_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.353396
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_08_pvtt_mean_icov_pca_train
#                  model                       dataset  phase  \
# 0   LogisticRegression           dataset_01_mean_pca  train
# 1   LogisticRegression           dataset_01_mean_pca   test
# 2   LogisticRegression       dataset_02_mean_cov_pca  train
# 3   LogisticRegression       dataset_02_mean_cov_pca   test
# 4   LogisticRegression      dataset_03_mean_icov_pca  train
# 5   LogisticRegression      dataset_03_mean_icov_pca   test
# 6   LogisticRegression  dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression  dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression           dataset_05_pvtt_pca  train
# 9   LogisticRegression           dataset_05_pvtt_pca   test
# 10  LogisticRegression      dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression      dataset_06_pvtt_mean_pca   test
# 12  LogisticRegression  dataset_07_pvtt_mean_cov_pca  train
# 13  LogisticRegression  dataset_07_pvtt_mean_cov_pca   test
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# ...
# 12  LogisticRegression   dataset_07_pvtt_mean_cov_pca  train
# 13  LogisticRegression   dataset_07_pvtt_mean_cov_pca   test
# 14  LogisticRegression  dataset_08_pvtt_mean_icov_pca  train
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 12  {'genre_blues': {'precision': 0.0997526793, 'r...
# 13  {'genre_blues': {'precision': 0.0921985816, 'r...
# 14  {'genre_blues': {'precision': 0.0309405941, 'r...
#                  model                        dataset  phase  \
# 0   LogisticRegression            dataset_01_mean_pca  train
# 1   LogisticRegression            dataset_01_mean_pca   test
# 2   LogisticRegression        dataset_02_mean_cov_pca  train
# 3   LogisticRegression        dataset_02_mean_cov_pca   test
# 4   LogisticRegression       dataset_03_mean_icov_pca  train
# 5   LogisticRegression       dataset_03_mean_icov_pca   test
# 6   LogisticRegression   dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression   dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression            dataset_05_pvtt_pca  train
# 9   LogisticRegression            dataset_05_pvtt_pca   test
# 10  LogisticRegression       dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression       dataset_06_pvtt_mean_pca   test
# 12  LogisticRegression   dataset_07_pvtt_mean_cov_pca  train
# 13  LogisticRegression   dataset_07_pvtt_mean_cov_pca   test
# 14  LogisticRegression  dataset_08_pvtt_mean_icov_pca  train
# 0   LogisticRegression  dataset_08_pvtt_mean_icov_pca   test
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 12  {'genre_blues': {'precision': 0.0997526793, 'r...
# 13  {'genre_blues': {'precision': 0.0921985816, 'r...
# 14  {'genre_blues': {'precision': 0.0309405941, 'r...
# 0   {'genre_blues': {'precision': 0.03191489361702...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0319  0.0638    0.0426       94  0.0145
#   genre_classical     0.8381  0.8000    0.8186     1055  0.7613
#     genre_country     0.0704  0.4024    0.1198       82  0.1310
#       genre_disco     0.0725  0.4722    0.1257       72  0.1518
#      genre_hiphop     0.2492  0.1906    0.2160      425  0.1435
#        genre_jazz     0.2851  0.4051    0.3347      311  0.2775
#       genre_metal     0.2206  0.7349    0.3394      166  0.3627
#         genre_pop     0.4091  0.0421    0.0763     1069  0.0596
#      genre_reggae     0.1520  0.0964    0.1180      197  0.0876
#        genre_rock     0.3465  0.2525    0.2921      800  0.1622
#
#          accuracy                       0.3540     4271  0.2816
#         macro avg     0.2675  0.3460    0.2483     4271
#      weighted avg     0.4387  0.3540    0.3459     4271
#               min     0.0319  0.0421    0.0426       72  0.0145
# Commencing Experiment: LogisticRegression_dataset_09_pvtt_mean_cov_icov
#
# PCA pre_processing started
# PCA pre_processing completed
# Training accuracy: train_accuracy = 0.480328
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_09_pvtt_mean_cov_icov_pca_train
#                  model                        dataset  phase  \
# 0   LogisticRegression            dataset_01_mean_pca  train
# 1   LogisticRegression            dataset_01_mean_pca   test
# 2   LogisticRegression        dataset_02_mean_cov_pca  train
# 3   LogisticRegression        dataset_02_mean_cov_pca   test
# 4   LogisticRegression       dataset_03_mean_icov_pca  train
# 5   LogisticRegression       dataset_03_mean_icov_pca   test
# 6   LogisticRegression   dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression   dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression            dataset_05_pvtt_pca  train
# 9   LogisticRegression            dataset_05_pvtt_pca   test
# 10  LogisticRegression       dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression       dataset_06_pvtt_mean_pca   test
# 12  LogisticRegression   dataset_07_pvtt_mean_cov_pca  train
# 13  LogisticRegression   dataset_07_pvtt_mean_cov_pca   test
# 14  LogisticRegression  dataset_08_pvtt_mean_icov_pca  train
# 15  LogisticRegression  dataset_08_pvtt_mean_icov_pca   test
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 12  {'genre_blues': {'precision': 0.0997526793, 'r...
# 13  {'genre_blues': {'precision': 0.0921985816, 'r...
# 14  {'genre_blues': {'precision': 0.0309405941, 'r...
# 15  {'genre_blues': {'precision': 0.0319148936, 'r...
#                  model                            dataset  phase  \
# 0   LogisticRegression                dataset_01_mean_pca  train
# 1   LogisticRegression                dataset_01_mean_pca   test
# 2   LogisticRegression            dataset_02_mean_cov_pca  train
# 3   LogisticRegression            dataset_02_mean_cov_pca   test
# 4   LogisticRegression           dataset_03_mean_icov_pca  train
# 5   LogisticRegression           dataset_03_mean_icov_pca   test
# 6   LogisticRegression       dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression       dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression                dataset_05_pvtt_pca  train
# 9   LogisticRegression                dataset_05_pvtt_pca   test
# 10  LogisticRegression           dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression           dataset_06_pvtt_mean_pca   test
# 12  LogisticRegression       dataset_07_pvtt_mean_cov_pca  train
# 13  LogisticRegression       dataset_07_pvtt_mean_cov_pca   test
# 14  LogisticRegression      dataset_08_pvtt_mean_icov_pca  train
# 15  LogisticRegression      dataset_08_pvtt_mean_icov_pca   test
# 0   LogisticRegression  dataset_09_pvtt_mean_cov_icov_pca  train
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 12  {'genre_blues': {'precision': 0.0997526793, 'r...
# 13  {'genre_blues': {'precision': 0.0921985816, 'r...
# 14  {'genre_blues': {'precision': 0.0309405941, 'r...
# 15  {'genre_blues': {'precision': 0.0319148936, 'r...
# 0   {'genre_blues': {'precision': 0.09017059301380...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0902  0.2968    0.1383      374  0.1300
#   genre_classical     0.8848  0.7863    0.8327     4221  0.7843
#     genre_country     0.1396  0.5902    0.2257      327  0.2608
#       genre_disco     0.1257  0.5813    0.2066      289  0.2457
#      genre_hiphop     0.4912  0.3792    0.4280     1701  0.3774
#        genre_jazz     0.4094  0.5536    0.4707     1241  0.4282
#       genre_metal     0.3096  0.7970    0.4459      665  0.4670
#         genre_pop     0.5964  0.1781    0.2742     4274  0.2271
#      genre_reggae     0.4040  0.6117    0.4866      788  0.4675
#        genre_rock     0.5929  0.4088    0.4839     3200  0.4003
#
#          accuracy                       0.4803    17080  0.4194
#         macro avg     0.4044  0.5183    0.3993    17080
#      weighted avg     0.5951  0.4803    0.4925    17080
#               min     0.0902  0.1781    0.1383      289  0.1300
#
# Testing accuracy: test_accuracy = 0.489113
#
# c:\Users\alvin\OneDrive - UCLA IT Services\Berkeley MIDS\W207\final_project\member_workspaces\alvin\..\..\results\test_results.json
# file exist, reading json
# saving model logisticregression_dataset_09_pvtt_mean_cov_icov_pca_test
#                  model                            dataset  phase  \
# 0   LogisticRegression                dataset_01_mean_pca  train
# 1   LogisticRegression                dataset_01_mean_pca   test
# 2   LogisticRegression            dataset_02_mean_cov_pca  train
# 3   LogisticRegression            dataset_02_mean_cov_pca   test
# 4   LogisticRegression           dataset_03_mean_icov_pca  train
# 5   LogisticRegression           dataset_03_mean_icov_pca   test
# 6   LogisticRegression       dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression       dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression                dataset_05_pvtt_pca  train
# 9   LogisticRegression                dataset_05_pvtt_pca   test
# 10  LogisticRegression           dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression           dataset_06_pvtt_mean_pca   test
# 12  LogisticRegression       dataset_07_pvtt_mean_cov_pca  train
# 13  LogisticRegression       dataset_07_pvtt_mean_cov_pca   test
# 14  LogisticRegression      dataset_08_pvtt_mean_icov_pca  train
# 15  LogisticRegression      dataset_08_pvtt_mean_icov_pca   test
# 16  LogisticRegression  dataset_09_pvtt_mean_cov_icov_pca  train
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 12  {'genre_blues': {'precision': 0.0997526793, 'r...
# 13  {'genre_blues': {'precision': 0.0921985816, 'r...
# 14  {'genre_blues': {'precision': 0.0309405941, 'r...
# 15  {'genre_blues': {'precision': 0.0319148936, 'r...
# 16  {'genre_blues': {'precision': 0.090170593, 're...
#                  model                            dataset  phase  \
# 0   LogisticRegression                dataset_01_mean_pca  train
# 1   LogisticRegression                dataset_01_mean_pca   test
# 2   LogisticRegression            dataset_02_mean_cov_pca  train
# 3   LogisticRegression            dataset_02_mean_cov_pca   test
# 4   LogisticRegression           dataset_03_mean_icov_pca  train
# 5   LogisticRegression           dataset_03_mean_icov_pca   test
# 6   LogisticRegression       dataset_04_mean_cov_icov_pca  train
# 7   LogisticRegression       dataset_04_mean_cov_icov_pca   test
# 8   LogisticRegression                dataset_05_pvtt_pca  train
# 9   LogisticRegression                dataset_05_pvtt_pca   test
# 10  LogisticRegression           dataset_06_pvtt_mean_pca  train
# 11  LogisticRegression           dataset_06_pvtt_mean_pca   test
# 12  LogisticRegression       dataset_07_pvtt_mean_cov_pca  train
# 13  LogisticRegression       dataset_07_pvtt_mean_cov_pca   test
# 14  LogisticRegression      dataset_08_pvtt_mean_icov_pca  train
# 15  LogisticRegression      dataset_08_pvtt_mean_icov_pca   test
# 16  LogisticRegression  dataset_09_pvtt_mean_cov_icov_pca  train
# 0   LogisticRegression  dataset_09_pvtt_mean_cov_icov_pca   test
#
#                                                result
# 0   {'genre_blues': {'precision': 0.052905464, 're...
# 1   {'genre_blues': {'precision': 0.0729927007, 'r...
# 2   {'genre_blues': {'precision': 0.093442623, 're...
# 3   {'genre_blues': {'precision': 0.1015037594, 'r...
# 4   {'genre_blues': {'precision': 0.0379746835, 'r...
# 5   {'genre_blues': {'precision': 0.0355329949, 'r...
# 6   {'genre_blues': {'precision': 0.0875202593, 'r...
# 7   {'genre_blues': {'precision': 0.0959409594, 'r...
# 8   {'genre_blues': {'precision': 0.0413943355, 'r...
# 9   {'genre_blues': {'precision': 0.0720720721, 'r...
# 10  {'genre_blues': {'precision': 0.0528893242, 'r...
# 11  {'genre_blues': {'precision': 0.0788381743, 'r...
# 12  {'genre_blues': {'precision': 0.0997526793, 'r...
# 13  {'genre_blues': {'precision': 0.0921985816, 'r...
# 14  {'genre_blues': {'precision': 0.0309405941, 'r...
# 15  {'genre_blues': {'precision': 0.0319148936, 'r...
# 16  {'genre_blues': {'precision': 0.090170593, 're...
# 0   {'genre_blues': {'precision': 0.08602150537634...
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0860  0.2553    0.1287       94  0.1153
#   genre_classical     0.8800  0.8133    0.8453     1055  0.7983
#     genre_country     0.1461  0.6220    0.2367       82  0.2759
#       genre_disco     0.1392  0.6111    0.2268       72  0.2687
#      genre_hiphop     0.4691  0.3576    0.4059      425  0.3538
#        genre_jazz     0.4116  0.5691    0.4777      311  0.4363
#       genre_metal     0.3188  0.7952    0.4552      166  0.4746
#         genre_pop     0.6060  0.1899    0.2892     1069  0.2395
#      genre_reggae     0.3948  0.5431    0.4573      197  0.4327
#        genre_rock     0.5900  0.4263    0.4949      800  0.4083
#
#          accuracy                       0.4891     4271  0.4263
#         macro avg     0.4042  0.5183    0.4018     4271
#      weighted avg     0.5939  0.4891    0.4990     4271
#               min     0.0860  0.1899    0.1287       72  0.1153
