# %%
import glob
import sys

import numpy as np
import pandas as pd
from xgboost import XGBClassifier, XGBRFClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.mixture import GaussianMixture
import tensorflow as tf
from sklearn.utils.class_weight import compute_class_weight
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from tensorflow.keras.layers import Dropout, Dense, Input
sys.path.append("../../")

from helpers.experiment import experiment

# %%
dataset = '../../datasets/dataset_09_pvtt_mean_cov_icov.pickle'

n_components=None
model_SVC = SVC(class_weight='balanced',probability=True)
ex_SVC = experiment(
    model_SVC,
    dataset,
    result_filename="rich_results.json"
)

# model_fit_call_fn=lambda model,X_train,y_train,class_weight: model.fit(X_train, y_train)
# Out:
# Commencing Experiment: SVC_dataset_09_pvtt_mean_cov_icov
#
# Training accuracy: train_accuracy = 0.681250
#
# /Users/dcollins/berkeley-mids/music_genre_group_207/member_workspaces/danny/../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.5057  0.5500    0.5269       80  0.4724
#   genre_classical     0.8000  0.9000    0.8471       80  0.8307
#     genre_country     0.6429  0.6750    0.6585       80  0.6198
#       genre_disco     0.5690  0.8250    0.6735       80  0.6438
#      genre_hiphop     0.8276  0.6000    0.6957       80  0.6781
#        genre_jazz     0.7463  0.6250    0.6803       80  0.6513
#       genre_metal     0.6731  0.8750    0.7609       80  0.7384
#         genre_pop     0.8462  0.4125    0.5546       80  0.5631
#      genre_reggae     0.7683  0.7875    0.7778       80  0.7528
#        genre_rock     0.6164  0.5625    0.5882       80  0.5455
#
#          accuracy                       0.6813      800  0.6483
#         macro avg     0.6995  0.6813    0.6763      800
#      weighted avg     0.6995  0.6813    0.6763      800
#               min     0.5057  0.4125    0.5269       80  0.4724
#
# Testing accuracy: test_accuracy = 0.420000
#
# /Users/dcollins/berkeley-mids/music_genre_group_207/member_workspaces/danny/../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.1765  0.1500    0.1622       20  0.0777
#   genre_classical     0.6154  0.8000    0.6957       20  0.6641
#     genre_country     0.5833  0.3500    0.4375       20  0.4070
#       genre_disco     0.3590  0.7000    0.4746       20  0.4249
#      genre_hiphop     0.3077  0.2000    0.2424       20  0.1825
#        genre_jazz     0.6429  0.4500    0.5294       20  0.4964
#       genre_metal     0.4857  0.8500    0.6182       20  0.5922
#         genre_pop     0.2000  0.0500    0.0800       20  0.0534
#      genre_reggae     0.4783  0.5500    0.5116       20  0.4545
#        genre_rock     0.1250  0.1000    0.1111       20  0.0246
#
#          accuracy                       0.4200      200  0.3608
#         macro avg     0.3974  0.4200    0.3863      200
#      weighted avg     0.3974  0.4200    0.3863      200
#               min     0.1250  0.0500    0.0800       20  0.0246

# %%
model_XGB = XGBClassifier(
        use_label_encoder=False,
        tree_method='hist', 
        eta=.05,
        max_depth=6,
        reg_alpha=10,
        sampling_method='gradient_based',
        objective="multi:softprob", 
        eval_metric="mlogloss",
)
ex_XGB = experiment(
    model=model_XGB,
    dataset=dataset,
    pca_components=n_components,
    result_filename="rich_results.json",
    X_train_std=ex_SVC['X_train_std'],
    X_test_std=ex_SVC['X_test_std'],
    y_train=ex_SVC['y_train'],
    y_test=ex_SVC['y_test'],
    label_encoder=ex_SVC['label_encoder']
)
# Out:
# Commencing Experiment: XGBClassifier_dataset_09_pvtt_mean_cov_icov
#
# Training accuracy: train_accuracy = 0.752693
#
# /Users/dcollins/berkeley-mids/music_genre_group_207/member_workspaces/danny/../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  0.0241    0.0470      374  0.1535
#   genre_classical     0.8778  0.9159    0.8965     4221  0.8619
#     genre_country     0.9655  0.3425    0.5056      327  0.5711
#       genre_disco     0.8370  0.2664    0.4042      289  0.4679
#      genre_hiphop     0.7609  0.7519    0.7564     1701  0.7296
#        genre_jazz     0.8056  0.5745    0.6707     1241  0.6601
#       genre_metal     0.9675  0.5368    0.6905      665  0.7133
#         genre_pop     0.6256  0.8173    0.7087     4274  0.6040
#      genre_reggae     0.8195  0.6510    0.7256      788  0.7191
#        genre_rock     0.7351  0.7616    0.7481     3200  0.6889
#
#          accuracy                       0.7527    17080  0.6951
#         macro avg     0.8395  0.5642    0.6153    17080
#      weighted avg     0.7756  0.7527    0.7410    17080
#               min     0.6256  0.0241    0.0470      289  0.1535
#
# Testing accuracy: test_accuracy = 0.634278
#
# /Users/dcollins/berkeley-mids/music_genre_group_207/member_workspaces/danny/../../results/rich_results.json
# file exist, reading json
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.0000  0.0000    0.0000       94  0.0000
#   genre_classical     0.8282  0.8957    0.8607     1055  0.8137
#     genre_country     1.0000  0.2439    0.3922       82  0.4903
#       genre_disco     0.7778  0.1944    0.3111       72  0.3845
#      genre_hiphop     0.5612  0.4965    0.5268      425  0.4792
#        genre_jazz     0.6495  0.4051    0.4990      311  0.4841
#       genre_metal     0.7692  0.3012    0.4329      166  0.4698
#         genre_pop     0.5003  0.6782    0.5759     1069  0.4136
#      genre_reggae     0.6765  0.4670    0.5526      197  0.5450
#        genre_rock     0.6032  0.6575    0.6292      800  0.5399
#
#          accuracy                       0.6343     4271  0.5451
#         macro avg     0.6366  0.4340    0.4780     4271
#      weighted avg     0.6393  0.6343    0.6184     4271
#               min     0.0000  0.0000    0.0000       72  0.0000

# %%
model_KNN = KNeighborsClassifier(n_neighbors=3,weights='distance')
ex_KNN = experiment(
    model=model_KNN,
    dataset=dataset,
    pca_components=n_components,
    result_filename="rich_results.json",
    X_train_std=ex_SVC['X_train_std'],
    X_test_std=ex_SVC['X_test_std'],
    y_train=ex_SVC['y_train'],
    y_test=ex_SVC['y_test'],
    label_encoder=ex_SVC['label_encoder']
)
# Out:
# Commencing Experiment: KNeighborsClassifier_dataset_09_pvtt_mean_cov_icov
#
# Training accuracy: train_accuracy = 1.000000
#
# /Users/dcollins/berkeley-mids/music_genre_group_207/member_workspaces/danny/../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     1.0000  1.0000    1.0000      374  1.0000
#   genre_classical     1.0000  1.0000    1.0000     4221  1.0000
#     genre_country     1.0000  1.0000    1.0000      327  1.0000
#       genre_disco     1.0000  1.0000    1.0000      289  1.0000
#      genre_hiphop     1.0000  1.0000    1.0000     1701  1.0000
#        genre_jazz     1.0000  1.0000    1.0000     1241  1.0000
#       genre_metal     1.0000  1.0000    1.0000      665  1.0000
#         genre_pop     1.0000  1.0000    1.0000     4274  1.0000
#      genre_reggae     1.0000  1.0000    1.0000      788  1.0000
#        genre_rock     1.0000  1.0000    1.0000     3200  1.0000
#
#          accuracy                       1.0000    17080  1.0000
#         macro avg     1.0000  1.0000    1.0000    17080
#      weighted avg     1.0000  1.0000    1.0000    17080
#               min     1.0000  1.0000    1.0000      289  1.0000
#
# Testing accuracy: test_accuracy = 0.587216
#
# /Users/dcollins/berkeley-mids/music_genre_group_207/member_workspaces/danny/../../results/rich_results.json
# file exist, reading json
# record saved
#                    precision  recall  f1-score  support     mcc
#
#       genre_blues     0.2462  0.1702    0.2013       94  0.1899
#   genre_classical     0.7973  0.8427    0.8194     1055  0.7584
#     genre_country     0.5584  0.5244    0.5409       82  0.5325
#       genre_disco     0.1857  0.1806    0.1831       72  0.1693
#      genre_hiphop     0.4823  0.3200    0.3847      425  0.3400
#        genre_jazz     0.4835  0.5177    0.5000      311  0.4596
#       genre_metal     0.4596  0.4458    0.4526      166  0.4309
#         genre_pop     0.5227  0.5706    0.5456     1069  0.3856
#      genre_reggae     0.4726  0.4822    0.4774      197  0.4519
#        genre_rock     0.5887  0.5887    0.5887      800  0.4940
#
#          accuracy                       0.5872     4271  0.4942
#         macro avg     0.4797  0.4643    0.4694     4271
#      weighted avg     0.5802  0.5872    0.5814     4271
#               min     0.1857  0.1702    0.1831       72  0.1693

# %%
pd.read_pickle('../../datasets/dataset_01_mean.pickle')
# Out:
#        mfcc_mean_0  mfcc_mean_1  mfcc_mean_2  mfcc_mean_3  mfcc_mean_4  \
# 11     -646.231445   111.854805    19.008308    16.829792     0.384627
# 13     -765.565979   178.684052   -26.383612     5.345988   -13.608403
# 14     -658.642700   112.548470    15.934329    17.882261    -1.357603
# 15     -774.882141   163.441223    56.226765    26.311859     9.883611
# 16     -609.905518    79.316460    22.191978    33.732761    13.227217
# ...            ...          ...          ...          ...          ...
# 55196  -677.128967   112.194321    -2.356055    27.138754    -4.340651
# 55205  -657.834778   104.840073    23.781740    18.864958     5.405090
# 55207  -762.701416   174.228287     3.216133     9.339471    -2.972456
# 55208  -671.603333   117.805748   -22.434090    17.718218     2.330396
# 55212  -875.106567   197.650681    29.310038    15.308829    10.092481
#
#        mfcc_mean_5  mfcc_mean_6  mfcc_mean_7  mfcc_mean_8  mfcc_mean_9  ...  \
# 11       -0.737740    -3.406654     4.369300    -2.526016     4.839982  ...
# 13      -17.391293   -20.750830    -7.267175   -11.232429   -11.701081  ...
# 14       13.185078    -2.982529     4.172069    -0.221640    -1.373562  ...
# 15        8.146501     2.419113     9.639036    -2.464165     0.318586  ...
# 16       -3.533257     3.880107     9.074506   -10.473398     3.426618  ...
# ...            ...          ...          ...          ...          ...  ...
# 55196    -1.145098     3.741500     4.097663     7.800027     4.520276  ...
# 55205     3.316004     2.755989     6.786467    -0.963619     4.307145  ...
# 55207    -4.029442    -8.040684    -3.637555    -3.809685    -1.340430  ...
# 55208    -4.240941    -9.629152     3.024223     6.413898     9.106426  ...
# 55212     3.602807    -0.255556    -7.285394   -16.927988   -15.285859  ...
#
#        genre_blues  genre_classical  genre_country  genre_disco  genre_hiphop  \
# 11               0                0              0            0             0
# 13               0                1              0            0             0
# 14               0                0              0            0             0
# 15               0                0              0            0             0
# 16               0                0              0            0             0
# ...            ...              ...            ...          ...           ...
# 55196            1                0              0            0             0
# 55205            0                0              0            0             1
# 55207            0                1              0            0             0
# 55208            0                0              0            0             1
# 55212            0                1              0            0             0
#
#        genre_jazz  genre_metal  genre_pop  genre_reggae  genre_rock
# 11              0            0          0             1           0
# 13              0            0          0             0           0
# 14              0            0          0             1           0
# 15              0            0          1             0           0
# 16              0            0          0             1           0
# ...           ...          ...        ...           ...         ...
# 55196           0            0          0             0           0
# 55205           0            0          0             0           0
# 55207           0            0          0             0           0
# 55208           0            0          0             0           0
# 55212           0            0          0             0           0
#
# [21351 rows x 23 columns]

# %%
#model_GMM = GaussianMixture(n_components=10,verbose=1,max_iter=100,
              # init_params='k-means' #{‘kmeans’, ‘k-means++’, ‘random’, ‘random_from_data’},
#)
#ex_GMM=experiment(model_GMM, dataset, pca_components=100, result_filename="rich_results.json")

# %%
svc_X_train_raw = ex_SVC['model'].predict_proba(ex_SVC['X_train_std'])
svc_X_test_raw = ex_SVC['model'].predict_proba(ex_SVC['X_test_std'])

# %%
xgb_X_train_raw = ex_XGB['model'].predict(ex_SVC['X_train_std'],output_margin=True)
xgb_X_test_raw = ex_XGB['model'].predict(ex_SVC['X_test_std'],output_margin=True)

# %%
knn_X_train_raw = ex_KNN['model'].predict_proba(ex_SVC['X_train_std'])
knn_X_test_raw = ex_KNN['model'].predict_proba(ex_SVC['X_test_std'])

# %%
svc_pca = 5
xgb_pca = 2
knn_pca = 2

def PCAify(tr,ts,pca_components):
    pca = PCA(n_components=pca_components)
    tr = pca.fit_transform(tr)
    ts = pca.transform(ts)
    return (tr,ts)

svc_X_train,svc_X_test = PCAify(svc_X_train_raw,svc_X_test_raw,svc_pca)
xgb_X_train,xgb_X_test = PCAify(xgb_X_train_raw,xgb_X_test_raw,xgb_pca)
knn_X_train,knn_X_test = PCAify(knn_X_train_raw,knn_X_test_raw,knn_pca)

# %%
class_weight={
    i: c
    for i, c in enumerate(
        compute_class_weight(
            class_weight="balanced",
            classes=ex_SVC['label_encoder'].transform(ex_SVC['label_encoder'].classes_),
            y=ex_SVC['y_train'],
        )
    )
}


svc_input = Input(shape=(svc_pca,),dtype=tf.float32,name="SVC Input")
xgb_input = Input(shape=(xgb_pca,),dtype=tf.float32,name="XGB Input")
knn_input = Input(shape=(knn_pca,),dtype=tf.float32,name="KNN Input")
joined_input = tf.keras.layers.Concatenate()([svc_input,xgb_input,knn_input])
# hidden_1 = tf.keras.layers.Dense(units=2,activation='relu',name='hidden1')(joined_input)
genre = tf.keras.layers.Dense(units=10,activation='softmax')(joined_input)
model = tf.keras.Model(inputs=[svc_input,xgb_input,knn_input],outputs=genre)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(
    loss='sparse_categorical_crossentropy',     
    optimizer=optimizer, 
    metrics=['accuracy']
)

model.fit(
    x={
        'SVC Input':svc_X_train,
        'XGB Input':xgb_X_train,
        'KNN Input':knn_X_train
    },
    class_weight=class_weight,
    y=ex_SVC['y_train'],
    batch_size=64,
    epochs=20,
    validation_data=({
        'SVC Input':svc_X_test,
        'XGB Input':xgb_X_test,
        'KNN Input':knn_X_test
    },ex_SVC['y_test'])
)
# Out:
# Epoch 1/20
# 267/267 [==============================] - 1s 2ms/step - loss: 1.4269 - accuracy: 0.7164 - val_loss: 1.3729 - val_accuracy: 0.5800
# Epoch 2/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.9896 - accuracy: 0.8555 - val_loss: 1.4715 - val_accuracy: 0.5835
# Epoch 3/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.8776 - accuracy: 0.8755 - val_loss: 1.6139 - val_accuracy: 0.5704
# Epoch 4/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.8236 - accuracy: 0.8838 - val_loss: 1.7174 - val_accuracy: 0.5722
# Epoch 5/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7917 - accuracy: 0.8898 - val_loss: 1.8517 - val_accuracy: 0.5601
# Epoch 6/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7692 - accuracy: 0.8935 - val_loss: 1.9383 - val_accuracy: 0.5608
# Epoch 7/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7545 - accuracy: 0.8960 - val_loss: 2.0279 - val_accuracy: 0.5610
# Epoch 8/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7442 - accuracy: 0.8968 - val_loss: 2.1326 - val_accuracy: 0.5547
# Epoch 9/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7355 - accuracy: 0.8984 - val_loss: 2.2076 - val_accuracy: 0.5556
# Epoch 10/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7275 - accuracy: 0.8993 - val_loss: 2.2923 - val_accuracy: 0.5533
# Epoch 11/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7214 - accuracy: 0.9019 - val_loss: 2.3764 - val_accuracy: 0.5507
# Epoch 12/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7157 - accuracy: 0.9015 - val_loss: 2.4564 - val_accuracy: 0.5495
# Epoch 13/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7112 - accuracy: 0.9030 - val_loss: 2.5465 - val_accuracy: 0.5495
# Epoch 14/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7055 - accuracy: 0.9041 - val_loss: 2.6291 - val_accuracy: 0.5488
# Epoch 15/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.7013 - accuracy: 0.9058 - val_loss: 2.7188 - val_accuracy: 0.5455
# Epoch 16/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.6970 - accuracy: 0.9055 - val_loss: 2.8120 - val_accuracy: 0.5444
# Epoch 17/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.9071 - val_loss: 2.9134 - val_accuracy: 0.5434
# Epoch 18/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.6877 - accuracy: 0.9071 - val_loss: 3.0099 - val_accuracy: 0.5432
# Epoch 19/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.6836 - accuracy: 0.9105 - val_loss: 3.1140 - val_accuracy: 0.5411
# Epoch 20/20
# 267/267 [==============================] - 0s 1ms/step - loss: 0.6793 - accuracy: 0.9101 - val_loss: 3.2253 - val_accuracy: 0.5395

# %%
merged_pca_count=10
# merged_X_train_raw = np.concatenate([
#     svc_X_train_raw,
#     xgb_X_train_raw,
#     knn_X_train_raw
# ],axis=1)
# merged_X_test_raw = np.concatenate([
#     svc_X_test_raw,
#     xgb_X_test_raw,
#     knn_X_test_raw
# ],axis=1)
# merged_X_train, merged_X_test = PCAify(merged_X_train_raw,merged_X_test_raw,merged_pca_count)

merged_X_train = np.concatenate([
    svc_X_train,
    xgb_X_train,
    knn_X_train
],axis=1)
merged_X_test = np.concatenate([
    svc_X_test,
    xgb_X_test,
    knn_X_test
],axis=1)

# np.shape(merged_X_train)

# %%
merged_input = Input(shape=(9,),dtype=tf.float32,name="Merged Input")

# joined_input = tf.keras.layers.Concatenate()([svc_input,xgb_input,knn_input])
hidden_1 = Dense(units=10,activation='relu',name='hidden1')(merged_input)
hidden_2 = Dense(units=10,activation='relu',name='hidden2')(Dropout(0.2)(hidden_1))
hidden_3 = Dense(units=10,activation='relu',name='hidden3')(Dropout(0.2)(hidden_2))
genre = Dense(units=10,activation='softmax')(Dropout(0.2)(hidden_3))
model = tf.keras.Model(inputs=[merged_input],outputs=genre)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(
    loss='sparse_categorical_crossentropy',     
    optimizer=optimizer, 
    metrics=['accuracy']
)

model.fit(
    x={
        'Merged Input':merged_X_train,
        #'XGB Input':xgb_X_train,
        #'KNN Input':knn_X_train
    },
    class_weight=class_weight,
    y=ex_SVC['y_train'],
    batch_size=4,
    epochs=20,
    validation_data=({
        'Merged Input':merged_X_test,
        #'XGB Input':xgb_X_test,
        #'KNN Input':knn_X_test
    },ex_SVC['y_test'])
)
# Out:
# Epoch 1/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.3327 - accuracy: 0.6989 - val_loss: 9.9510 - val_accuracy: 0.5357
# Epoch 2/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.2006 - accuracy: 0.7431 - val_loss: 11.5563 - val_accuracy: 0.5144
# Epoch 3/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1884 - accuracy: 0.7516 - val_loss: 26.9460 - val_accuracy: 0.5294
# Epoch 4/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1933 - accuracy: 0.7611 - val_loss: 20.2863 - val_accuracy: 0.5048
# Epoch 5/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1896 - accuracy: 0.7612 - val_loss: 28.5534 - val_accuracy: 0.5324
# Epoch 6/20
# 4270/4270 [==============================] - 6s 1ms/step - loss: 1.1823 - accuracy: 0.7582 - val_loss: 43.0768 - val_accuracy: 0.5111
# Epoch 7/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1825 - accuracy: 0.7590 - val_loss: 53.4603 - val_accuracy: 0.5359
# Epoch 8/20
# 4270/4270 [==============================] - 4s 1ms/step - loss: 1.1514 - accuracy: 0.7650 - val_loss: 53.8777 - val_accuracy: 0.5310
# Epoch 9/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1321 - accuracy: 0.7796 - val_loss: 43.4389 - val_accuracy: 0.5163
# Epoch 10/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1473 - accuracy: 0.7782 - val_loss: 57.9755 - val_accuracy: 0.5109
# Epoch 11/20
# 4270/4270 [==============================] - 4s 1ms/step - loss: 1.1358 - accuracy: 0.7847 - val_loss: 73.4030 - val_accuracy: 0.5266
# Epoch 12/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1185 - accuracy: 0.7830 - val_loss: 70.0242 - val_accuracy: 0.5163
# Epoch 13/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1598 - accuracy: 0.7810 - val_loss: 135.8386 - val_accuracy: 0.5350
# Epoch 14/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1591 - accuracy: 0.7854 - val_loss: 151.6625 - val_accuracy: 0.5479
# Epoch 15/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1807 - accuracy: 0.7732 - val_loss: 139.5913 - val_accuracy: 0.5228
# Epoch 16/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.2435 - accuracy: 0.7596 - val_loss: 126.9328 - val_accuracy: 0.5338
# Epoch 17/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.2166 - accuracy: 0.7721 - val_loss: 126.3318 - val_accuracy: 0.5226
# Epoch 18/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1752 - accuracy: 0.7831 - val_loss: 122.2094 - val_accuracy: 0.5256
# Epoch 19/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1448 - accuracy: 0.7857 - val_loss: 153.0487 - val_accuracy: 0.5284
# Epoch 20/20
# 4270/4270 [==============================] - 5s 1ms/step - loss: 1.1814 - accuracy: 0.7788 - val_loss: 98.5733 - val_accuracy: 0.5418

# %%
pdf = pd.DataFrame(data={
    'svc_pred':ex_SVC['y_test_pred'],
    'xgb_pred':ex_XGB['y_test_pred'],
    'knn_pred':ex_KNN['y_test_pred'],
    'y_true':ex_SVC['y_test']
})
# pdf['p1correct'] = pdf['pred1']==pdf['y_true']
# pdf['p2correct'] = pdf['pred2']==pdf['y_true']
# pdf['pagree'] = pdf['pred1']==pdf['pred2']
# pdf['p1or2correct'] = pdf['p1correct'] | pdf['p2correct']

pdf['svc_pred_correct'] = pdf.apply(lambda x: 1 if x['svc_pred'] == x['y_true'] else 0,axis=1)
pdf['xgb_pred_correct'] = pdf.apply(lambda x: 1 if x['xgb_pred'] == x['y_true'] else 0,axis=1)
pdf['knn_pred_correct'] = pdf.apply(lambda x: 1 if x['knn_pred'] == x['y_true'] else 0,axis=1)

pdf['pct_correct'] = (pdf['svc_pred_correct'] + pdf['xgb_pred_correct'] + pdf['knn_pred_correct'] ) / 3

# pdf.groupby(['svc_pred_correct','xgb_pred_correct','knn_pred_correct']).count()

pdf
# Out:
#       svc_pred  xgb_pred  knn_pred  y_true  svc_pred_correct  \
# 0            3         7         9       9                 0
# 1            1         1         1       7                 0
# 2            1         1         1       1                 1
# 3            9         9         9       9                 1
# 4            5         5         4       5                 1
# ...        ...       ...       ...     ...               ...
# 4266         6         9         9       6                 1
# 4267         1         1         1       1                 1
# 4268         5         7         7       7                 0
# 4269         7         7         7       7                 1
# 4270         1         1         1       1                 1
#
#       xgb_pred_correct  knn_pred_correct  pct_correct
# 0                    0                 1     0.333333
# 1                    0                 0     0.000000
# 2                    1                 1     1.000000
# 3                    1                 1     1.000000
# 4                    1                 0     0.666667
# ...                ...               ...          ...
# 4266                 0                 0     0.333333
# 4267                 1                 1     1.000000
# 4268                 1                 1     0.666667
# 4269                 1                 1     1.000000
# 4270                 1                 1     1.000000
#
# [4271 rows x 8 columns]

# %%
pdf.groupby(['svc_pred_correct','xgb_pred_correct','knn_pred_correct']).count()
# Out:
#                                                     svc_pred  xgb_pred  \
# svc_pred_correct xgb_pred_correct knn_pred_correct
# 0                0                0                      840       840
#                                   1                      290       290
#                  1                0                      323       323
#                                   1                      438       438
# 1                0                0                      240       240
#                                   1                      192       192
#                  1                0                      360       360
#                                   1                     1588      1588
#
#                                                     knn_pred  y_true  \
# svc_pred_correct xgb_pred_correct knn_pred_correct
# 0                0                0                      840     840
#                                   1                      290     290
#                  1                0                      323     323
#                                   1                      438     438
# 1                0                0                      240     240
#                                   1                      192     192
#                  1                0                      360     360
#                                   1                     1588    1588
#
#                                                     pct_correct
# svc_pred_correct xgb_pred_correct knn_pred_correct
# 0                0                0                         840
#                                   1                         290
#                  1                0                         323
#                                   1                         438
# 1                0                0                         240
#                                   1                         192
#                  1                0                         360
#                                   1                        1588
